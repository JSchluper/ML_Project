# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from random import sample
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
import os
from surprise.model_selection import train_test_split

# %%
raw_data = pd.read_csv("Data/Gift_Cards.csv", names=['Item', 'User', 'Rating', 'Timestamp'])
data = raw_data.sample(n=30000)
data.drop(['Timestamp'], axis=1,inplace=True)
data = data[['User', 'Item', 'Rating']]

# %%
data
# Out:
#                   User        Item  Rating
# 79555    ADGECU172C477  B00C5UMB7S     5.0
# 45764   A13YUJJPHY0J8E  B006PJHP62     5.0
# 71207   A1NBVOP8G3UAYI  B00BWDHCFK     5.0
# 26835   A2Y5TLUQGF6P67  B004Q7CK9M     5.0
# 69053   A2MYKI5Z820DUF  B00B2TFSO6     5.0
# ...                ...         ...     ...
# 36270   A1SXDT07RAO7WU  B005ESMJ02     5.0
# 118249  A13YDJCUE91G7F  B00UXLIQNY     5.0
# 123610  A3GBL75U8XGZIE  B014S24DAI     5.0
# 78767   A196VP7SA1O15O  B00C5UMEMA     4.0
# 41266   A1DIF0G7ZQVB8H  B0062ONJ6U     5.0
#
# [30000 rows x 3 columns]

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(data,reader)

# %%
trainset, testset = train_test_split(data, test_size=0.3,random_state=10)

# %%
algo = KNNWithMeans(k=5, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='A2RDO5IGKKKY6P', iid='B004LLIKVU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZXEPAGS4CYDR', iid='B005DHN6E2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A86PYSJOACBTN', iid='B00G4IWEZG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KVHTB0UM3RN2', iid='B004KNWWU4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2GBV1DKXH1FGX', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ZCXXSCEVH0RA', iid='B004W8D0Y4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AG7TAN8NFCAJA', iid='B00G4IV2VI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2D8EZD6T3SBCM', iid='B00CHQ7I2S', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GUOW4N23U0YY', iid='B01GKZ3SQG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJJV6O0ONHZUB', iid='B00JDQKFPC', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NVJ8D5IBRZ85', iid='B004KNWWV8', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1J3GIR73SLUQB', iid='B01G44QN9W', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADMAYTSC7VHYE', iid='B00IYVZ1BU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FL7JOT4IFA2S', iid='B005ESMFP6', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1X972H9A2LU3C', iid='B00A4EK69C', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1F89R0MD2RI3I', iid='B0091JKVU0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NYI5P4WFSKQT', iid='B0069VHL5Q', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WTIPXQDJIMUI', iid='B004LLIKVU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3REOG76MQQ48O', iid='B00ELQD11E', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1G22P5Q1HVNJ3', iid='B004KNWX3U', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1CQZ8U5UMMFQT', iid='B00F3ZMTO2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SXGKB06EO3OF', iid='B00BXLVFAO', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FEKNKQQBJUJQ', iid='B00F2RZMEA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LE6SIZWTREQK', iid='B00UXLIX00', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMRHC9IP59NE1', iid='B00ELQD11E', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALLSNTNR6N6UL', iid='B0091JKJ0M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASJ0WEFLPWF8H', iid='B004LLIKY2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACU22OOTCPJDF', iid='B0145WHXGM', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32XRJ0AYV17XS', iid='B00AR51Y5I', r_ui=5.0, est=4.670781893004115, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A8II27IBVO08Y', iid='B00AR51Y5I', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RYTM56O12CQ5', iid='B00MV9H6VY', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2PSDO5U6WGSR4', iid='B00JDQJZWG', r_ui=5.0, est=4.802352941176471, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A5I2D9JANKSSG', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A147LPFFV8H20Q', iid='B004LLIKY2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25DZLBUIWANNY', iid='B009CBHNXA', r_ui=3.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGYHCYAGSKYI7', iid='B00BXLVAD6', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1W825S4Y0W0Q5', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VGERCXO4SFCH', iid='B00G4IVRI6', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARO23TGKDS0SE', iid='B0062ONI5W', r_ui=2.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A33Y49309SRK04', iid='B0091JKVU0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQ2E7M8QZJQT', iid='B00Q5BNS48', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AKCBN6173LCY6', iid='B0062ONJ6U', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AKME2IEHMYFK5', iid='B00P9VGZYA', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2X3S47UDJKMAQ', iid='B00A4EK106', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HK36MGMJVDYS', iid='B00JDQJZWG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1D4PJT2IQN2TG', iid='B00O3YJMS0', r_ui=5.0, est=4.428571428571429, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AS5ZYSQTL9UGR', iid='B005ESMF5G', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31PSBZEDA504Y', iid='B00DNAGTIQ', r_ui=5.0, est=4.56, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A32LFG868940F7', iid='B00ELQD11E', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HB8M8H3BF55H', iid='B00NU7VFCC', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVTA7LHJ95RVQ', iid='B00ISCEAMG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2117I4B9N7QOD', iid='B00G4IWDXE', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LLNYU1RLPJOK', iid='B007V6ETXA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2B4L6KNQ6QN6', iid='B007V6ETDK', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AFCAW01J044YL', iid='B00BWDH0LQ', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2R3EG6SHPIHX', iid='B004LLILGO', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QLSJITS563E1', iid='B00GXSCVUU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AIECDXTCR9PRP', iid='B004LLIL5A', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2YO90BR60R7KX', iid='B004KNWWMW', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NRFH0YJ7VQ2Z', iid='B00ADR2XIC', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2PHOTTFXUGB7V', iid='B0091JL3OI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JFEGDVGO239R', iid='B004LLIKVU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TNXZD61OGXNC', iid='B004KNWX6C', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MKDH1WY7FGLS', iid='B00BXLTZ6K', r_ui=5.0, est=4.676470588235294, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A37QGB8MJ7R8J6', iid='B00BWDHBU6', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2YPI2MXNLVGIJ', iid='B004KNWWU4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10S8N8Z6T69K0', iid='B00G4IV2VI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJ46V83JH3PVM', iid='B0188LO3UK', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FX5I9I1SJSLY', iid='B00P8N415E', r_ui=4.0, est=4.6, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AISCAWYIBCCAH', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2V3R5V9LISYJV', iid='B00P9VEQF0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JNAB1DKFTIM7', iid='B00JDQJZWG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IN9VX9TLMQL5', iid='B00Q5BOSYC', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7BUUF6ZHTXRR', iid='B015QELP0S', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6JD1IONQGP2G', iid='B00CHQ7I2S', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Y18XHIK0MAJQ', iid='B00ADR2XIC', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AL5SQKHRN6E9P', iid='B00JDQJZWG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AB3O55SK94P1B', iid='B00AR51Y5I', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A336TEK9Z77932', iid='B004LLIKY2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2N8UCL2NT0IFE', iid='B00G4IV2VI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2OSD7R4SAF15Y', iid='B00MV9LSHC', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A30CTTS4BCO5G7', iid='B00FTGTIOE', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GL24X06W2A4H', iid='B00BXLSIJ0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2IF5IBX7VAB0U', iid='B00CHSWGR8', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22I68I9OLXX0G', iid='B00B2TFSO6', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2KI6MB8YKKN6J', iid='B00IGYPALG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NRN3DESUI6QB', iid='B004LLILBY', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3T1X8IA06PAUG', iid='B004LLIKY2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IGG1KSF38KLC', iid='B0091JL3OI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A156EUOGEAFBW3', iid='B00PG40FPU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4NCF2WKGWLB7', iid='B01E4QRAX0', r_ui=2.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NWJ9YF3ZH2I', iid='B0091JL3OI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJLIPT59S5U8Z', iid='B01E4QPDV6', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GJNC744CQ50U', iid='B004WKPVBC', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3DOTSJFB43Y47', iid='B014S1KPKG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KOKN5V93WB8N', iid='B0091JKY0M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OKRXMS4GQUQJ', iid='B0187SVX48', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8DQPYXOQK7Z5', iid='B006PJHP62', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A17BFGYBLTIH91', iid='B01E4QQ6QM', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A49XU5ILUKAZF', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29199TYGFZ0L2', iid='B004RD9ACA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2C31IRJIPJ8W0', iid='B004LLIL5A', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21MBNUP5K3I9U', iid='B00MV9O08G', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMB39IYHYXA1H', iid='B00ADR2XIC', r_ui=2.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22HHM5V40OF1Z', iid='B00F2RZAC4', r_ui=4.0, est=3.6666666666666665, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AWLK5Z18ISHCC', iid='B004LLILG4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25NOGZEPY4P47', iid='B00KV30IHG', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TTZQYLHZR6AY', iid='B004LLILFK', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A24I7BCY99FN5V', iid='B00BXLSUF2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3UUOSIUEOA0G1', iid='B00BXLTUBA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AU9JYZCFSWQ92', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6U9G9KFWCVVK', iid='B0091JKY0M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2L8MJQE0EGVVF', iid='B00BXLW4Q8', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IBGOP0612BIH', iid='B004LLIL2I', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GPS8D0AWIEG8', iid='B00MV9FM9C', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANEQLIWO0FRNA', iid='B00AS527QW', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3I0UVIPLDH7YG', iid='B007V6ETDK', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2G93R3G6P6JBQ', iid='B005DHN6E2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2DNEVDAKO333E', iid='B005DHN6E2', r_ui=2.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1G8OILS25TZND', iid='B00BXLUO1U', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HHJ9J5ZEIB5F', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26X75WVO7ZOLT', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AUCIKHGVF68JU', iid='B00BXLT1UA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GTR56X88D1Z4', iid='B004KNWX76', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1SQ9KX64R57PH', iid='B00H5BNENW', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1J70Y2UCAHWLL', iid='B01FERQPAM', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UK2PK6112TQ', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3RR8VEYVXBNQM', iid='B004Q7CK9M', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXDB0ZQHCF0J4', iid='B015WY178W', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2YD1L68H2K7UN', iid='B00MV9FM9C', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ZX0QPXOSTQNK', iid='B00H5BMH44', r_ui=3.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FM806DTIDP6Y', iid='B0091JKVU0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1SKPJMLLL7PFM', iid='B00G4IV2VI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3EAD4LLY2PH2T', iid='B0062ONJ6U', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XH6Y01UGDIB5', iid='B00P6TN9T4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KO3K5IKNK08P', iid='B004LLILGO', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2DFJ0RTYUMYF4', iid='B0189TCA7E', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WJBYR07RTZ37', iid='B00MV9OQYO', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3S34N2SUZTQVV', iid='B0091JL3OI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A17SWGXLCI2NIQ', iid='B01E4QS95I', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IQRA1L2ALP3W', iid='B0091JL3OI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A13CVBOA3CJ7JW', iid='B01B25LFGY', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BKQIBS7TMRM3', iid='B0091JL3OI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZWGSW2ZSEZ45', iid='B0091JKJ0M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A124NU5CM9CPRI', iid='B00Q5BOSYC', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A280AF9TAIR31C', iid='B005DHN6E2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2D1NTYNQ0TVEE', iid='B01E4QUN0W', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2V1RX3OTQQ9AS', iid='B0091JKVU0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5VL35L6K3F8P', iid='B00JDQJZWG', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A357WBUOUWB6PA', iid='B00BXLT1UA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASHP8S5ECNIDP', iid='B00KV30IHG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A284Q0K2XF47ND', iid='B01E4QPDV6', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1STALQGIG41QY', iid='B004LLILLO', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2C25XZLGVHFXB', iid='B00Q3NFTTA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38UMI11OTZ43L', iid='B00ET5WBU4', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MHPUWWSYCV2K', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2XZR93A46Q8SU', iid='B00MV9LSHC', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AK83BKGXYPCTK', iid='B0145WHXGM', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APB7GIKA92IK9', iid='B00GOLGWVK', r_ui=5.0, est=4.608108108108108, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2BSJKY9V2OLHN', iid='B004KNWXA8', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HCG1S3OP2QFE', iid='B00BXLTZ6K', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2KJR14CE39W50', iid='B00AF0K82U', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3A0WPE0QS1W8T', iid='B00Q5BOYZU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4LIW4MCWX3YC', iid='B0091JKJ0M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHBOZWRCNFAA5', iid='B007V6ETDK', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1PFRFO9FJK1GB', iid='B0066AZGD4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2I91RR6TP1LMM', iid='B004W8D0Y4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7657U6RAV1BX', iid='B006PJHP62', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2S6OCU56NHLTG', iid='B00CHQ7I2S', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2A69D15UOTHRS', iid='B0091JKVU0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQ1QRXUSYRBXT', iid='B014S24DAI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RZA4QS3110LT', iid='B007V6ETDK', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYTWASCPJRB8O', iid='B0091JKY0M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5G8VYDNPJTV', iid='B004KNWWZY', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9SNUPG09SN50', iid='B004KNWX0S', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APLQG8LUQN6H9', iid='B00CHSWG6O', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALT26FJ56C5P5', iid='B00BXLSUF2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2T4LK62MKBVW', iid='B0066AZGD4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VNG9WWC8RNDG', iid='B01CZ54L66', r_ui=3.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1CMVRZLO79SV5', iid='B0091JKY0M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2U7LAXBOCGD8M', iid='B00B2TFKHG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYT62J4K5FMOR', iid='B00MV9GM8W', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3THDISP557Y48', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AUN55PISB7U77', iid='B00CHSWGR8', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2W6OSOAD3PNNB', iid='B00JDQJZWG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1DVHUUBM5Y8MU', iid='B0091JKPDI', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AASSJQHA3PXWU', iid='B00BSXWNTY', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LVRGK723PZ2G', iid='B00P9VEQF0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2V8ZHDQUXDR6K', iid='B0091JL3OI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4D6PX0P598JK', iid='B004LLILGO', r_ui=2.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4UWQJSZFIT7R', iid='B00H5BMH44', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JP2F6TWECW9H', iid='B004LLIKVU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10HN7GWU0R80E', iid='B00CXZPG0O', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A23D4BZSA9OF9T', iid='B014S1KPKG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7LSDE4LTTA28', iid='B00E1QAWXE', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FQYNWFJ7XZJJ', iid='B00UW1CEMY', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMIVH4MZU6HTF', iid='B00BWDHOLW', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3W485Q9WOW40M', iid='B01FERR9FW', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXSVY0U0NVL89', iid='B0091JKJ0M', r_ui=5.0, est=4.801498127340824, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3EJAS1WNY6T4P', iid='B00MV9H6VY', r_ui=5.0, est=4.980030721966205, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2EQ1K6SXQZ3ZY', iid='B00JDQJZWG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A209VYQ9844EO', iid='B00ADR2XIC', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3AUIFCZLV829T', iid='B0078EPB78', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AF0SUVM4IKSTF', iid='B004LLIKY2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KNRDOB2PF8BL', iid='B00H5BM23K', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3W262GVVT2UF4', iid='B00PG8502O', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AZCGA674BX8J2', iid='B004LLILMI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9LCNL860NZNN', iid='B007V6ETXA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AU0KJFY05KHFV', iid='B004RD9ACA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AV4VTGPMXTO2D', iid='B00BWDGYL8', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HXUQA8YSVMPJ', iid='B004LLIKY2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARXOGWPA202TB', iid='B00CHSWJPC', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHBDFM96TCW6C', iid='B00F3ZMTO2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AIFOQLMUHWHYR', iid='B005ESMMWW', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RW9ZEZZY3B9O', iid='B00G4IV2VI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A34IUSPV9JWPV', iid='B005ESMMWW', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1SUUGJOPCOVMR', iid='B0066AZGD4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MKPIP4R1SD8G', iid='B00CXZPG0O', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A33V6C045IYXOM', iid='B004LLILEG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A174J1LSUZNT2Q', iid='B00GRLUECA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AEGP5NUG8YFS0', iid='B00CHQ7I2S', r_ui=5.0, est=4.6923076923076925, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A23CUS3FK31U51', iid='B0091JL3OI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1P60IREY109I0', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19VSAAX9BPKVO', iid='B0066AZGD4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Z9Z7SAA2PEP8', iid='B01FERR9FW', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASMUZ89YE886D', iid='B004LLIL2I', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MZ24X7T6C8S4', iid='B0078EPBHI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A79FDXLXTER0N', iid='B00G4IW690', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AWP0EPY3L73NF', iid='B0091JKVU0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APVHIPJ7T9JFU', iid='B004LLIKVU', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A33TD1448XSY0I', iid='B0145WHNXA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GT7OEZ6SSAVB', iid='B00MXD9CQA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3VN3FXPVOEHGD', iid='B00BXLSZPM', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2YBXNA8U81G4M', iid='B004LLILGO', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LQPY9W3Y3E4I', iid='B0091JKVU0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2I9XC6OFSKSP2', iid='B00H5BN6V2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2XKVB8BRQBL73', iid='B00A4EK69C', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LKIONLFVFQWB', iid='B0066AZGD4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IE4QU9T4LG41', iid='B004LLIKVU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4KLJL61HOX3M', iid='B00DNAGTIQ', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A13S1MIDLMPP2J', iid='B004LLIL4G', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22VUEGAGLNGYI', iid='B01FERQPAM', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2H5ZBAP7QAC9A', iid='B004KNWWMW', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10C7L870CKG2K', iid='B0062ONF64', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1D08OHHRPLSYX', iid='B0066AZGD4', r_ui=3.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LKE0SEQBP6PD', iid='B004LLIL2I', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2AF1E05NYNYEL', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2809PJW3YEG1B', iid='B00GOLGWVK', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YU3BWSGVTCW3', iid='B004LLILPU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A194RZC9SUFSO2', iid='B004LLIL5A', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AFLAE5R04R9MR', iid='B001GXRQW0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3SR8GC0DAX7AA', iid='B00O4I4SAM', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1372XEZIZQSYW', iid='B00CMFWIGA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OZ0E83JGT6H6', iid='B0145WHSDA', r_ui=3.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A74UJ9EEQKAV2', iid='B00G4IV2VI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2KXI31BPRBT4Y', iid='B004LLIKY2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7KH0MK5HX11K', iid='B00BXLT1UA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Q2XLWWWRCCZ6', iid='B004KNWWP4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VPYQLVYT1RZ3', iid='B014S24DAI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAW69DI8OZUMR', iid='B007V6ETDK', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AO3QS0ZU98782', iid='B0091JKJ0M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAX1O6SY6YAM0', iid='B0062ONJ6U', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZDO8D1U2U2RP', iid='B00BXLTJ8O', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JMIUOU2Y09M4', iid='B004LLIKVU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IT5PRVXBDF81', iid='B00BXLW4Q8', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NNEO7QVXRB84', iid='B004LLIKVU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AT3W6WTEUCJ7X', iid='B00GOLH5UC', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39CUOY62C96YH', iid='B00OGQ7SAO', r_ui=3.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANPWPWSXVFY2V', iid='B00P8N3QLY', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HQRA4XLAZFGN', iid='B00PG40QOK', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IEYEA0JZPMLT', iid='B00G4IV2VI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10UKU1ORDAMU0', iid='B00CT774LK', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2B6I0N8RNAQXJ', iid='B005ESMJ02', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10ZH66E5G5AWL', iid='B004LLILF0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5KOQRRHF2ZWT', iid='B00B2TFURQ', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A30JATQWUTVRJ', iid='B004LLILC8', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMN1B3O4YNHE', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AC4248H2XSC1W', iid='B0080IR6BA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADG5BR0NC0G6B', iid='B00A4EK69C', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AS5CMYAWIMSQN', iid='B0066AZGD4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1HO17VQYULTS6', iid='B0066AZGD4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2GZ2BHAJ3XLBQ', iid='B01E4QRAX0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A233I7UD5YB3A9', iid='B00BXLUFQ4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JOF0D2PC35NU', iid='B004Q7CK9M', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AS8NLNQVTNIC', iid='B00CHQ7I2S', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASGE8AF2XXBLA', iid='B004KNWWT0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A33WXUADIUT11U', iid='B00AR51Y5I', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KZ29QB7W981V', iid='B00G4IWEZG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1PN3N4ZN43WA7', iid='B004KNWX6C', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3F899K6UPZXN4', iid='B004LLIKY2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JAXKXBKVPM54', iid='B00JDQJZWG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A20CRLMVES437X', iid='B0091JKY0M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMEEYSKSUZ8EK', iid='B00JDQJZWG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JDDS32TXHO5J', iid='B0091JKJ0M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALSV9F7AJP17N', iid='B00B2TFJEA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4M2DJQDFKT07', iid='B004LLIKVU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMB3SAWHIF3TO', iid='B00BXLVE6Y', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...
#  Prediction(uid='A2GKR6NVOZ4BF6', iid='B00Q5BN5PK', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A30HY1JQL6UZ0A', iid='B004KNWWU4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A247HAJJORHADN', iid='B004LLIKVU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2R9Y2T1JU2YCK', iid='B00KV30IHG', r_ui=5.0, est=3.93859649122807, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A10QNVWR0K993D', iid='B00GOLGWVK', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7DB5ND03LO71', iid='B00A4EK69C', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANNQ6YRW9B8ZN', iid='B00C5UME0M', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A34XLT5Z52URCH', iid='B00Q5BNP5U', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A124O8K09GIZOU', iid='B00F2RZMEA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TGMYBLMUL4VW', iid='B00X6G8J3A', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12MM1WWCRO0MP', iid='B004LLIKY2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5I2FT4XR71E5', iid='B015WY0DOQ', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A28TIBCUPRHJ6F', iid='B0091JKY0M', r_ui=5.0, est=4.927160409244542, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AOW3I5VL7YX0Q', iid='B004LLILO6', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2F3HQR4SPOJ7Y', iid='B00ADR2XIC', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3VYNCIWZ141QT', iid='B007EE5KKK', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AWCRM7KLCSIX4', iid='B0145WHQPA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A57DFC51TEL4T', iid='B005ESMMWW', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AIX0JXPORI5IK', iid='B004KNWWV8', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1TYEEXQF07IIJ', iid='B004LLIKVU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25J3E3HRNF3OA', iid='B00G4IWEZG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4SSQVDCGVJFA', iid='B015RUEWZ6', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WF8BCCLNII43', iid='B00G4IWEZG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15CES4QGFGK2H', iid='B00895H7FO', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADQBKPS50TQ5C', iid='B00JDQJZWG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FWGANPAH9ZVX', iid='B00X6G8J3A', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3EXR007SNEDE9', iid='B00BXLUMGC', r_ui=5.0, est=3.857142857142857, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3575QH7N7YHXB', iid='B00JDQJZWG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3DRWAY8PZW51H', iid='B0091JL3OI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8VEXTW3VZ8SQ', iid='B005ESMMWW', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1N5KQC9AU6SR1', iid='B00JDQKFPC', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A20F1JSI3VFJ68', iid='B01GKZ3SQG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2XD4X62E9G6J', iid='B00FTGTIOE', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8HO1EYBQO2AT', iid='B00CHQ7I2S', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1MFA3JP7N4VY9', iid='B00JDQJZWG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3AF8FLHMHZDLB', iid='B0188LNKEA', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AWF72VAGMNDO8', iid='B01FERR9FW', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VMETQJK5MB08', iid='B01F43RW5S', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AOIXKRX33QSEV', iid='B0091JKY0M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADLYOY08UX80O', iid='B005EISPLE', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AX4U8A521RFM6', iid='B0062ONJRE', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18PEZSY4R33P0', iid='B00KV30IHG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVQTTNP8S8RHK', iid='B00JDQKFPC', r_ui=5.0, est=4.641791044776119, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2333UAOWD6RFP', iid='B00GXSCLI2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AEN9NDM9IQS5C', iid='B009HE86FQ', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASN0V3QNMC296', iid='B004KNWWMW', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1143YIYCFWT1G', iid='B018T7G9XM', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2535Y1WO3XSP3', iid='B001GXRQW0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1G7X4M1MBNIP7', iid='B016PASNX4', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8L72I7758PUQ', iid='B004LLIKY2', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AFDSERJ8Y8UI9', iid='B004LLIL5A', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HY9YJZEIE7DG', iid='B004LLIL5A', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3SL7A65PFOPTX', iid='B004Q7CK9M', r_ui=3.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Z2TG8D64C3T8', iid='B00F2RZAC4', r_ui=5.0, est=3.6666666666666665, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AP0W2ELBPSJ0Q', iid='B00B2TFH3I', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SVBAWZUQASF3', iid='B004RD9ACA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A11GKOQL1JI3AR', iid='B00E1QAXWO', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1W9DHAIHCNNGQ', iid='B0091JL3OI', r_ui=5.0, est=4.797872340425532, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2RXZ1QAYAUXXY', iid='B0062ONJ6U', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A208BL9QQMVX0G', iid='B0091JKVU0', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AK7OYRPVKDYWD', iid='B00H5BMF00', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UZE5EYNW5ONP', iid='B004LLIL2I', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMVCSTVCSPGYW', iid='B017TGZ5ES', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3T5Q3LHALFUBC', iid='B00EEHV8DI', r_ui=2.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A14M8034XXI995', iid='B01E4QPDV6', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XZ4QLPZXPGV6', iid='B00MV9L0PW', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OHH2DEFK9T2F', iid='B00MV9GRNW', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WDTTWXR1THYC', iid='B00BXLVAD6', r_ui=5.0, est=4.787878787878788, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2LN59TG9PA926', iid='B00PG9870U', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AIJPWF370DAJG', iid='B00JDQJZWG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4J6Z1BT1JOU2', iid='B00A4EK69C', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3T5AQNS487T42', iid='B004LLJ6RC', r_ui=1.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AEJ3XIXU1KX2N', iid='B00JDQJZWG', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15AETXMT1WUDV', iid='B00GOLGWVK', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1B10BR5ZS4IGU', iid='B0062ONF64', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19EF8GX42R5VZ', iid='B0066AZGJI', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3A0KWYM1J07TG', iid='B0062ONF64', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AKR86TV3JUAW3', iid='B00PMLD91O', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A102YBR2UBSFL4', iid='B00H5BMH44', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AR6JYAHAJ9P69', iid='B00CHQ7I2S', r_ui=5.0, est=4.6923076923076925, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A34F0ZCX31WY2N', iid='B01E4QQ6QM', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A20D91G27Y7BZY', iid='B00BWDH2O6', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RMBHM5LEN0IG', iid='B0080IR6BA', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HLVDGF61HBJ0', iid='B00B2TF61G', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3SHH112Q6CYLN', iid='B01FERQPAM', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASM7OPQSZALOT', iid='B00BXLTJ8O', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJB7GIR87QMEW', iid='B004Q7CK9M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GQLDJFJB7IST', iid='B004LLILBY', r_ui=4.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PSY8RJSEOD5Q', iid='B01E4QUN0W', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31A784CC8PVGO', iid='B005ESMF5G', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2XY0OI5KU6DJH', iid='B016CICYXO', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABDQUTTBV4G7Z', iid='B006PJI0Y8', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29HUPMT9NDHOA', iid='B00CHQ7I2S', r_ui=5.0, est=4.963649155722327, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A23V5JRAUC9205', iid='B0091JKY0M', r_ui=3.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2V4IPBWH32A0G', iid='B00BXLSGHO', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AEF12MHCWA243', iid='B00A4EK69C', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AL44ZENJK14BE', iid='B005ESMMWW', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2EY9D0T16MIV2', iid='B0091JKY0M', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALCFNF8K9SL1S', iid='B00FTJI60I', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AOO6ZPR3N4HIL', iid='B00H5BMZPU', r_ui=5.0, est=4.6786666666666665, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  ...]

# %%
print("Item-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# Item-based Model : Test Set
# RMSE: 0.9966
# 0.9965569861040184

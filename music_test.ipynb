# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from random import sample
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
import os
from surprise.model_selection import train_test_split

# %%
raw_data = pd.read_csv("Data/Digital_Music.csv", names=['Item', 'User', 'Rating', 'Timestamp'])
data = raw_data.sample(n=30000)
data.drop(['Timestamp'], axis=1,inplace=True)
data = data[['User', 'Item', 'Rating']]

# %%
data
# Out:
#                    User        Item  Rating
# 265919   A3RX4MDMGCGTPG  B0062SI18C     1.0
# 1339922  A2CROG36CT7EXA  B00J5WK5R2     5.0
# 1565922  A1RL8LQCMWU5PE  B01DYSKRSY     5.0
# 1010200  A2CB1SMUZTSKDB  B004K1A34S     4.0
# 478353    AC9OF4L77J1Q5  B00QU1QUU2     4.0
# ...                 ...         ...     ...
# 1021690  A33AJHPX7RT3VJ  B004UGEDFS     5.0
# 28244    A1U7PGH7HQ96D5  B000VWQFQ0     5.0
# 147883    AJBPQ8SRG7ZFN  B0013DBZ3O     5.0
# 1284096  A2J655WCZH4FUD  B00FPCIYJM     5.0
# 738013   A2DXGXRD3CFZEN  B00122L3UG     4.0
#
# [30000 rows x 3 columns]

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(data,reader)

# %%
trainset, testset = train_test_split(data, test_size=0.3,random_state=10)

# %%
algo = KNNWithMeans(k=5, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='A2UN4NLBBF4YRN', iid='B001223BPG', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1J8WFAGQ3G2Z3', iid='B00LQ8AZTQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A319ZFRX1FHWWV', iid='B000W159H6', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LU4LSKJQ4PAG', iid='B00A1X166S', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A215DVSEARE345', iid='B00X4MPOB6', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2IAQJ7YEL1LAT', iid='B00AL9E8NA', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39JJXSXAYOW8G', iid='B00U0VDG1O', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NGFDJ34ISNFO', iid='B00M8JDEFY', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALMRYWZ5QWNAG', iid='B00FQS4LXI', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASBM7P0QY1T7W', iid='B0014LPMLQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ATZXDPD2TSSGE', iid='B000KH1JMQ', r_ui=1.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADOCZFSIDHFDU', iid='B0099G7KDQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HWR9FG5FANYA', iid='B00Q03EEK8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3N9S0678QEHLK', iid='B011MTCCP8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADRP1OAW0ZI2Q', iid='B001I884I8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1I7D6XLCSOYFR', iid='B005LAZE8C', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BF3IMKY7AI6Y', iid='B00GJ9B62M', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AR49E52LJ53UI', iid='B009ZWOMJO', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2OFGQ0EILKLVL', iid='B015L1YAJ4', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1324E4GE3NDF0', iid='B0043CJC3C', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AI8DK1Q99NJGQ', iid='B00TINQKX6', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AA8SWZZ7O4PHQ', iid='B00BFI3VPW', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3EXZJLQLQ8XCS', iid='B001534IZE', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32VFRLZR2DHNF', iid='B00W8HCGE6', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3M1PABXTB57UD', iid='B00UMI95DI', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADN48HOHOF3FX', iid='B00CJAGPQC', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WP9UZI9V6HW9', iid='B003B6MV2U', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2G5U4IRVX9NYC', iid='B00LQ91KQW', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABO2SCO9UCPJQ', iid='B001BIKSFC', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2B57NTNFMWKZJ', iid='B001W2JX6C', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PPKA8HD3N3H', iid='B00AACPTA4', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3P6RWQO6HN508', iid='B005T4QZGK', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IANESN7ZEUA4', iid='B00651GFF2', r_ui=1.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3DKYFTI474CWV', iid='B00DPJ0JYA', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3J9JPVIQX1LPD', iid='B000003885', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2R9MMMP0TIF9P', iid='B0011W40TI', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2S67FYOJ408L0', iid='B00DRMGL5Q', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADYDVC6W286BT', iid='B00949V4IU', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1E9TOC87RYJ4J', iid='B00OVKK6RM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2PXCOZ4UAR8Q9', iid='B00MIB84K2', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1SJZ07X94QWL4', iid='B0053TU1HU', r_ui=1.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2L4OLC319OV5H', iid='B00DVZMQQC', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WLCCFJDKNC3T', iid='B00136Q2AM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXBEQHK9P53UF', iid='B001NB4YLG', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2OG3IBOTQ8BJD', iid='B007VGGLLI', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1PSNWDW7EK416', iid='B00856S2I8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CKE4BYR4U8I', iid='B000VZV70Q', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LLCX4YUAFRJS', iid='B003A94XX8', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2IFH6H8YXDIPM', iid='B0042HWDOS', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1VK743612GYKR', iid='B004LI62FO', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2662YZ7Z4EXZT', iid='7799420340', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IDLG7TTANB8A', iid='B00IYWBHJE', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A47SZ8K5QQIKD', iid='B00DDK65V2', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2AUVO0ZMTL8PW', iid='B0128GGLIS', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJ57CEBUAWM6R', iid='B00N35155S', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29L37RUWXOWS0', iid='B000TED7J8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Y8FXG07Z745E', iid='B008HI6H18', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1O1UW4P6437ZO', iid='B00KRWYYZS', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RMXKC88W8F45', iid='B005SKFOBC', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NS72K6W2HQ55', iid='B00ET4IE2O', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6U2Z11U0PESI', iid='B01FENMQJU', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3L9K0BCRU90IK', iid='B00YI87LPC', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AD342OQX4EFN7', iid='B00136JL8W', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AG8GKY5JZQ2YK', iid='B003W3J1R0', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AO2A9JN4UJ726', iid='B001F2QO7U', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A30XJBEAGP5L4E', iid='B003A98FI2', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RVXB0IQS4UMP', iid='B000XTBGHE', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AK6LQMBSAF5JA', iid='B002M2U86A', r_ui=1.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAJNE7N89ALJ8', iid='B007917TBG', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SXWXZCBLW4M1', iid='B0011ZTXJM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1V7GEEDTGKRVV', iid='B00E82SPIK', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AP37PH75FKIBC', iid='B00066EJFK', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MS0K74OYTVEN', iid='B00168G2M0', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15YTTEFO06YG2', iid='B005M9XKB0', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MOTK3UXLX62N', iid='B00RPWY3LI', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3V576WW1WVL87', iid='B001NBIP52', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALAJL3S09HBS7', iid='B0046E0AR4', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A27JEQQGI9O1RY', iid='B01AU2YATY', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38BHRRYOO2YS8', iid='7799420340', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AY749WRXHPBSR', iid='B00VVT6T22', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OR62KQPTYL7I', iid='B00H4LWZ9C', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYJA6KAR32CO8', iid='B002R4K6AG', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12JGT50ODKBOO', iid='B00123M3CW', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HIL1IWWD2WEA', iid='B0013F4FWK', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BXLNV548OTMQ', iid='B01CP2ZW0S', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5JAQ53JZMOLF', iid='B00LB8OYHU', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PDOSCIONR6VP', iid='B00NI5KKVI', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AEZ8WH06SEW6K', iid='B002WQ0TN8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1PP2153FTFKRB', iid='B001NYVVTQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3K6Y7FKECGEWA', iid='B0018QZ3MU', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A11WKAAI427Q9F', iid='B00NIK65LW', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2AOHAVFYXJ5ZF', iid='B013MBT3WE', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LEOCJPSOKYQT', iid='B001BIKRFI', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A11AQ0OYGK3RV6', iid='B009JDU9IW', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Q887X2EV3MKD', iid='B000T4FWFA', r_ui=2.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25IST5OW71ATW', iid='B00QT8YACG', r_ui=1.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1A2WE6M055O9E', iid='B00I53H5KC', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12CCXCOCWDXNK', iid='B01G9GSK00', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19VAYDZ9AVDYD', iid='B000SZIVVM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A35RXELKEV4WD', iid='B004VW5SO6', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A383LAZQT4W0E6', iid='B004VTTG92', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2L8PN4U9Y8V3R', iid='B00T5HQ4LI', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TO9WBUCW05XH', iid='B00BA5G3M8', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4817UC8FYX29', iid='B000TEHH12', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SE3ZXFAISPBQ', iid='B001ESU57K', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2XUEZUXB59H8', iid='B00GLP4DMO', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25VQORE9NAF4Y', iid='B000W0AJYU', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3OKFV88BRTFQV', iid='B00NB1I73W', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32SD5LD9KNS6Z', iid='B00GBKI2OE', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AET2Y6A8VJVLU', iid='B001VKLKXE', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BQHWJPTB8GTO', iid='B001239DZM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3D9DOEP6JV97E', iid='B00NOI4SGM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QEWNZILV6LKH', iid='B00973AF0G', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OHEAMWM8PKAE', iid='B005D4SN7K', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1EPDZNV9O5ZQ3', iid='B004ZLSBJW', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A17BVYZ6TO2J4S', iid='B005AQQNBY', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A356ROO6PSX1SI', iid='B00HDXIL76', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39LLHT6GSR3G5', iid='B00136JSDA', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Y0XUQXTFXCYL', iid='B002833YVO', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1O26YWT8L3XH3', iid='B002A6PHKK', r_ui=1.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A295I2D0E3RFHB', iid='B0011Z0YA4', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QIIW7KTTCE5N', iid='B00920DUI8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BFMWU6A72IS9', iid='B004IAYQ6W', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MXX9V176BAFM', iid='B001AUJPEQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39P3N31BSQTH0', iid='B005HZ2C04', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IBN28RK6OFSP', iid='B002X2158O', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AK4QSZYH5WOYQ', iid='B00U3WJHCW', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3EEDVYXKWMCGJ', iid='B000W23KD0', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1V3N0LF1QGG0X', iid='B003JFXB36', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AI5SX1JGCAV0L', iid='B00T6H7EO8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3UEBZSEZK5HVU', iid='B00BXGWSYG', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15A0BMCHG3CO8', iid='B00SPF2KT6', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Y5PZH74SZPJA', iid='B00E91Q7Z8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26LQB7ZWJ6P6L', iid='B00BNLH9H2', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A33J22TCOIVUPX', iid='B016IFEE9I', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A14X8N97P4KB4O', iid='B00157PEPS', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1L3KQDN2O63RZ', iid='B00B113E0U', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2F25738C2BNFG', iid='B005HMIAP8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A34A6Y9OL0Z9YR', iid='B000JF21D0', r_ui=1.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Z5NH49GYJVXJ', iid='B011M16RFC', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3NGN0GYQT3C02', iid='B000Q3LE7O', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALJJE5OXUUOTE', iid='B00123K9KK', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RNYF2PTOB82J', iid='B001BZDIDY', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25ZDMO4YCKXUH', iid='B005LYO1XW', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HEMOSLW11WP7', iid='B002R4K6AG', r_ui=2.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3UYYMKLJYINEU', iid='B00D3YOXNK', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1HOTDFY2WMACK', iid='B001P4UC4E', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3E27KVUS37QO8', iid='B00IZQ8QE8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1HU2CQY9QJ9PJ', iid='B016KV7OC4', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PJW5JV4DMWVE', iid='B00138B048', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A35XJ0QG8CY9E', iid='B000LT10X6', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1W1W59NHU6ZV9', iid='B00NERRM7A', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A209ZXT7UYGI85', iid='B000ZJ8NTQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AN2OQO25R328V', iid='B00137Z13U', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1W2ZQE5AZJQT0', iid='B00F2QQEAM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OZ9G3A96UNHA', iid='B002DORFL8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38HMZ7KPUA8OM', iid='B0078VCGOC', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MPMM70ADTUID', iid='B009YUGQJ6', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A36L6W937KDCLA', iid='B0059M5Q7Q', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6AZSE5GYDJK8', iid='B004EXI3IA', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3OI3VXPFU4FWC', iid='B00138I83O', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PL579XZQFZ7E', iid='B00JG505GO', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AV2ZN6VULDWZ6', iid='B004KBTH8G', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A14XNOLCTQNRRA', iid='B0012EFYDQ', r_ui=2.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AK28QBF941S4', iid='B01DDQP5S4', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3M1EKSN23SVOJ', iid='B002UXK0Z0', r_ui=1.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2J7NQATY4U3DV', iid='B00K95JC2S', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3R6BEBJAY5H6L', iid='B0011DNO12', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AKMU8MV4TH01G', iid='B001OFZRYE', r_ui=1.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FAL1A8C0EIVA', iid='B00G0DL93S', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2KO27AST0HU3C', iid='B00D06WMZ2', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A24JWNCNMC0OZX', iid='B00LSHG2L0', r_ui=1.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3K2H4VS98DWWI', iid='B009Y4JIHY', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A36AR86D4UG2RR', iid='B001HEZIQE', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31TMI9MNTIDN3', iid='B005938WX0', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18GT7UOA49PE0', iid='B0011Z8OFG', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LMKZXTPYQZ5F', iid='B009U4GRJA', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A11737S87U133X', iid='B01C6FMYLY', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MMQ4FAPRN6VQ', iid='B001F84SU4', r_ui=2.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KA0MWGSUT4RA', iid='B00CELDMBW', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WJB9Q715U1WL', iid='B00J9251T0', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JCIC2MHMKU21', iid='B0068ZZ7SQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31BTPHCQCE8WB', iid='B001NG5XZM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UG89ZNLDS4V9', iid='B001IXQU3O', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SM2X8V6W0VKT', iid='B00M8JCW3E', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2O6EDPMFV41N8', iid='B00J6OBDO8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HVI11OF4HPZC', iid='B00N9TSA2O', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YJQ5UBT6BE6O', iid='B00BU2VHOA', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2A2I9F3QDPB80', iid='B00137XVP0', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2E3930TNRBM5C', iid='B001B6S21G', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYUHV5DPN5TEZ', iid='B0092MKTWQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3VWKC1YVCJC4V', iid='B00THFC2QO', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15OXG4V7IK2D9', iid='B0009X0COC', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GNB3K5YK72YA', iid='B00C0NFOSI', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FLCUSG2X5ZXV', iid='B001DQF7QM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2H3CA3LECEPKW', iid='B000VWW6CM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACSEI53U1S1FB', iid='B0181O9DEK', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ZQU4YR2CHB7O', iid='B0076T0PTY', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3RRD7KZ42T69T', iid='B000BKR9J4', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A53S8VVT1IHA7', iid='B0189YO1GC', r_ui=2.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJJHRVFG5HSSS', iid='B0076QWBJY', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZIMWTTZEQKSB', iid='B011MTCCP8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VHIIYH1TWQH2', iid='B0008377FA', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A24V4IZ52HE3RW', iid='B018ZGLX1A', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A270GC5ZMM4NJ7', iid='B00SP0Z7PK', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22KMCKYE5KQ2X', iid='B00H7L76W0', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQDQA07JPFM17', iid='B00O2RCFDC', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXRN6W4B0EDIA', iid='B001NZN666', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3C6GI0GRQ6O2L', iid='B000W0CQ78', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Y4H7CDRU13V4', iid='B017UMG8TW', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8Z2DXZPY2J3P', iid='B00GPLAWZQ', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3DPY3XDY9I9JB', iid='B00A7ZXBE0', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2N724KH4I65XB', iid='B002QWFG3Q', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3CTZZ50BOYN3Q', iid='B000MK50C6', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IWYKRSJH066K', iid='B00124BPBG', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AF8VKB9DBBA3Z', iid='B002OLV3OK', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XRN2NWGONJD1', iid='B005ZZ9ERU', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHG7OKVJWQCUF', iid='B00CZF8B68', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YN6TCFN2SU69', iid='B00C10MLDQ', r_ui=2.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJMEY7T77KNJB', iid='B00586Z5Q0', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FW5PRV36GX95', iid='B018M9N8KE', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2I80IM13K6VSO', iid='B005AAEWSG', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ZL9I2Q7EXPVQ', iid='B00QVU2P4C', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHADRK7P7TZWD', iid='B009VLX8FS', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGF9I7KGFHYFD', iid='B006N51LE0', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AKFR52GYNSBHL', iid='B016RWVUIA', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GC7GB3J0N0U9', iid='B0000566FE', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A11MJ4MR6BMP6I', iid='B00O5284S4', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19IBZGD11Q0XL', iid='B00CMIUOPE', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APSJ9V89LUGKN', iid='B000TH94NI', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HP9Q13DIG0HA', iid='B007UA38HK', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1EJ31MA35TDN1', iid='B00KU63BS2', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HZ9SYM75CT19', iid='B01553ZB9G', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IG4T88APXACM', iid='B000QA59TQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARUV41JBWOR6S', iid='B000TDBGRY', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A28Q80TIWAIYH0', iid='B00A7ZXMP8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9HY4G6FVWAGK', iid='B00M25YUFC', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AORHJSYV21KMR', iid='B00137QS28', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2GL5MWHUXL5X6', iid='B019G76NT4', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AUC6Z0VVMS759', iid='B01CTIX99E', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A173IDJ4YX4VYX', iid='B002C16UIQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3DMBP3PG1PIU', iid='B00137URHA', r_ui=4.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AMFA4MKQ0JXXC', iid='B0012F8U40', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A299HWTL5VWO6Y', iid='B00U2OSYRU', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TEEUFV5GYDYF', iid='B007DLVH7Y', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NME3U9CDOEZJ', iid='B00FAJDXLY', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJLQ6AY122MQY', iid='B00I5VC45K', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A249JF6C6FP12I', iid='B015L1Z5RU', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21Q8TYJO50OCU', iid='B0055HVX7W', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2X8IQT82H3150', iid='B00M7LZ640', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A111JLPTFWM1ZX', iid='B00B0NDF26', r_ui=1.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FR68QH6Z4YZM', iid='B00122E59W', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A35RGECZ9UK7KU', iid='B000V9GADG', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3NAILUDDVIX65', iid='B0010W4LN4', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A34150BOAQFJVA', iid='B00AO7CE6C', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABU7ZOQR6IU5B', iid='B00PXNHXPY', r_ui=1.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LHAXBM5GBJS2', iid='B001GH1ZQE', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37OV07ANL5IWL', iid='B00138ICYE', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2EEYPJXZ1JDCB', iid='B0013CYC2G', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1G2RADP734YNL', iid='B00070EK54', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LU79BYMWZEW9', iid='B000056EW1', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Z29OSISZ2SY3', iid='B002XSWNES', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A16IGPQFNQNJ8X', iid='B00ISAEB5E', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVSBZ1AH7OM0P', iid='B005FNUU52', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KP3SJGITFT0Z', iid='B00A14V1GC', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVC9DLJJ358V2', iid='B00137ILPU', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A84HQ85M6KE1Z', iid='B000W1QXT4', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJ33JM8L0QKWC', iid='B005NCB8F6', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25O3B23LATCKB', iid='B0011Z4Y6E', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMKD71WMNVZXP', iid='B001KW5MF0', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3EZPTG25WPN6U', iid='B0065GFZLC', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A33V38CXCJ1Y3W', iid='B000QR72EO', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RTBHW4H6OLE0', iid='B00SDAOYA6', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ATYEE1MHPPOJG', iid='B0080NNI30', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A16A9J9WFHCTUC', iid='B00JLTZT8Y', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CKW817LDC4MI', iid='B002774ON8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AM5E53FMI5AKK', iid='B01F2O06YS', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AEDKQYNCC8X2S', iid='B0135P6PZA', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26YREV8F03L2Q', iid='B00Y1GNS4Y', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2E4344NE4OS3D', iid='B0162RFM84', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2DVW33US3OCAG', iid='B000THK4N2', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3VO5G13M7IZ2V', iid='B009XHH79I', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22TX8DWGBTM9Q', iid='B00KAAFEOM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3H6X2WJSWZNIO', iid='B01GAKJG30', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2N44GQGOMHRKU', iid='B00HSGJ45Q', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TPYPZJIHSEQ1', iid='B009YZU3OU', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A34LK21INEH364', iid='B00KYVZ0D2', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AIOC8B798MK2F', iid='B006H1ME5A', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6A9FAOSK9CW6', iid='B01BI8H870', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15WKYFCF7EII9', iid='B007EENJT4', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KWOOPZYFHLLK', iid='B00D6W15US', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12752HRLFJZKW', iid='B01979VYZO', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3CX6GKBD84X16', iid='B008WHTXT2', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AG62C9D1UOKZL', iid='B0016Q8C9S', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1H9EDLWJT0QRF', iid='B00123BCKQ', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A229SB28KBKUUC', iid='B00VAM4DTG', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5Z0CAGN8AML2', iid='B0099G7KDQ', r_ui=2.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...
#  Prediction(uid='A1I635R7B9WAAN', iid='B002774NIY', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AF96FBA9SRL60', iid='B01EBJI0W0', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5G52PQUFVMVX', iid='B000V8GZC8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A244I60LIB5WGL', iid='B000THG29W', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26HOZ5R77QMLJ', iid='B015X23QBY', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NP5ONODHBGDU', iid='B000TGRYSG', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3R40BHUGLQU9Y', iid='B002KV4O7W', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXSHUZ5PVL8QW', iid='B00330UFQS', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2EKA5NQ7DW07Z', iid='B00136LOVY', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A300G4KPPMZF2A', iid='B0092MKTWQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A13ZWRQOSK0HO1', iid='B014CJFN92', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2V1C6OGM0N6UZ', iid='B013RKU158', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15DDTB5Z4755R', iid='B005I0BR7C', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A278LRP3IIXUC4', iid='B0010DIGUM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXJL3H78TMEU6', iid='B00QTCU1CK', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2U2HF4SACK0EP', iid='B00CZWWSJC', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3DW4SXQ9HCUTC', iid='B00TU1DA0M', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3ELRDDMEJCZRM', iid='B005I244SO', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8LX3L2DA0WH', iid='B001J2WNEO', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2YABQ88PPCUCV', iid='B0020VQXYO', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5GVNDNHZ0NFS', iid='B005T18DOK', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MC7FS3ZL8CFY', iid='B003TVQ8LC', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4R1U11MII9ST', iid='B00161CE1U', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A20HAJ774TT2S5', iid='B00122MCOC', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WD2OZDVFJS3Q', iid='B004XZ6UMK', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3P150FNM1I0P2', iid='B001N4LXJE', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AKGF27HN0OF19', iid='B011DBV2NI', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMXUSQHMT3SYB', iid='B000TE3752', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JWLM7SARHRS4', iid='B001OB2FVQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A129PHREKU2FB4', iid='B001J6QZA8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHH6G75K7GX7X', iid='B002Q61WBC', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7C0ZNLBEBI5R', iid='B00G7HG10I', r_ui=2.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZI36JBGA8AKH', iid='B000W11JU2', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALKUOG5V6NXAD', iid='B00136PNPM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3ID3O2ZH5XZWB', iid='B005GLRTPM', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CUFTGZXXSJXV', iid='B00137OHD0', r_ui=3.0, est=3.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A59EI9ZZ5PIM', iid='B00BYKXBNS', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A366S12KCZ280V', iid='B00KVOEQDW', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3SKLXMMXO5TK5', iid='B006USJA4S', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Y06SSE7JS85K', iid='B004BRTTKU', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3L9OU1DS8BGVR', iid='B0012F6LL4', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AST1ODFV4R8RT', iid='B0092GRY0W', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANMO346IWPGYZ', iid='B00A8Z6XD0', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2AIXGPS8ZI5W', iid='B002TA4MSU', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HGQUDA8PXV1Q', iid='B0050MC0I8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2QEXUA9Y9AT87', iid='B000QQDSSY', r_ui=2.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25A2JAIIC21WS', iid='B0010W4LN4', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6HSIFJZXZLXO', iid='B00122UNOS', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1SKXIMVHG8SZC', iid='B00136NSPY', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25HQGY2HUXJ1K', iid='B00136NX2W', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19X5QBKUBD5GO', iid='B0013K4OXA', r_ui=2.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AI4KNWTC4LYG', iid='B000THKG26', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1D46NVAB9E54D', iid='B00OIK3SWA', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQWGPJVOVS9FC', iid='B0036G736E', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQY971MQ8S0TT', iid='B00X75U3SY', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1EWFF4ZU2IZC5', iid='B00137GA6M', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AFOI1O6ZX41OK', iid='B000YN1VPQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A63UI9PO2YA1J', iid='B000W06VFQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1DOYTTI83IT0J', iid='B004J96GVA', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BG1N1J4R84GM', iid='B001IT2G04', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10S8O3RYORIO9', iid='B000VZJS20', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1VHDD89TY4FMN', iid='B01BBXJ1J0', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1TQN8PND2YEH3', iid='B00KG2N52M', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2I2A7N3OCPNW4', iid='B00A992GJU', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AKYCQ9VPCRDJ6', iid='B007U73KCQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2PJC0BL2P5Z00', iid='B00YIB0OFS', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VQHCP7OSQMMA', iid='B0023RW4HU', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31J4UA88RLTOX', iid='B00136LOVY', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TXKUC8SN53H7', iid='B001BW1TRE', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CCJVCRYMVH2Q', iid='B00KONDS5W', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GNKC6BZYMZDE', iid='B008JTP85Q', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVDZCUH1FMI7A', iid='B000WLIN4M', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1MSSQG4LO1DK', iid='B00540MW20', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2GUVBQW56F161', iid='B01FEH12AA', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2DBZMU0WQM817', iid='B001FMF1DI', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29ZFRD33A1RU1', iid='B0014NU250', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32M0IK94FKJL6', iid='B0013G0PG4', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MHC5CND4TWLX', iid='B00108H806', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BZG0B6LPUDHP', iid='B0000CFWZA', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BBQC6RHR1W6S', iid='B003OAWAEC', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1PG1VA2R49ISJ', iid='B00G04I732', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2IWNV8MJ1X0IW', iid='B00TJ6S4RW', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KDYV3CNKEWFG', iid='B0011Z7JFW', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3J4RCD44YQQKU', iid='B00CUWLQDQ', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BE8VILNIGXL7', iid='B000SHLU90', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A30A2OT1RSESWL', iid='B00136JC4U', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALKBJ6PWZZMCI', iid='B017OOZHXO', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADOCP6DX36FP8', iid='B00QR7R698', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4Z550CTWK609', iid='B000V62YY8', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22X871BAINL93', iid='B000SZEW7E', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJXY5PAB17I9U', iid='B00123F8Y2', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3H3FL80B82VCJ', iid='B00L63GQHG', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1I57Q29TFTMN7', iid='B000W29WVO', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANB4YGNX8LCLF', iid='B000W1X11M', r_ui=4.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YY11SOUO5EA0', iid='B00JE9Q59S', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A384XR2WG8UEJO', iid='B000TE1FA6', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A14DSDBH2ILW3J', iid='B003YW8AR6', r_ui=1.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2C0WALXYWHRTB', iid='B0014J72NO', r_ui=3.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VG705ITRYIJ7', iid='B000J0OKWK', r_ui=5.0, est=4.656380952380952, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  ...]

# %%
print("Item-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# Item-based Model : Test Set
# RMSE: 0.8668
# 0.8667984465794875

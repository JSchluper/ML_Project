# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from random import sample
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
import os
from surprise.model_selection import train_test_split

# %%
raw_data = pd.read_csv("Data/Digital_Music.csv", names=['Item', 'User', 'Rating', 'Timestamp'])
data = raw_data.sample(n=30000)
data.drop(['Timestamp'], axis=1,inplace=True)
data = data[['User', 'Item', 'Rating']]

# %%
data
# Out:
#                    User        Item  Rating
# 1010016  A1S51UW0CQDL20  B004JYTZWW     5.0
# 832500    APB1VAE7P1CAV  B001A7ZCVO     4.0
# 1337787  A18G7OQCDEU64C  B001DX97GQ     5.0
# 1010748   A2Y80QS3611TV  B001TCDSG6     5.0
# 1140072   AQV0NWB0Z5OVS  B008VPX6Q6     4.0
# ...                 ...         ...     ...
# 1579783  A1LX310NWOA6EK  B01GRGDNVS     5.0
# 816518    AIJBY6I15UKY5  B00160Y612     5.0
# 393671   A10EUNHCOZQUWH  B00GLP4CRK     5.0
# 1271246  A1W4RUMGNCWB7U  B00EZ7ESXE     5.0
# 1305967  A34GJLUXNOJYO1  B000WLJD7I     5.0
#
# [30000 rows x 3 columns]

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(data,reader)

# %%
trainset, testset = train_test_split(data, test_size=0.3,random_state=10)

# %%
algo = KNNWithMeans(k=6, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='A206GVIIE1S8TU', iid='B01EZLHRG4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2L9J2RR03LKQX', iid='B002T9ZE3S', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AIMKISJW60M4U', iid='B0013AVN9I', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAQRDI2Y7LX47', iid='B00M8JD49K', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3E9MAGSDRWU97', iid='B00O51WB2A', r_ui=2.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2A0XZF9LYIK2C', iid='B000S5111E', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PPQ57BCVI7D5', iid='B000JF21D0', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANNLHHD0SDS0Q', iid='B000QHGS30', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2IOVZOGGONNX1', iid='B018HTEOL6', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VRTNFDK8V0HL', iid='B01DXPW5F6', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FKBUETDKFMEX', iid='B001O04JFC', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LD4ZAL2VXN18', iid='B00OVXHH6C', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AOHXTJH2DE5K7', iid='B0049Z47HO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IY5ZKHG0WCVP', iid='B00P10HBJC', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SGQBUYZDDBXE', iid='B001E4ZDTO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4S7EMVAX7HZL', iid='B00H2EBJSE', r_ui=3.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2AGIBHD4Q85A3', iid='B00DYATQWG', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ACSVMLXE13EM', iid='B01AOIRMIK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TTHN1UMO82VY', iid='B001380QCA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GOG98TZGHM2Y', iid='B00334XZP2', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQ9TO208G1QVE', iid='B001KQK6CU', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VOVZMI83Y7L6', iid='B00J84EQGI', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2D8WG9OR8ABSK', iid='B0045L0LPE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WJT9VXP1RXS', iid='B00137GCGK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38EUOO7IPV81P', iid='B007DD4JBI', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GEGJKDSJ8VB2', iid='B000WLO8UU', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AU58WZX4PFHFG', iid='B00JRZOHZI', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2R8180EITLCCN', iid='B005A541CS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A35RXELKEV4WD', iid='B0047B4NEM', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FP7QE393QLKZ', iid='B000GPG6KM', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SUIH353LP5I6', iid='B013FILLKQ', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AYS6P5PD1OC0A', iid='B000BKIWUO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SED45YIM0BES', iid='B00JWO0KQO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2K1CHNNBHOYSL', iid='B00IXBOP8G', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TT063Q694PYX', iid='B017SG6RS2', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2E71UQ5DHQXOX', iid='B005F83A2C', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A34BT7IZI5VM3G', iid='B00PKXD0G8', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ER46SZHFPI5N', iid='B000TDYT4G', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MNQJ8UUY6Y61', iid='B00CI7BGFQ', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALTJ6UILAEDBB', iid='B003XIZTT8', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ALY2L39YO604', iid='B000TEMT7Y', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TSG4BJFX53OJ', iid='B00137T5KU', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A33M3F9JHY6Y7I', iid='B0009OOZDK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A14YTPQDH3PAZU', iid='B00123272S', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BRSN9NJDII8K', iid='B001BHXGSY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2X6P8TV9T1NVJ', iid='B003HI7KAK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FSA1F6ZOTHPC', iid='B00136JH0Y', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AZBAPY82Q0KUI', iid='B018YMGWU2', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37Y0EVY1CE471', iid='B00137Z748', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2V98ZLO9Z58OT', iid='B000V6PXPA', r_ui=5.0, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AEAXPXOLE87B6', iid='B002U08UQO', r_ui=3.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18QKNZ9W6NY3N', iid='B00NF2S8WC', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39CYQVU20TZ1E', iid='B00124DTBK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1PI24LYIISO3Z', iid='B001D7JTMO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38O6408OOWPYM', iid='B00137X5Q0', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CCCCDT2DX7CT', iid='B005AJ8A94', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A33Q4FMY9O43G8', iid='B00F03230W', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AZFQLN535W4VT', iid='B0012251CW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VJ5ALN1BIV3B', iid='B00B5Q7M90', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2M9A56OIDDYXA', iid='B0013F0LD2', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AH8JM42V0J5L4', iid='B001BADY3S', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1EPUILE19U8EL', iid='B00UULECSK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2U3A97M36WVL9', iid='B0094B8UBC', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABMLSDLNTWLND', iid='B005EPJNTU', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22Y8FLR14R2ON', iid='B00EUM5T5K', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AO40HH7G2N6LI', iid='B00XDD0LHI', r_ui=1.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A75WPRUXG0AHJ', iid='B00KYVVS92', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3OCP1GTITSTA1', iid='B00330WKMA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3SEX0WIETA193', iid='B001K5AAJA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3D3VHVA8U8D3D', iid='B000V68YTW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2D20R0ERIF16R', iid='B006CCCWN8', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A389YXOJ6XPWZT', iid='B00CHSRVIM', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3SKPJ1KSDWSB3', iid='B000V6ADNW', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2UM55S29IC4JE', iid='B004VLGQSY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TAVO7T08KM1L', iid='B0012EFYJ0', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IKJEO1EE0BLX', iid='B00138I4Z6', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BZ0WZTVOS917', iid='B0087XS8NS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABT1UH8XWMXZ0', iid='B00G5T9H0O', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADLVT8R7CK0F1', iid='B00976MN7G', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2EFGUAPU99U3K', iid='B005SSZM6G', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3K9H2ZQ79OAUB', iid='B001TZDF9S', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JKXG51RRDHOF', iid='B005OCY5UK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1DHABZP9KK1W0', iid='B001BHXGN4', r_ui=3.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RKS0O04U3GY3', iid='B009BIAMZ0', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJW9IP72V7EPQ', iid='B00F1DIZ3U', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2E7VJ7RLGQYUR', iid='B00ELP24YK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21Q6JKL4KI98', iid='B0049SEVDQ', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KH4G6HQZJKH8', iid='B007Y18L1I', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2468MT5JQW6KC', iid='B00B0NU0WO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2X28T9D25WDMC', iid='B000V66LEC', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3P6718H05PRGI', iid='B004B72NSA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1264Q1DKK4BZ7', iid='B009BI9MMO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7XCCPDVX2GMM', iid='B00588URO8', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XTTZX842DR3P', iid='B00123FSWE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WPFIZ8P3O86V', iid='B00122MSXW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7KQNB6UXNWIL', iid='B00137IKRE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RKC3FYAMA949', iid='B00INFTFE6', r_ui=1.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3G2QLJ1S595DB', iid='B000VKGA1C', r_ui=1.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CN2ZZ0OHBWJY', iid='B004XNDZQQ', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AFZM7SEUYRCPH', iid='B000EOTCFQ', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WESW1MWVF247', iid='B00138DB40', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AG3FWH1JIEWQ3', iid='B000W174QU', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3AY0ARVR39DZV', iid='B013YXZNWY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39NXZYVU8XPKB', iid='B00UDDW016', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TBNZF6JVH3QJ', iid='B00G725PDW', r_ui=3.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2906HV22ZGS7X', iid='B0067D7NLS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2YSDJ3236SCJZ', iid='B000MM8QBQ', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IHYM2GY22784', iid='B001ED8X6U', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AU34FGACZX4SF', iid='B00JLJ185C', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19AVQ1O55JHPT', iid='B00K0F4PQU', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3UF5MD2NJDJQA', iid='B01DOO46BM', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2G87562JKKZO9', iid='B00E91QBPY', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9P4Q7KX35RS2', iid='B001EE8Q3O', r_ui=3.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3VBKKMIS9B6HR', iid='B00IONQONW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SN6TAZXAQQ3X', iid='B000S9CBSC', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1VC9IF9OU55QP', iid='B01AZG6E80', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QQLS6WRD58UZ', iid='B00462R9YS', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAYRJZ93V0GT2', iid='B003IOZP2I', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GNVD0ONRB2B2', iid='B01G33LMVS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADRO6G1D3RJCG', iid='B00BQWEJ1C', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NCF6A8QTPF16', iid='B00H5XFV4K', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JKEGEZO34BLG', iid='B000YUGLF4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQ0PZ63QBZPG3', iid='B003E39KCY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KPQG4U3SZO99', iid='B00OXE3CMC', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1HWD18QGGY9BM', iid='B003JPJVC6', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1O6NHDJEJK5Q7', iid='B000QPL8QE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RS0BLC2ZGBXT', iid='B0072R5K6S', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10QOIXBXK5WW8', iid='B00CKQ2TP6', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHTCXQM4457YA', iid='B00137T3PW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JM722REC0ALQ', iid='B007AEJHOE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGHSOVVWRNRI0', iid='B00O8ZAW3S', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2DARHKCF0ZT4O', iid='B000V6NWS0', r_ui=3.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AU6XM468S2VSV', iid='B00IDXXIWS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A11JTCOUI4KA00', iid='B00E4QI300', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2MVG32YP6YIYM', iid='B004Z4ZN4A', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AW7PT55M6U5F0', iid='B00HVOUQ5C', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3F80BH2HRE78J', iid='B00CXS5EQ2', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2S4YZWQ8VJPXN', iid='B0012KSQ4E', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6IBVPUFANIGX', iid='B006BZBROQ', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A34L5AZYT984YX', iid='B000V66SGS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3POU7UGOUV002', iid='B004O4J4VE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1VTEL32W5FM13', iid='B00122C18E', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25847PDOZPU53', iid='B014M3E2I6', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2E96Y4SJX732L', iid='B003EU0EBI', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZRH2QY2QJRTE', iid='B001OWF1CU', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SNIT0U1AB5JN', iid='B000P9BWIK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A16WBKWHL1PN4A', iid='B01AB8H3XW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACI7J2C6GJFTA', iid='B0012460GG', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A17O3OF67ZHAN2', iid='B0087UXQSS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2R62SNZT4PGJS', iid='B00137KS2O', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1R4UGSXQLL3ZM', iid='B011ECYQC0', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IAYE5X4Q6Z56', iid='B0013K0RZ4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A35MW8Z6H1XMBY', iid='B0050OKI8U', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WIWSD0Y7RMYX', iid='B00J62YPZ4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QAEWAO9DN7F8', iid='B0043X2OGS', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31JK6OLH11DES', iid='B00LVS3QJM', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3D2W6ZWK4A7L0', iid='B00NGJDB7Q', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9SQ6K5DVQEFL', iid='B005CCZQG4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYTS0TU23LDAJ', iid='B00XY7SGXY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A35CCGJDNXUDY9', iid='B00WVHUPP0', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A375SY4TGJ3VAR', iid='B00CNVMK52', r_ui=2.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YOCX8KC9W0TF', iid='B0014C2QMI', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1E3E4CPYZWMUQ', iid='B0000563O9', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GL14KN88T558', iid='B000QWHBK4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3DQ5GOLMGJSCK', iid='B001NZ1BW2', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJ8M6GVFGIRLS', iid='B00137IO6Q', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A24ISDBKJQZJV7', iid='B00J62YPZ4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2B3Y31NASDGON', iid='B0057P5T9A', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RRDGWVSUGOGM', iid='B00I0QPDBW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACLOO4WU0WY6U', iid='B0076DFMS4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Z71CEFFGG4SI', iid='B0018GCSKU', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A100684PI9VM5V', iid='B00TTPCAO6', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3UB5Z0EMOTK20', iid='B005KXWT6A', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NVEU61U7405A', iid='B0057OY9WO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2H51CAF89J1H9', iid='B00FASGWJ0', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3S0JLDF4SR9FI', iid='B004BRTTVO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABDR6IJ93HFIO', iid='B00702O03E', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A32Y73F4L84PV7', iid='B00JLJ185C', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ND2SPIBP3W6X', iid='B00SUWFODI', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A247YCXPOEUUHF', iid='B00123HNJA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LDP84AHSOD3X', iid='B00UKJORP0', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3I36MXIPBMZX5', iid='B00123NW40', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VHS7BU4OHOWZ', iid='B0032MWXG2', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A24JOAB23REBY8', iid='B00121WK3Q', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1MX7284FFEHY1', iid='B00D9D4XD0', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3SUC4AT5CSJNH', iid='B000TD76LE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31Q4LPI43T2UO', iid='B00K6RV3TY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AO7POPFE6F85Y', iid='B00104M9PY', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KBK0L0FM72VZ', iid='B013CKV75G', r_ui=1.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RUX68VI24F9', iid='B00TQTRGYO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RAGEUA4JWDP9', iid='B00XHS3EUK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AN9PM7Q7ZMZWH', iid='B001GKTH0C', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BAXN0CD2U0Z5', iid='B00NQDO7W0', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JR704FL9YJ26', iid='B0019D82DY', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AD3J79WH30USD', iid='B00137Z79I', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IS0I7OD15HAB', iid='B000VWS1XA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALAUJAJ0RG20I', iid='B01EK8WDJS', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JS5XK75D1SOY', iid='B0029QELEY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A14UHQFQCLGPAD', iid='B0012461XS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1MLUG8INLOBKW', iid='B01188BTD4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NI2Z40OTQVA0', iid='B002R4OBVG', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3EMUVN1S6QORC', iid='B00122DCAK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2W4GP1AJ7GTEN', iid='B00138JRTS', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JXX1BAZ19Y4X', iid='B0029S2CQG', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2DY4N1HW4LM5', iid='B01BIR6HVO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARHFLE6YSWNW7', iid='B0048W8WLA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A13PFJ6P7OJ4OW', iid='B008ILLPRU', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GNAKY0CMC54B', iid='B001BIQPAY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18CLCOVT4YVJK', iid='B00SYTTBMC', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1EAGW7PM2B54X', iid='B000TECLCW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1P0IUETYCP4DP', iid='B00AIN9MQ2', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5WDGX4L8NATQ', iid='B013MC1VAK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BX3M36X9WV9X', iid='B0028IK51Q', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ZZK1OVTQ1DBD', iid='B000MSF2YE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Q0BU32CVOLRA', iid='B01F5LEG1W', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJDOTLSUGA40N', iid='B00QVZ1VXI', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4F027AV3Y8L2', iid='B00NW1UL76', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37UHDFN6YV0Z9', iid='B011JBXK3C', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QK99TDVMSHLS', iid='B0135P6PZA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABO8BD2C0ENYY', iid='B00136RMD8', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2DUP4ZRI933N1', iid='B0011Z8NAM', r_ui=3.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3VHE7Z8Z17SNZ', iid='B00CVO61CY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GKI8QNWDFAZ8', iid='B00JLJ185C', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TGBP2WU5W7NS', iid='B00XIX7PMC', r_ui=3.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2M3TT19H660NL', iid='B00GCMQ6T4', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1D25KPP42E6MY', iid='B000LD9ONK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25SCWM075UPXI', iid='B001FEAEEC', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1U7ZMT3TRCGUD', iid='B000W0VJMQ', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YM5HIKMGW7H6', iid='B00123K43M', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2KFYEV2YSZ2PK', iid='B000VZYZQE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AM63TZR2RLM2K', iid='B005WRW5O0', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HG9CYJ1HRUXF', iid='B00FKGZ0CC', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26JA346ZBU0KF', iid='B00WAKBRMS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1E8OXKBTTUUS4', iid='B00137Y3R0', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1TPR66C6ANNXV', iid='B012CAS28M', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3LKEIAE2KEX2M', iid='B00Q5TMI7S', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IBAI8WXBKL3W', iid='B002GJI8WA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RFDCZKD92P2L', iid='B00LIQLELO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARC3O1TO78VH0', iid='B00YE9RD4E', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AT426LFS9TSJI', iid='B000VWUJJO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Z10EOPEM2TF5', iid='B00N3B410I', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FHFL4EAPNHT8', iid='B00N321600', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2EDM4Y52M5NP2', iid='B00IFHB0IQ', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BMF5NDNE5Y7Q', iid='B001IAOQOW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MQ4NB8JKWT5U', iid='B00EH6PXQO', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BCWXXHYRGQW2', iid='B0092ESZ3O', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A69P42FJTII8S', iid='B01FTCOKF4', r_ui=3.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9MC2C2AC45B2', iid='B005MVLI8A', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31UL3LX0DGGI0', iid='B00HCR4ONS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18D3YC9NTGU1W', iid='B009G3S0F4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2M3CD8QGDWRYT', iid='B00KX5IBYY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38QDT9RNP7T81', iid='B0100R1X4O', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AZXJ1OB4CVUWT', iid='B00QXY17RC', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2URXL8OWUWLEU', iid='B00HCT1F7Y', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A11F23GZKIST3U', iid='B0108UP0EC', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39W1J0I0MRIDB', iid='B005HAOCT8', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A245D3WCRX9VNP', iid='B00UBC5NUO', r_ui=2.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31RKOWXBYYI7S', iid='B00122R8LY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WV2XQMQSPEC0', iid='B00136NQKG', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AKJYA3882IQE8', iid='B000TE9T2C', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AP3EZTH6I5KOJ', iid='B000TETN96', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FU1ADQE8M29V', iid='B001RWY682', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3NMYFDRXM3UDW', iid='B002LD5UFE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1K6GXTP6FAYC4', iid='B001W4LE94', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AIPACSTY7WV6U', iid='B002N8SIQK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29ESKHE8L15JS', iid='B000PHA2XS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RMEX1XH4E8WP', iid='B016OA5EF0', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UQHC1L2LNYR8', iid='B00CG3HDKY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAJK2542MNB9L', iid='B00BHL4KP2', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38TG2YGTDWTLO', iid='B004ZI8H4E', r_ui=3.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AITWIN9BE0L21', iid='B00137MJVW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A143S7EWCACCBU', iid='B00NJMNLRK', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PNEFCFPRBCOT', iid='B009ANAAD0', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3U3PA6J2XOVFK', iid='B004X2NFB2', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OKPC1K12YZEP', iid='B0013F2AIQ', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALAN202POEYAL', iid='B004DH2M2A', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OTNP4FR6YUK', iid='B0092MKTL2', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1J2T32T8M92PE', iid='B00I3GJ298', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A35CI9B21VCKP4', iid='B000VT08VG', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FL3GLDABYZ9', iid='B00MZ4X38U', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6EWHQ1UGQ8IV', iid='B009Y6WTBE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1CBINO5K0KPT8', iid='B002UTR0IO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A203YKA8GQHFMW', iid='B01H683UG4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AFSBKKDFLZZX5', iid='B014I3M54S', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JBSF5ZLAGYON', iid='B0055DNHVG', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2R5N52M5NABR5', iid='B006MMU3ZW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XHO5BELCIYW', iid='B005CICO5O', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32H81KE9686JC', iid='B00XTIFCXU', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2AWSMOKYRMZ0Z', iid='B00920DUOW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AIHH3AQJU3EVO', iid='B000SHANO8', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1CSQWYXFDR6CL', iid='B0179AY4SM', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1URPDQ22IA4SH', iid='B00E191MSA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LZNIMD7N4G6D', iid='B004VQK9XW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASORW14SWFK0Z', iid='B0013EWRP8', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1SNAP94O2G1XU', iid='B005859IT6', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GON0R5RMNAWG', iid='B00HYPANQU', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3P53NFDW4VI4F', iid='B00U370CJE', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AKAAWLXUTIZ8T', iid='B002TQ5MGU', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...
#  Prediction(uid='A2OZRG22YCQLAV', iid='B015U2LLIW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TTPQ5GJOGJX2', iid='B00122KZBY', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39UGMO30XMTZD', iid='B00NHQ1EX6', r_ui=3.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WRTMM95YLN9F', iid='B005HJMQ7O', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1AOSGL544GNEB', iid='B004L99MNW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QWFW8PBUOIRP', iid='B00137XLYQ', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALLU4SGSA4SJG', iid='B00AFZJWXQ', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GGA2PF5WV12B', iid='B000ZK7YKO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A398D9LMIJ0NC3', iid='B000W239UY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYQN1EPLKBA3F', iid='B00137QW6U', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3ITVEMO5GCBGE', iid='B001F3FZVK', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2IX78SEP2XHA', iid='B0059X3I0W', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHWIBLP7IENZW', iid='B001ZWQ1UU', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PV88SQQHA3EA', iid='B0051IB316', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1326CKJ4FZLG4', iid='B0016O6QIE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6JXJNIY8E4X3', iid='B01BB1C1Y4', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IG5GCYCLXVQM', iid='B00B09BGQW', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABQEFF5VF7R2', iid='B00CFEOIWK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UZ2TCYMSV1I2', iid='B00GPCJHI8', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1AUM4JF74T4BT', iid='B0053V0LJ6', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NV50CLLSFKU3', iid='B000VWPYJ4', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LTFCZFN8BRPL', iid='B004WLMU7O', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18E9L5EW53P60', iid='B000FM82E4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WC34VO9MOJFC', iid='B00137GE22', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3F9EUOZMUBJN2', iid='B001BKQ0CK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2QWEN6DDQ91M7', iid='B000W059EA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NMX55Y3MWWAU', iid='B001YITTCM', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2AEXV36WLMURN', iid='B00444VXYA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2N2ZO8NVRGACR', iid='B003DRSLJE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2YWCGRDG8CK8K', iid='B001NVKFVY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QKR1WNAZL3R7', iid='B00137YODS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1MKHUO4FLQWW9', iid='B0030G66TK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7JU0O2A2NPAD', iid='B00YBJJYIA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JETH76MXBM0O', iid='B00FYEMKG4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARZK8BFLUJP85', iid='B00K8K6P9C', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BEPZGOKPQM0R', iid='B00AAAKH80', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2X6QOZNUEM01T', iid='B00124AW9M', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15UHDGZDU7XKR', iid='B01B73XEEW', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AC3LZVRLL8ES9', iid='B00C5CVAAU', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1PYNMYNWRHLGR', iid='B00KMUO306', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5BVF7AMS6A05', iid='B0083TUFZU', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A126EEI39G25KK', iid='B0020KDUD2', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3ATBRI6WTGCCN', iid='B009MFK7SO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1A287Q32DQE53', iid='B01F8XAILY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MR89URAL2CQ1', iid='B003UXO640', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3G8QF7A6RMI8I', iid='B01DOO46BM', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A205UCRD78Y9BC', iid='B009XY5EC8', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMHVFVCAZAGH1', iid='B00DIM03PY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XEDKMWHYBFG1', iid='B00KM093AG', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1316U5LLGMH5V', iid='B00MJV5LXE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1TWNXZXQ65C5K', iid='B00YZRR9LM', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2C5U7R2C9SLUZ', iid='B01GAKJGL2', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OR7PTQBLX8T0', iid='B0015K287M', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AWFRIEBFFJ0ID', iid='B00122IPBG', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAD0UN7NQAA55', iid='B004X0Y9N2', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15VH1KKF18YXZ', iid='B00122T86M', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A18PQ95SA55X9C', iid='B000W1923S', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A20DZX38KRBIT8', iid='B005T18DOK', r_ui=1.0, est=4.857142857142857, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ANAX7K8262IV8', iid='B00QNKHB08', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANYABTPYLO36C', iid='B001KSENIG', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2798LQ4A1VV2M', iid='B007MUYTDU', r_ui=3.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OG1LL6YJOIKJ', iid='B01AQS5PM8', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1B69N5MDXDUWZ', iid='B011ECYQC0', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5LWPQ0QOMJUJ', iid='B0013D4IK6', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3V8I3FPDFWHCR', iid='B007K3UEAG', r_ui=1.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YA8V5KWI01YS', iid='B000THGDBE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8HQK441BRMF1', iid='B00E0S8S9I', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1G76MAA1001VM', iid='B0019GQDD2', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AA8UURMKRMD5Z', iid='B0028GL0TY', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A257KN34YDOCB9', iid='B00EOKQBHS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A98VFCJP80FD5', iid='B000SZHREO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1X2OO3ZTWOPJE', iid='B00EETFMKQ', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3G4UAHIATGNEK', iid='B00IRSDMHK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2GYNSGMEXCTN8', iid='B005ROQ2Y2', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2582PXGV0YPAK', iid='B004YBCWJS', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39N331YHMT5HY', iid='B000YNA4PO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UNR1BH9BLVXP', iid='B000WLJDSC', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2ETRMCY0RLGAE', iid='B01BMXZ95E', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GDGDUOKTBY2U', iid='B0086JZPNO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APWXR7DD42XBN', iid='B005C0WSEE', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGDPOH01F95IS', iid='B00IKS2BHY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AY0QXNZ5IHIIO', iid='B00137QR9M', r_ui=4.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3F7U41ZW2FPE8', iid='B000V68LGI', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AIKIO03ZYK12M', iid='B00FZ0WC3I', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2P044UYHAWEJA', iid='B0163I35OA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10EOY23JTQBOP', iid='B00PCPQ1OW', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Y2GZXWTWZTNH', iid='B00LVZ4MIY', r_ui=3.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A237YM1IV821AE', iid='B007IYMPKY', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AC5V0B141DHCP', iid='B000TE0N54', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SFEJ1KXNSN0W', iid='B00517ZK48', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37U6S9KM4HAZ4', iid='B00NG1I2V4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AC7GDVVEGWO8Y', iid='B000L6PW4W', r_ui=1.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HNPEFZFFLUHY', iid='B0093DJKH4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABEHUSLHYMDL', iid='B00CV8KRHA', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A35F3AG7H067E8', iid='B00137O7B2', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APR138F7629V2', iid='B00N281JIO', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A20C41F9R4LW4V', iid='B00AIVH3QK', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2UBUF3UUSAWNZ', iid='B0011Z4YB4', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2QCH8CHOCK4BB', iid='B0011Z8O2O', r_ui=5.0, est=4.659761904761905, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  ...]

# %%
print("Item-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# Item-based Model : Test Set
# RMSE: 0.8763
# 0.8762654867671217

# %% [markdown]
# ######

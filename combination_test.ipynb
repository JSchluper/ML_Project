# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from random import sample
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
import os
from surprise.model_selection import train_test_split

# %%
raw_giftcard = pd.read_csv("Data/Gift_Cards.csv", names=['Item', 'User', 'Rating', 'Timestamp'])
giftcard = raw_giftcard.sample(n=10000)
giftcard.drop(['Timestamp'], axis=1,inplace=True)
giftcard = giftcard[['User', 'Item', 'Rating']]

# %%
raw_music = pd.read_csv("Data/Digital_Music.csv", names=['Item', 'User', 'Rating', 'Timestamp'])
music = raw_music.sample(n=10000)
music.drop(['Timestamp'], axis=1,inplace=True)
music = music[['User', 'Item', 'Rating']]

# %%
raw_fashion = pd.read_csv("Data/AMAZON_FASHION.csv", names=['Item', 'User', 'Rating', 'Timestamp'])
fashion = raw_fashion.sample(n=10000)
fashion.drop(['Timestamp'], axis=1,inplace=True)
fashion = fashion[['User', 'Item', 'Rating']]

# %%
data = pd.concat([giftcard, music, fashion])

# %%
data
# Out:
#                   User        Item  Rating
# 89558    A4SPI5IVNO72W  B00G4IURXW     5.0
# 99281   A35FKL9SLQLHXV  B00H5BMH44     5.0
# 59698   A2267GKPOYUK2V  B0091JKY0M     5.0
# 19456   A1X5NWTJW8FTWF  B004LLIKVU     5.0
# 116863  A25WNBB1FOQRRX  B00PMOSXSK     5.0
# ...                ...         ...     ...
# 473726  A2J3NNNR86CSCQ  B00FAR01MU     1.0
# 774553  A2GJC8IN158G83  B01ABSED08     5.0
# 748837  A1EGMB0S7SRVY8  B0184X947O     3.0
# 589961  A16QBV17FSAFLD  B00RCYND38     4.0
# 282714  A2Y3DAF6PF6UD0  B00YJC2AGW     3.0
#
# [30000 rows x 3 columns]

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(data,reader)

# %%
trainset, testset = train_test_split(data, test_size=0.3,random_state=10)

# %%
algo = KNNWithMeans(k=5, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='A1GY7WIWY3O3CE', iid='B0066AZGD4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AP2RMCXTMXSIZ', iid='B00122X5VG', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FU5D1IXCQ2TC', iid='B00UMI95DI', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A48KUX9DSTFQS', iid='B004LLIL5A', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQMYR173EELDB', iid='B000KPIHQ4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22H1YNO8VW6D', iid='B00DG6VIJW', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HCUY33VECUD6', iid='B016DFCL2K', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IDDGREBHCC53', iid='B00KK7PQN4', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10H24TDLK2VDP', iid='B00T52U3EW', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2UUW02RTUX37W', iid='B007V6ETDK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2A9JKNDJQ603B', iid='B01ABSEMB8', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LYDKA5IR8B28', iid='B00TGP7PKI', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1B76OV7EALM27', iid='B00VTDX5RM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A351EHQV49XBCS', iid='B0062ONJ6U', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGUCDXUFKB2NV', iid='B00LCHB9KU', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A28G8GAR810TPR', iid='B01FERR1VE', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A359VTUTZL4PP9', iid='B001VFSNYS', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FNQD6IQURYQD', iid='B00JWTXQ6A', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HATW9TKLXAFI', iid='B000GHRZN2', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TY1IY63GFOK7', iid='B00137MHE6', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AX7XDAW73RSKP', iid='0006920055', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SCF9W9JXI6EQ', iid='B005143DFO', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Y24AZLK950XM', iid='B005JOYRVA', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AY8IO8HI8M5MF', iid='B00138J7EI', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Y1ZUS2NIVGE1', iid='B009Y2GL44', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1I3S0J4WE7HVB', iid='B01CCJEE8A', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABY6TWBT8RP8O', iid='B016JCXQ76', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AIAI9Q3II6MWU', iid='B00B63731Y', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3RRCZ3UME9SW1', iid='B001416OXG', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2EU9AUOLDA8WE', iid='B0189YO1GC', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25Y4YBER2Z0L9', iid='B01F9EO8R2', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AWJU47R97K13O', iid='B000W0X9EM', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A33E1XBNN5FEXT', iid='B01595OS62', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGT0QV5JBA3AI', iid='B000UTV3UW', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KSR1L4XXSC88', iid='B00136NNVI', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADN55GRI2F1QM', iid='B0091JKVU0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3R9UM5617QBNO', iid='B00PIF0D2M', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JKIYXZXOUL75', iid='B00137XA38', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21V0URQRQL2ZA', iid='B005EISPLE', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A17DPUMI4CDQWJ', iid='B007V6ETDK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VWJGCWIW9T60', iid='B00YD567IW', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4OW51B0QTWDE', iid='B000W04OK0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A13YO4F9ZD7CKB', iid='B00B2TFSO6', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1P3JVHM8021GQ', iid='B00CHSWGR8', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25FA0KVL2Z3DG', iid='B00TYOPUS0', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASNFY0CU3E0XO', iid='B00FTJI60I', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3T26WC0N6VUWD', iid='B019NBR5CW', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VD948ACKE0PI', iid='B018UPUJJI', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A182LAG0D7VK60', iid='B00BXLW4Q8', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UIX7WPIYP5UP', iid='B01FTMNDUM', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32CL341FIUFIA', iid='B0091JKVU0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AF6TYAFI87SPC', iid='B0199J6JKW', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3E5S4YXL9U12O', iid='B01E4QUN0W', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZCC0USO86DKZ', iid='B011TX9E30', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CH60KVVJW18F', iid='B002TA2CM8', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1VXFCKOT183U4', iid='B00956UPSW', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JY1C8I4BD5ZF', iid='B000WZWW7M', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A27HMUNRB4BNMC', iid='B01BLV4R8M', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AX94ZHNXN7DBR', iid='B00IX96K8Q', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AKQ2RYJRIQ766', iid='B009RUKQ2G', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MTQIKSFISRBU', iid='B0170K9UTO', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2AMIXLZRZCRQS', iid='B01FERQPAM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1W6ZPJXPY2S8E', iid='B00H5BMH44', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JL9VE5FOFBPC', iid='B005ESMJ02', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22OC5TNQKNVIW', iid='B004LLIKVU', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FGRIG9GI96AW', iid='B002VJT8HY', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6CDXMCK2ZUVI', iid='B0019GDZVU', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1SF0PNBZDEYTU', iid='B004LLIKVU', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A69R69BF3G5WM', iid='B0080IR6BA', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25Y79P8T6MFVN', iid='B01FERR9FW', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A16WOPZ82ZPY52', iid='B01E4QUN0W', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ZSNF1WZYJJFN', iid='B00DVEHRM6', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18FP3GGZW3VGW', iid='B005XEF7R4', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3AM6K28K3LAHE', iid='B00MV9GM8W', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9SKI0BXG1K90', iid='B017I18NMA', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3C5SEVOIBGWYQ', iid='B00120HNAW', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1DW39GP259RNC', iid='B007V6ETDK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARZ8Y07Y7NAU0', iid='B004LLIKVU', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AB2NYS4CE37N7', iid='B01E4QUN0W', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A20CWW6BVSUE36', iid='B01BN3LM4A', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2A7IUZYJNPLSQ', iid='B004LLILGO', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A35WL5FECFNY1L', iid='B007V6ETXA', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BAARIUVDCD99', iid='B00CHSWG6O', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQ31407J3937P', iid='B00KFC91GM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UWCKNDXWY4F8', iid='B00G3LBBGW', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AT8QM8VKIJ6I', iid='B000TDWUBU', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A65KQ9T6PHQXZ', iid='B001GXRQW0', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AEZ7LCLTKNN62', iid='B004RD8XPK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3NIH66H4FSGPA', iid='B004KNWWT0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15C9TPOG65A33', iid='B00TJ67YUK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2COQ53ZPJ34A8', iid='B016MZVIPC', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1VJ5V79I92YMN', iid='B002C2ZX4W', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AK5X8SRP772TM', iid='B01E4QS95I', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BSQPP8C8ZFOB', iid='B00I542DM6', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12X0V5CBUIJFY', iid='B00V0U06EO', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A36M54UNDFL9LH', iid='B006PL4LFI', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3SFMW6GMRBR8I', iid='B00J6E7UA4', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BE0NN45GMM7D', iid='B00BXLVFAO', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AF7D1PFZOP370', iid='B001CV4R3C', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FWYPPEIQFQ20', iid='B00BWDH4DK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A33SGUCETTMRBZ', iid='B004LLILEG', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XVUJ5DAN3P93', iid='B00GNNDSNO', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ATCGYJ5JKZ4V0', iid='B0181WKG4S', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NK421UW2K57Y', iid='B017SP5ODW', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3N1TA2K1GDYOH', iid='B00MV9M0UQ', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2B8W4I8SJ8LSR', iid='B004LLIKVU', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19TPZ3LVBA85Q', iid='B017QPHZ1I', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABLQURMVFIFLP', iid='B00PJEDJRS', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MZWOOVJ96IM0', iid='B00CRQ496G', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A20VJT1JJMCZZS', iid='B000TGTLC8', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYSAUWWSU7516', iid='B005ESMMWW', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1HGZNUXTRBGJ4', iid='B01F70LLD2', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25NH0AQHRUM62', iid='B01CZ54L66', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANBVNU6E8E4BC', iid='B007V6ETDK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3EDV690WRH3AH', iid='B0013D8DM0', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37F0XXW8WA1Z8', iid='B00IYF4QSA', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2UHM9D2Y4DN7O', iid='B00O3YKR48', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2F4SKUXGX3840', iid='B007WMAPQ8', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LFOGPED50UZF', iid='B00HRUGFSM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMEL124IZLDDX', iid='B00123HR8C', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FPENZR1XO759', iid='B00H5BNENW', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BUGPU45ICFEM', iid='B0064EYS2M', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QY0GOCOZL37P', iid='B00CZ5007Q', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QM540H44LS69', iid='B00G3LBDDS', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QT4I28HKC38Z', iid='B0189TCA7E', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1MWWIJ3BVTIBV', iid='B00B2TFSO6', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3U6W30C8NV11Y', iid='B000ZN073W', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A28IDBYBISVC12', iid='B00B2RVQLM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A14IO7S0D2L9E1', iid='B00DI1JJLY', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1V7484BSZGRET', iid='B00LL2OCR8', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BEBG7BR8CBFR', iid='B00P3DVHT2', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AULTKBC66NWLI', iid='B000A15X6K', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AURK3ZVXI1QKB', iid='B00V8RRHG4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3RP8IF9FG4GL3', iid='B01DA12GL6', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BZF5EAY4COVS', iid='B00GN7YYEW', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19XN8ZNPB2VFJ', iid='B00HNIM1EA', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19LSYQ1WGTKQ3', iid='B000K2PJ4K', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5DFK89KIWRZ7', iid='B01FERQPAM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A17Z5DY5K2QUPY', iid='B004KNWWZY', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AF0G67MITCN65', iid='B00123BCKQ', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2IQ7KWQ27600S', iid='B0091JKVU0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WM3VU6BH06IM', iid='B000VZLO5E', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21G1VI8BA7YFS', iid='B0088MYNZU', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AIRZODDCOV9AS', iid='B00C5I0DRK', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A34AY3OUH2CZZG', iid='B000MGLGSM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OFZ23FDQNA12', iid='B016VWBMI4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32QOPWZZLCDY', iid='B00137QS0U', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AR9L3WKUYOGQY', iid='B004NYMVNI', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1PN1KQ4142VMN', iid='B0025ZCZ8S', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QE77XDAIKYNJ', iid='B00A4EK69C', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YVOIFKTIVUOB', iid='B000EE1NNA', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1TDBEGOQSK17B', iid='B00FJ4CDGQ', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12G6BLE6JWEGL', iid='B0132IPR0O', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APGB39R4CXSUP', iid='B00MHLSG2E', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1008TVH0VKIA2', iid='B00NLO2OZG', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AEYLNZPYQ09B4', iid='B01FERQPAM', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31FD0A1TWWA3G', iid='B019X2NGHO', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3ITM6X7UWPHGZ', iid='B0147I9042', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VOVZMI83Y7L6', iid='B01BIMACN8', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LDEDOQZH3VTP', iid='B00123FP5E', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BVMF4C6EM25N', iid='B016I230PA', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A218R21WVW2V1', iid='B00I74V7OY', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21I8AT008DGSP', iid='B01DZVUSS4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2R5K7G4ENPPPJ', iid='B00137QMFG', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FKBWAF4ECM7U', iid='B0028IR7YO', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2PJSNSFCCPVBA', iid='B000VXHQI0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FLUPR02MERPV', iid='B0047DJ1OM', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1HP8CN2W399Q8', iid='B014S24DAI', r_ui=5.0, est=4.763636363636364, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1LROBRQRC3P2B', iid='B000059ZS4', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9CN9CS56WN7U', iid='B00YIWQVWM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FB9Z8GFUR4N5', iid='B00GA35LBY', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26RFZF3RD14C', iid='B004W8D0Y4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXRYVYIBF754Y', iid='B009PMILQE', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYANDEILXQ8DT', iid='B004LLIL5U', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AT1SA2GE10XTW', iid='B0078EPRPE', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1HIP9HR2UI0X6', iid='B00C5UMI3K', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1CAJNC0VW514N', iid='B01CZ4HV9G', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8JG0V3RSBV2Z', iid='B003EYDYMA', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GY08ST5TIT3O', iid='B00RXC7TC0', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A142PHHW8041JK', iid='B00EP6SZWK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVVE9K4TOZENM', iid='B00NUGDE4U', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A490XZXZ946DO', iid='B00BEJ6QE0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1S36JN25HZ17Y', iid='B004LLIKY2', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38LT2MSNH8UAK', iid='B004Q7CK9M', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39PKQXU1KPHI4', iid='B0062ONJRE', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LP0EEMIJ4S2S', iid='B0091JKVU0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2GJDVGSQY7IB', iid='B0187QCFR4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXGBJNCK5Q6JY', iid='B01347172K', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19A44C8F9S5DG', iid='B000GPBG9I', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3E613BUD1KG19', iid='B005EISPLE', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A23XA8MQ22BG23', iid='B0017JF4FO', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2XS8TJDRIWSB0', iid='B003A2FU78', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZTYQVX6HX27R', iid='B017FYYUKO', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5R9SRUBJYDT5', iid='B00ADR2XIC', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WFWV7PRWHX06', iid='B0010Z9CQW', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2UWAMILXW2PR3', iid='B000J4HE6U', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A258G74RNEDAP2', iid='B018GGYGRC', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12F8Y929PETJY', iid='B00TEYS4GA', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LKP4WPT0WNOR', iid='B00OV7OUM2', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GIIV2SVH8VRA', iid='B00WUC7FH2', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29PKET6ASF1UJ', iid='B00IJJVWYM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1TKJGKQ5MV5JZ', iid='B01EV217HW', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3O2E1TZJQ5M55', iid='B00MNWK5Z8', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25WGN0DH9XTVO', iid='B0145WHQPA', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ESPOWHLPNI54', iid='B00BZIOAOS', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1E44X20LNA22P', iid='B00MLO2PGA', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3DKB9335YZKYT', iid='B00JDQJZWG', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2G8CE0G4SWGGP', iid='B00O5C66KM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2DYCJUTE9G5OS', iid='B00138E3RY', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39DL9ALOCS27Z', iid='B00CRQ4CF4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SOOXMNIZOYB5', iid='B00B2TFSO6', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1B0CCHM06GK7M', iid='B005DHN6E2', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1W6I7OKHE2H41', iid='B010MFKWSC', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RAOSI4RAGI47', iid='B00MV9H6VY', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQI2K8WS6YGNU', iid='B004LLIL5A', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1U7TQ65OOXSOC', iid='B01GF6W1E0', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AS7Q206CXVWUG', iid='B004W8D0Y4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21TNRHA7ZAVO2', iid='B00CHSWG6O', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29ACO4QLFEQQY', iid='B00137T3ZW', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FGJ5BC5TQWJU', iid='B00136ROOA', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AEMNJAB8E1THZ', iid='B005MVLI8A', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38N769XBLULH9', iid='B01E4QPDV6', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AS18HDQFG0T1H', iid='B005ESMMWW', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1MMVQ9JNXJN5F', iid='B00H5BMNJI', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AI39CVGYL7PPB', iid='B00T839E1Q', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3SY0LGYQ53HOK', iid='B000WLIN4C', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3AB3COQOHS47B', iid='B000VWOOUY', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2E8V2XGKL4R4P', iid='B00XTM0ZPG', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADLQFHXSPBM2V', iid='B0148U9ZXK', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3OT3AX7QERMW4', iid='B017VM74E4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25F72L3GQ1Y4N', iid='B01E4QUN0W', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3P45H5Z1MNB1G', iid='B00Z9U05E2', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BJ8KM9T1D0VB', iid='B00S466OMA', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LQ3Y5253PXYU', iid='B00DOHM496', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1D5C2KAK28OWY', iid='B0069VHL5Q', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JYA3N6P888VR', iid='B005ESMMWW', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AT23GRCE4KCTX', iid='B0012DR1LU', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3F0LW0P2H71RL', iid='B0194PD6OI', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3NLMOB1YXSDMI', iid='B01E878Q2E', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2958O86ACTSQ2', iid='B0091JKVU0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2XDAOYAS2R48Q', iid='B0091JKVU0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2OZJU6KM08HYW', iid='B00G4IWEZG', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BZVAHO59I7H6', iid='B00JQO81V6', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2H1S2W9PNS6I2', iid='B01CDV7TNE', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JA01O0U9DASC', iid='B00KIB7HZM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2568YDRRWGMBN', iid='B001LFP0EO', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A148M31JM88VJM', iid='B004LLIKVU', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APB4P43CWFO7Q', iid='B00PMLDPYK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A691L9MLEB5B6', iid='B000QZZF36', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NLJIB8W3JFIC', iid='B00X6G8J3A', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10QLX5CDPZ35D', iid='B007V6ETDK', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3V8BCENBATSFY', iid='B01G46HXTO', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3J5RR5YZ44DFQ', iid='B003B995G2', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3RJ9KQ9ZL917L', iid='B014A7L20K', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1TPKPL0LZ2RV5', iid='B00OQZ4D9Y', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31OJEDO227ACW', iid='B01EO0MF1S', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3UG5VD977JCAH', iid='B002T9TJOS', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PQ6BSP4JMS2J', iid='B0028EXXSM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A34EGQ2S0ARY7Q', iid='B003S3SLFC', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AB37KDMMA46K4', iid='B000JRNAGK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QSSGYFMB34C4', iid='B005ESMF5G', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGQYYCOMVXGCA', iid='B000WLILIA', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3D2GPLU9ODJM', iid='B00MA93VIM', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MXVKFT3I1ZGT', iid='B004LLIKW4', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LVNLLO7YJR1Y', iid='B004OJ5ESQ', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2KP5LJW8BXJUK', iid='B00M7LN7SM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3AE7ZXRM0W2MB', iid='B009Y0IEM8', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AK9GPJ3UNCQK9', iid='B00VEK53QG', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A305MLMMMKUPSG', iid='B013R7PCQ4', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQEGWI5BLEU7V', iid='B00IYDIM0K', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2QWA8JL283IB8', iid='B00S4KZZ26', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABFQAQBMGX4KE', iid='B00H5BMH44', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2J19XPHSDZ1ED', iid='B019QTCZMQ', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29WZCBRO3RVGA', iid='B0092MKTL2', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39RCM0AD34YCP', iid='B00MV9H6VY', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NPPAAS9JMRP2', iid='B00EOKQBHS', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12SLSIK8A2265', iid='B01F4OLK1Y', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3I8B8BAJMVN6H', iid='B00OC97P12', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2EYX620UGDCKK', iid='B00V5PN56A', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QGM8QQXU4MR1', iid='B001GXRQW0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Q0ANL89INJLA', iid='B000RKD7OE', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3ENSQAUDFISQ3', iid='B00AW80PPU', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3RC3AK8UN89I9', iid='B00138KJI6', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3RSDHV4880GND', iid='B01E4QUN0W', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2UHGTGOH7WPW4', iid='B001GXRQW0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HV3JZSNW1205', iid='B004W8D0Y4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2P6V2VTM7VBZP', iid='B0019A8WB4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TFXETXXXQD9U', iid='B004LLIKVU', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5V0U5LPJEWW6', iid='B00U6DX3BY', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TYER35WIE01U', iid='B004J37L2Y', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38KUO7EKLQPW', iid='B00C5UMHOU', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KG0J6VUOHG2K', iid='B006PJHP62', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12PU56GKM4GEH', iid='B00I8H1J3O', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJ33R1MO9LJQR', iid='B000051T38', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1A68KC27IXL2U', iid='B004LLIL2I', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2W0CGEJJHMI4G', iid='B00BXINW30', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAY9I2YS3D8CQ', iid='B00AF0K82U', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...
#  Prediction(uid='A11UZ95GYNKXN7', iid='B001OFPWU8', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21SHSLLRB8BBG', iid='B007F55UGW', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A13DGSN4LNFXIB', iid='B00B2TFURQ', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANKZT3CC6MNWW', iid='B000KPIHQ4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGXBZPIW9U37Z', iid='B00DNAGTIQ', r_ui=5.0, est=4.875, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A17RCK6O0F1JNA', iid='B00D7OQDBG', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WXKDA47VPOFT', iid='B01422IQD4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SV8QTOW35S9Z', iid='B019NGYYE4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39W7WCX9S5M3I', iid='B00PMFBOD0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2X36IJ28Y2WUD', iid='B00A4EK69C', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AT6RBO1UAFFGU', iid='B00G4IWEZG', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZF9HPKZXYBKI', iid='B0186YFYXE', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANR9AXQ1VDMHL', iid='B004KNWWV8', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1T1OEV0RVPF5N', iid='B00QI1AUFA', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Q103PZAIP2R4', iid='B0067CC5XK', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3M8LZPC587GEN', iid='B00FHL1GUU', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARR3AKN4DGZWI', iid='B00XTM0ZPG', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A36FM612N45QVQ', iid='B004CE37QO', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3EV84BKJFL1Z5', iid='B0013CWA98', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2P735SGQT5LZQ', iid='B009ZAWI5Q', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADAVMWCRASBQ2', iid='B0066AZGJI', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXFMUQM9B2HTR', iid='B0013F2AL8', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3L93PE7M1QKQ2', iid='B0091JKJ0M', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ATXUBTY8R3U0F', iid='B00GXE331K', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2OU7QCDRH6ZOJ', iid='B00B2TFURQ', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3Q8C602WGHC2W', iid='B00EDW9E80', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A190YMCBG5IFS', iid='B0188LO3UK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UGM9T8GPCMUO', iid='B00835MOGM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7C8FN6GI7TY7', iid='B01AB2IHCO', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1N35NN5HWCHGK', iid='B001416OXG', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A27136FNTVU2TV', iid='B0091JKVU0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A392E9YOWM1ZSM', iid='B001EPWVLG', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2A6DLV86N8W01', iid='B014TKMDH4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A82EXY20JSZZ9', iid='B00XO1OZTY', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VO3QMKSLQDK3', iid='B01578LQ84', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2D3NPOOFAIOHO', iid='B00FN90L7K', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29T4OHWJDAWN7', iid='B007V6ETDK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AFFF7YGAGR1XF', iid='B0149QJVUA', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LUWTGVVNWL6J', iid='B00KX5FGBA', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AZ9W5FI49PB4S', iid='B00DJKKIPU', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQRGINVS2ZSZ0', iid='B00JBVUWRK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AV769LM3GC151', iid='B01H6AYZR0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3U3FND3HB0MSP', iid='B0016L40E4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15NDNQZFI0O2G', iid='B00H5BMH44', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QK1KI0UWQCI6', iid='B010GLWJXI', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NELYOU2T1NLO', iid='B005MZ3708', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASYFVAREWV1MS', iid='B0000287BK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BKRCYANSTX0N', iid='B00IIJ9PQK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TC630JVQ6465', iid='B0091JKJ0M', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASQ56F3ZAAM5F', iid='B00BXLVHZM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1R4GGA2TBWO5P', iid='B018399TEC', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1AOAVUAQQQREQ', iid='B00JPIBLS8', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2C2M1I0MRKREC', iid='B01B61IQ8Y', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WCZVTX61O426', iid='B007JNP9MK', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2H1AAFKLZ7MTH', iid='B01GHLVWWA', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3ML4BR9LTK9AA', iid='B004KFVCV2', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A14ZAVEJDI0R1C', iid='B00DYAV3WM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A68IORP89GQCN', iid='B00KREP1HQ', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31EMCO1N3HFS1', iid='B0108UP0EC', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A36A9XPNZS2NW2', iid='B00548H3CQ', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1D3IPHHWX7CFZ', iid='B000PHANNM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FBBSEWF0XT5K', iid='B00T730PL0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHZY04YNN0HGB', iid='B00RI86YXE', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A338CGS4RJPE5', iid='B0043ZBBQ0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A33EDHEQIEEH94', iid='B000XTDVUE', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RQTGK86JKI8G', iid='B01DO1QGY0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APS61VDDUPC5Z', iid='B005F83A0O', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A226UI5G15ZW10', iid='B00CT7AC7I', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AT4LE0ACLYSLX', iid='B005ESMJ02', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJ9UD3TWD68T3', iid='B014ULXXI0', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2PUWA39R5R8FY', iid='B006PJHP62', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10TF7C5W6AQPP', iid='B01FMUUQJC', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NW1MPYSXIS8N', iid='B0078EPB78', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A27HKE3D4C3V9Y', iid='B009470G2C', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2E6PCE0GRSUOQ', iid='B00YEMDRQE', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2K7N4FBGEHVK9', iid='B000WLIN6K', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JUMEDQB86XTF', iid='B00X92BSNY', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2B4XR3LPWUCSJ', iid='B00BUVH1LO', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGI9FFL4UEDTA', iid='B0066AZGD4', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31SND47TRAU2F', iid='B00RLSCLJM', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MINNDMBOFW1K', iid='B00PG23QFI', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1II2J6ZHL4ZCV', iid='B00BXQIGA6', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACHZJ3WUTQ2BF', iid='B004K3J7LG', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2C9M9XF9CA1DH', iid='B00ZGK21ZQ', r_ui=4.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39QB7L1RYJ3YE', iid='B01COSSVVK', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AW3LGP3CJFURZ', iid='B00LHJMGHI', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1MU47D78FY5HV', iid='B002OY3UJI', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GSM66TWM216E', iid='B00BXLW5QC', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AZ2HJ44P984KH', iid='B017TH3S4Q', r_ui=2.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A385W15T6KW1LT', iid='B009EANE3M', r_ui=3.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2O3D17TP8VRHH', iid='B01FN750R2', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AKZUAARQYEHWW', iid='B00UF6RI36', r_ui=1.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAT29VCFHD42E', iid='B00F2RZMEA', r_ui=3.0, est=4.6923076923076925, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1NF9UFJSBPDVS', iid='B00R77U0SG', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1A99TOZ30WFCB', iid='B004OS67N8', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A42TV8FJP7MI3', iid='B000V64TW8', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANOMQ4RJ35QVI', iid='B00PG40J3I', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANLS6YY9AB3BY', iid='B004LLIL4G', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYZF5OYICWHJA', iid='B000SX8ASS', r_ui=5.0, est=4.416190476190476, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  ...]

# %%
print("Item-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# Item-based Model : Test Set
# RMSE: 1.1659
# 1.1658789535608503

# %%
import pandas as pd
import gzip
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def parse(path):
  g = gzip.open(path, 'rt', encoding='utf-8')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF('Data/meta_Gift_Cards.json.gz')

# %%
cols = list(df.columns.values)
cols
# Out:
# ['category',
#  'tech1',
#  'description',
#  'fit',
#  'title',
#  'also_buy',
#  'image',
#  'tech2',
#  'brand',
#  'feature',
#  'rank',
#  'also_view',
#  'details',
#  'main_cat',
#  'similar_item',
#  'date',
#  'price',
#  'asin']

# %%
df = df[['asin','category',
 'tech1',
 'description',
 'fit',
 'title',
 'also_buy',
 'image',
 'tech2',
 'brand',
 'feature',
 'rank',
 'also_view',
 'details',
 'main_cat',
 'similar_item',
 'date',
 'price']]

# %%
df
# Out:
#             asin                  category tech1  \
# 0     B001BKEWF2  [Gift Cards, Gift Cards]
# 1     B001GXRQW0  [Gift Cards, Gift Cards]
# 2     B001H53QE4  [Gift Cards, Gift Cards]
# 3     B001H53QEO  [Gift Cards, Gift Cards]
# 4     B001KMWN2K  [Gift Cards, Gift Cards]
# ...          ...                       ...   ...
# 1542  B01GMFJ8JU  [Gift Cards, Gift Cards]
# 1543  B01GOQIKRI  [Gift Cards, Gift Cards]
# 1544  B01GOQHGL4  [Gift Cards, Gift Cards]
# 1545  B01GP1W4LA  [Gift Cards, Gift Cards]
# 1546  B01H5PPJT4  [Gift Cards, Gift Cards]
#
#                                             description fit  \
# 0     [Gift card for the purchase of goods or servic...
# 1     [Amazon.com Gift Cards are the perfect way to ...
# 2     [<div class="aplus"> <br>Amazon.com Gift Cards...
# 3     [<div class="aplus"> <h4>Amazon.com Gift Cards...
# 4                                                    []
# ...                                                 ...  ..
# 1542  [Hand-Pattied Burgers  Chicken, Steaks & Fish ...
# 1543  [<strong>Smoothie King Gift Cards. The Perfect...
# 1544  [Cattle Baron Restaurants, Inc.is a privately ...
# 1545  [The cards, available in $25 increments up to ...
# 1546  [Before you click to continue, you should know...
#
#                                                   title  \
# 0                       Serendipity 3 $100.00 Gift Card
# 1                                 Amazon.com Gift Cards
# 2     Amazon.com Gift Cards, Pack of 50 (Old Version...
# 3      Amazon.com $50 Gift Cards, Pack of 50 (Old Ve...
# 4                       Wood Puzzle Magic Box Gift Card
# ...                                                 ...
# 1542   Harvey&#39;s Grill and Bar &amp; Hayden&#39;s...
# 1543                            Smoothie King Gift Card
# 1544                  Cattle Baron Restaurant Gift Card
# 1545                             Go Play Golf Gift Card
# 1546   Lowe&#39;s Gift Cards Configuration Asin - E-...
#
#                                                also_buy  \
# 0                                                    []
# 1                                                    []
# 2     [B005ESMEBQ, B007EE5WNA, B007EE5OBU, B07HJHK8Y...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1542                                                 []
# 1543  [B00NVUDIZ0, B00BXLVE6Y, B00O4I5S7O, B00GOLGWV...
# 1544                           [B00CXZPG0O, B00PG84W32]
# 1545  [B077CZY68Z, B07JJHVWXL, B00NVUDIZ0, B01CZ54L6...
# 1546                                                 []
#
#                                                   image tech2  \
# 0                                                    []
# 1     [https://images-na.ssl-images-amazon.com/image...
# 2     [https://images-na.ssl-images-amazon.com/image...
# 3     [https://images-na.ssl-images-amazon.com/image...
# 4     [https://images-na.ssl-images-amazon.com/image...
# ...                                                 ...   ...
# 1542  [https://images-na.ssl-images-amazon.com/image...
# 1543  [https://images-na.ssl-images-amazon.com/image...
# 1544  [https://images-na.ssl-images-amazon.com/image...
# 1545                                                 []
# 1546  [https://images-na.ssl-images-amazon.com/image...
#
#                                 brand  \
# 0                       Serendipity 3
# 1                              Amazon
# 2                              Amazon
# 3                              Amazon
# 4                 Creative Crafthouse
# ...                               ...
# 1542
# 1543                       QuickGifts
# 1544                       QuickGifts
# 1545  Go Play Golf by Fairway Rewards
# 1546
#
#                                                 feature  \
# 0                                                    []
# 1     [Amazon.com Gift cards never expire and carry ...
# 2     [Contains 50 Gift Cards, Gift Card has no fees...
# 3     [Contains 50 Gift Cards, Gift Card has no fees...
# 4                                                    []
# ...                                                 ...
# 1542                                                 []
# 1543  [Over 500 Locations Nationwide!, Smoothies, He...
# 1544  [9 Locations over New Mexico and Texas!, Join ...
# 1545  [Go Play Golf - the only national gift card th...
# 1546                                                 []
#
#                                                    rank  \
# 0                                                    []
# 1                                                    []
# 2                                 1,786 in Gift Cards (
# 3                                                    []
# 4     [>#2,893,775 in Toys & Games (See Top 100 in T...
# ...                                                 ...
# 1542                              5,808 in Gift Cards (
# 1543                              1,201 in Gift Cards (
# 1544                              3,302 in Gift Cards (
# 1545                              1,015 in Gift Cards (
# 1546                              7,585 in Gift Cards (
#
#                                               also_view  \
# 0                                                    []
# 1     [BT00DC6QU4, B01I4AHZXC, B0719C5P56, B01K8RLHZ...
# 2     [B005ESMEBQ, B007EE5OBU, B007EE5WNA, B007EE60N...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1542                                                 []
# 1543  [B00NVUDIZ0, B00GOLGWVK, B07JKD8G5X, B00BXLVE6...
# 1544                                                 []
# 1545  [B01LYIR4CZ, B077CZY68Z, B07736DNZB, B01N9AE2Z...
# 1546  [B0078EPRVS, BT00DC6QU4, B01CHHZL34, B07JX5XNY...
#
#                                                 details      main_cat  \
# 0     {'
#     Product Dimensions:
#     ': '3.4 x 2.1 ...       Grocery
# 1     {'Shipping Weight:': '0.5 ounces', 'Domestic S...    Gift Cards
# 2     {'Shipping Weight:': '1.8 pounds (', 'Domestic...    Gift Cards
# 3     {'Shipping Weight:': '1.6 pounds', 'Domestic S...    Gift Cards
# 4                                                    {}  Toys & Games
# ...                                                 ...           ...
# 1542  {'Domestic Shipping: ': 'Currently, item can b...    Gift Cards
# 1543                            {'ASIN:': 'B01GOQIKRI'}    Gift Cards
# 1544                            {'ASIN:': 'B01GOQHGL4'}    Gift Cards
# 1545  {'Shipping Weight:': '0.6 ounces (', 'ASIN:': ...    Gift Cards
# 1546  {'Domestic Shipping: ': 'Currently, item can b...    Gift Cards
#
#      similar_item date      price
# 0
# 1
# 2                       $1,250.00
# 3
# 4
# ...           ...  ...        ...
# 1542
# 1543                       $10.00
# 1544
# 1545                       $50.00
# 1546
#
# [1547 rows x 18 columns]

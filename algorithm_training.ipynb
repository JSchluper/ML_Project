# %%
import numpy as np
import pandas as pd
import json
import gzip
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
import os
from surprise.model_selection import train_test_split

# %%
def parse(path):
  g = gzip.open(path, 'rt', encoding='utf-8')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

data = getDF('Data/Gift_Cards_5.json.gz')
data.drop(['reviewTime', 'verified','style', 'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'vote', 'image'], axis=1,inplace=True)
data = data[['reviewerID', 'asin', 'overall']]

# %%
data
#data.dtypes
# Out:
#           reviewerID        asin  overall
# 0     A31UBHTUUIFJUT  B004LLIKVU      5.0
# 1     A2MN5JQMIY0FQ2  B004LLIKVU      4.0
# 2     A25POI5IGGENPM  B004LLIKVU      5.0
# 3     A2HYGTHB4LJ9FW  B004LLIKVU      5.0
# 4      ACDG3M94UMZGJ  B004LLIKVU      5.0
# ...              ...         ...      ...
# 2967  A1MXZ1CW0ZVTKL  B01DWOZKSC      5.0
# 2968  A1SVYJFIASQ46Z  B01DWOZKSC      4.0
# 2969  A1QZ08NSDCZBA3  B01E4QS95I      5.0
# 2970  A1L4GG3FBMIG6V  B01FERR9FW      5.0
# 2971  A1MXZ1CW0ZVTKL  B01GKWEPBG      5.0
#
# [2972 rows x 3 columns]

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(data,reader)

# %%
trainset, testset = train_test_split(data, test_size=0.3,random_state=10)

# %%
algo = KNNWithMeans(k=5, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='A3JT9D014239AO', iid='B00CXZPG0O', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A27A4BCOBGPYR3', iid='B00FTJI60I', r_ui=5.0, est=4.8866930171278, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A33QLA6L0ZJ7ZM', iid='B00MV9O08G', r_ui=5.0, est=4.6, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1JH2VX7X8SFVR', iid='B01E4QUN0W', r_ui=5.0, est=4.988499521527636, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A10CJ0DWV2M12X', iid='B00MV9H6VY', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A28WNQS5B4JGUJ', iid='B00GRLUECA', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AZKLLDZ59Q4A1', iid='B00BXLW5QC', r_ui=5.0, est=4.927547336151072, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AD85M8MCAFJKY', iid='B01BLV4R8M', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A13H0YP0J8PM6V', iid='B00MV9H6VY', r_ui=5.0, est=5, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A2QHY2VA7AZEL2', iid='B00P3DUFRW', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1V9KVHS8CF7N9', iid='B004Q7CK9M', r_ui=5.0, est=4.885245901639344, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3RROHRPYKJU4J', iid='B00BXLSZPM', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1Z3D35JS8AGCP', iid='B00IGYPALG', r_ui=5.0, est=4.9, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2AWS633WWTXFX', iid='B00BXLW5QC', r_ui=5.0, est=4.997715979896057, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A3D2YI192P0RO9', iid='B00BXLV55Y', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AN7NSSEVCS3DS', iid='B00ELQD11E', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A35S2WL2F27WC7', iid='B00BXLVE6Y', r_ui=5.0, est=4.970224599932511, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3MKDH1WY7FGLS', iid='B00BXLVE6Y', r_ui=5.0, est=4.9, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AK3402G7FO7AY', iid='B016CICYXO', r_ui=5.0, est=4.875, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1GQZ9GW1PLAUJ', iid='B00F2RZMEA', r_ui=5.0, est=4.8724947766770486, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1K78G1I46XN4O', iid='B00911NGTG', r_ui=5.0, est=4.857142857142857, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2GNZITHG06UE3', iid='B00GOLGWVK', r_ui=5.0, est=4.955906920162865, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AAE05KS3NMVPL', iid='B01E4QS95I', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='ATA4YSJ4JCBTR', iid='B0080IR6BA', r_ui=5.0, est=4.92364275984655, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2P9CF2457P7J1', iid='B00BXQIGA6', r_ui=5.0, est=4.984539397302666, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AOAV7YRGTS2BF', iid='B0078EPRPE', r_ui=5.0, est=4.922786422757256, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1OQYXKIH50PHK', iid='B00FTGSKL6', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A63HW9AIN5MI3', iid='B004Q7CK9M', r_ui=5.0, est=4.996777816461445, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A1OVVGPONC0EYY', iid='B005DHN6E2', r_ui=5.0, est=4.929292929292929, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2CGORRQGDEL37', iid='B01E4QQ6QM', r_ui=5.0, est=4.8969696969696965, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A197JBN6LZPSR2', iid='B015WY0DOQ', r_ui=5.0, est=4.911764705882353, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ADL4AT0OZ9IS6', iid='B00JDQJZWG', r_ui=5.0, est=4.888888888888889, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AHBLLZMAXGB2U', iid='B005ESMF5G', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1L7ZNJ417R9KR', iid='B0091JKY0M', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2KOKSKEDIBRGQ', iid='B005ESMFP6', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A22KMCKYE5KQ2X', iid='B01FERR1VE', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3RROHRPYKJU4J', iid='B00BXLW5QC', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A63HW9AIN5MI3', iid='B01FERR1VE', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ATZR7KHUSFX3K', iid='B0091JL3OI', r_ui=5.0, est=4.8076923076923075, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='ALL9XFM0Q1N4E', iid='B00BXLUO1U', r_ui=5.0, est=4.875, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2U88Z24HBE9ZF', iid='B00FTGESM6', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1Z1JLCLHI6T5E', iid='B00BXLW5QC', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1YWA3Z785KX03', iid='B00MV9H6VY', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AQQ89MHENR0OL', iid='B00JDQJZWG', r_ui=5.0, est=4.995067246097468, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1NWGBDJ06W9BH', iid='B01E4QPDV6', r_ui=5.0, est=4.980678260221138, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A2EMYDRME7UQVN', iid='B00BXLVAD6', r_ui=5.0, est=4.800632911392405, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AAD9PJLHYQXHB', iid='B00BXLSGHO', r_ui=5.0, est=4.922446406052964, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2P9CF2457P7J1', iid='B00BXLSGHO', r_ui=5.0, est=4.879836048469507, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AP6K4SV815OHV', iid='B00CHQ7I2S', r_ui=5.0, est=4.982905982905982, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AFWMFPFDWAYS', iid='B00JDQJZWG', r_ui=5.0, est=4.888888888888889, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A28YGUP7ZFI6PP', iid='B00BXLSGHO', r_ui=5.0, est=4.922446406052964, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A28DC3TXTBUV96', iid='B00ET5WASC', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1SVYJFIASQ46Z', iid='B00BXLW5QC', r_ui=4.0, est=3.991734031249534, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A3FA7V5OQA9FBU', iid='B00FTGF3P2', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A15NY62RL9WFIO', iid='B00BXLURUI', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1U1G73EI5IRZF', iid='B00BXLTR6S', r_ui=3.0, est=4.875, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3BTZ27R4XTL19', iid='B00GOLGWVK', r_ui=5.0, est=4.95785844249968, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A28TIBCUPRHJ6F', iid='B004Q7CK9M', r_ui=5.0, est=4.986478041336858, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A31UBHTUUIFJUT', iid='B01E4QS95I', r_ui=5.0, est=4.980690462912069, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AA0XW0HGIL0XK', iid='B00MV9FM9C', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A35ZL3SVAXF593', iid='B00BXLVFAO', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AF5WDVMF7BID8', iid='B00BXQIGA6', r_ui=5.0, est=4.969406435123972, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1WLQZOGXNQQC8', iid='B00BXLTUBA', r_ui=5.0, est=4.971685971685972, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2W3RQOSC87P4A', iid='B0080IR6BA', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3JOKTA79FF9ZO', iid='B00BXLVAD6', r_ui=5.0, est=4.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1ZF37OJS48D77', iid='B00BXLUFQ4', r_ui=4.0, est=4.190476190476191, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A16QCOFOP5DW4I', iid='B00BXLVAD6', r_ui=5.0, est=4.880463956681547, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A2WCRWBZJETE17', iid='B014S1KPKG', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3MP4P1CZO3GDO', iid='B01FERQPAM', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A2RTTRR421J9KG', iid='B006PJI03Y', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A28TIBCUPRHJ6F', iid='B00JDQKFPC', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3V5F050GVZ56Q', iid='B00BXLSUF2', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2JC55N3T203DD', iid='B00ELQD0DS', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AIG7PZQOVH31T', iid='B00O4I5S7O', r_ui=5.0, est=4.991650301873831, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2QCP2MQPDXKHN', iid='B006PJHP62', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1L4GG3FBMIG6V', iid='B01E4QUN0W', r_ui=5.0, est=4.978258180650544, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3HRJPNZFGI2YZ', iid='B01B25LFGY', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='APJ54GHXDLW7O', iid='B015WY0DOQ', r_ui=5.0, est=4.911764705882353, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1JE5NEAFE9SV3', iid='B00BXLVAD6', r_ui=5.0, est=4.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3LT61TE9F13YF', iid='B00FTJI60I', r_ui=5.0, est=4.979933110367893, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A379SJMF93CVYZ', iid='B0078EPBHI', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A37CORPQS3IVD0', iid='B015WY0DOQ', r_ui=5.0, est=4.972370766488414, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2YSO316K2D5MK', iid='B00CXZPG0O', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A35S2WL2F27WC7', iid='B00GRLUECA', r_ui=5.0, est=4.992058786837748, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2TZK0F2X8EIVA', iid='B0091JL3OI', r_ui=5.0, est=4.8076923076923075, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2RV5MAIOHKMW0', iid='B00FTJI60I', r_ui=5.0, est=4.861801242236025, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A32M8K2QDHX8JO', iid='B00BXLSZPM', r_ui=5.0, est=5, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='ALG9T0EF2ZXDI', iid='B006PJI03Y', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A368CSWVBNABBB', iid='B01DWOZKSC', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3HRJPNZFGI2YZ', iid='B006PJHPV2', r_ui=5.0, est=4.85778273445139, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2DIIBPEA3CTXL', iid='B00AR51Y5I', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A22KMCKYE5KQ2X', iid='B01E4QUN0W', r_ui=5.0, est=4.985684337133015, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1U1G73EI5IRZF', iid='B00MV9GM8W', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A138CUKESU7PIX', iid='B00FTGESM6', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2Y9R4IWK1ANBN', iid='B00AR51Y5I', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1CCSBUDVPRO8Y', iid='B00BXLSSOU', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AS9AWGWHW7AWC', iid='B01E4QS95I', r_ui=5.0, est=4.97299899266246, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A31UBHTUUIFJUT', iid='B01E4QUN0W', r_ui=5.0, est=4.959531961679444, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A1UGE7FHLQC450', iid='B01FYJMJHI', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A17PNZL8SLGRG8', iid='B01CZ54L66', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2JCUY769II5B5', iid='B016PARP24', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2R9Y2T1JU2YCK', iid='B01E4QPDV6', r_ui=5.0, est=4.894736842105263, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A73IL07XP97YM', iid='B01E4QS95I', r_ui=5.0, est=4.998703262793741, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A3PZJVCJN2J4RB', iid='B004Q7CK9M', r_ui=5.0, est=4.978642214314159, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='AILKGRMLEMGXC', iid='B00BXLT1UA', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1EN789V0ZI7BQ', iid='B00AR51Y5I', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1L4GG3FBMIG6V', iid='B00CHQ7I2S', r_ui=5.0, est=4.982905982905982, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AH4CWUHVKZ2I5', iid='B00ET5WBU4', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AZ78R12YFCRS0', iid='B00MV9H6VY', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AZLOVR7A8WCNL', iid='B00BXLW5QC', r_ui=5.0, est=4.993617021276595, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A11F143J72N3QZ', iid='B006PJHP62', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1F2NKB1ZKMO2V', iid='B00MV9OQYO', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A8R2L54HEVG6N', iid='B0091JKVU0', r_ui=5.0, est=4.898305084745763, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1NPV58UNNIBWL', iid='B015WY0DOQ', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3O5INI2TZ8KHT', iid='B01E4QUN0W', r_ui=5.0, est=4.930632911392405, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3PZJVCJN2J4RB', iid='B00CXZPG0O', r_ui=5.0, est=5, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A3HRJPNZFGI2YZ', iid='B00GOLGWVK', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1N5KQC9AU6SR1', iid='B01E4QQ6QM', r_ui=5.0, est=4.915248028694965, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1K78G1I46XN4O', iid='B00CHQ7I2S', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A31JPNHS8Y3G40', iid='B00GOLGWVK', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2P6CE40SQB90M', iid='B00BXLVHZM', r_ui=4.0, est=4.8407641993326695, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A1VP2NVKUX65V0', iid='B00BXLUO1U', r_ui=5.0, est=4.875, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2GALQK816VOQP', iid='B00BXLSZPM', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2SWVHBL244VHD', iid='B0078EPRPE', r_ui=5.0, est=5, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A28MI0OGL4S2BB', iid='B0091JKY0M', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1ZF37OJS48D77', iid='B016PARP24', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A14Z8ADHY64JUV', iid='B00NU8FTK0', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A32M8K2QDHX8JO', iid='B00910XGTM', r_ui=5.0, est=4.777777777777778, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1UGE7FHLQC450', iid='B00911NGTG', r_ui=5.0, est=4.857142857142857, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3GJ0ME0T16IIO', iid='B00BXLW4Q8', r_ui=4.0, est=4.277203251024082, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1PGEVY0S98WCC', iid='B01E4QQ6QM', r_ui=5.0, est=4.958098957635398, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A13OFOB1394G31', iid='B0091JKJ0M', r_ui=5.0, est=4.9743589743589745, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3OFTIM87CP08T', iid='B006PJI03Y', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AV8SEQYKSR87', iid='B00CXZPG0O', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1PD3L2DC3VIB8', iid='B004Q7CK9M', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A3PRNMOWQGAR15', iid='B00O4I5HWA', r_ui=5.0, est=4.625, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AS9ARKLF5DV8R', iid='B00HLAO65M', r_ui=5.0, est=4.791861824319796, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='ADFC4YK6CC9C1', iid='B0091JKVU0', r_ui=5.0, est=4.898305084745763, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3NNNJAQ22RN10', iid='B00BXQIGA6', r_ui=4.0, est=4.90448524016852, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A13H0YP0J8PM6V', iid='B015WY0DOQ', r_ui=5.0, est=4.991052616848192, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A2SWVHBL244VHD', iid='B01DWOZKSC', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2PHOTTFXUGB7V', iid='B005ESMF5G', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3HRJPNZFGI2YZ', iid='B0091JKJ0M', r_ui=5.0, est=4.9743589743589745, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A182B2JKKMI6DM', iid='B00BXLTUBA', r_ui=5.0, est=4.922731356693621, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='ARZLW6MFV58E9', iid='B00BXLW5QC', r_ui=4.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A18FM0A09F4VI9', iid='B00PG9870U', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2Z43ZQDGCFCBD', iid='B01E4QS95I', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1Z3WM378F0L67', iid='B00MV9GGEC', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ALQUMN89FI5HD', iid='B0188LO3UK', r_ui=5.0, est=4.94165113988829, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='AP1DLN56CVTUI', iid='B00BXLTM0E', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3T3BD40FHQFYK', iid='B00BXLT1UA', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2U88Z24HBE9ZF', iid='B005ESMFP6', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1KT83W01QECQL', iid='B00BXLT5EW', r_ui=5.0, est=4.857142857142857, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A35TLFQDEJH95Y', iid='B00MV9O08G', r_ui=1.0, est=1.323969635685343, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A11P365785M5XM', iid='B00ADR2XIC', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A34JP8QRZRS7W5', iid='B005ESMF5G', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2QCP2MQPDXKHN', iid='B015WY0DOQ', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3JVFGFO1DZIBX', iid='B00AR51Y5I', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1CINUBBFNYCL7', iid='B00BXLW5QC', r_ui=5.0, est=4.8936170212765955, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3GJ0ME0T16IIO', iid='B00F2RZMEA', r_ui=5.0, est=4.837837837837838, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AIK1JA1DVLUBW', iid='B0091JKVU0', r_ui=5.0, est=4.966432131311761, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1U1G73EI5IRZF', iid='B005ESMJ02', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A30LC9JY57YA0O', iid='B01E4QUN0W', r_ui=5.0, est=4.908262337348812, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AK3402G7FO7AY', iid='B00JDQJZWG', r_ui=5.0, est=4.888888888888889, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='ADGKZ1FXY3DRE', iid='B014S24DAI', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A33YZG61WPNG8D', iid='B00FTGTIOE', r_ui=4.0, est=4.123860832746394, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1KT83W01QECQL', iid='B00BXLTUBA', r_ui=5.0, est=4.809523809523809, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2EMYDRME7UQVN', iid='B00BXLVHC0', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3V5F050GVZ56Q', iid='B00BXLUFQ4', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A138CUKESU7PIX', iid='B00EEHV8DI', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2P9CF2457P7J1', iid='B014S24DAI', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AZKLLDZ59Q4A1', iid='B00CXZPG0O', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1TC5SEU8KYKKJ', iid='B0078EPBHI', r_ui=5.0, est=4.996740235857449, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A13X371OP2DYB1', iid='B01E4QQ6QM', r_ui=5.0, est=4.962014560145336, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1M4YX4CF56QUK', iid='B00MV9FPLM', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AQVPYF87SQF6S', iid='B00MV9N316', r_ui=5.0, est=4.828282828282828, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1KDV50IO35IK3', iid='B0078EPBHI', r_ui=4.0, est=4.401499204257208, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='AX3A22D274GLE', iid='B006PJHP62', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='ACCXISPR2ASZA', iid='B00KFLZVQM', r_ui=5.0, est=4.857142857142857, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2CHMYBZTQEK50', iid='B00MV9H6VY', r_ui=4.0, est=4.928571428571429, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1SVYJFIASQ46Z', iid='B00BXLSZPM', r_ui=4.0, est=4.038608317230265, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A1R5DGRO0AU4AV', iid='B0091JKVU0', r_ui=5.0, est=4.964971751412429, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2RTTRR421J9KG', iid='B00YD743CW', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1DTFDL68IUFWO', iid='B00ADR2XIC', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='APJ54GHXDLW7O', iid='B00MV9H6VY', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1R5DGRO0AU4AV', iid='B0080IR6BA', r_ui=5.0, est=4.983333333333333, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='ALQUMN89FI5HD', iid='B00BXLW5QC', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AQVPYF87SQF6S', iid='B00MV9H6VY', r_ui=5.0, est=4.928571428571429, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1F2NKB1ZKMO2V', iid='B00MV9M0UQ', r_ui=5.0, est=4.888888888888889, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1L2NJYQ9O10TP', iid='B01DWOZKSC', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1AX06H07SYSGI', iid='B01CZ54L66', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AQ07WF9O4HG65', iid='B00G08KW2C', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A7VGY11A193XL', iid='B00BXLSZPM', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2630ATALYRS6K', iid='B016CICYXO', r_ui=4.0, est=4.90530303030303, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1U1G73EI5IRZF', iid='B00FTJI60I', r_ui=5.0, est=4.780860325120807, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A1DWCUOCK2EKCG', iid='B00MV9H6VY', r_ui=5.0, est=4.928571428571429, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2LNRXH1S0EH1H', iid='B01BLV4R8M', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2LN59TG9PA926', iid='B00BXLSGHO', r_ui=5.0, est=4.862095160939903, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AXSVY0U0NVL89', iid='B006PJI03Y', r_ui=5.0, est=4.1923076923076925, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='ALLLA3XNDX424', iid='B01E4QPDV6', r_ui=5.0, est=4.99017690831531, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='ADG6M004G3PYL', iid='B00ELQD0DS', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1M4YX4CF56QUK', iid='B00911NGTG', r_ui=4.0, est=4.857142857142857, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1Z3WM378F0L67', iid='B00MV9GTFS', r_ui=5.0, est=4.857142857142857, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1U9NOZSL0SN9X', iid='B00GDHVSYG', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A31UBHTUUIFJUT', iid='B0091JKY0M', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AP6K4SV815OHV', iid='B015WY1JDK', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1N5KQC9AU6SR1', iid='B0091JKVU0', r_ui=5.0, est=4.95062115963621, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A2XVDYOW18FNMJ', iid='B00BXLW5QC', r_ui=4.0, est=4.093617021276596, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AK3402G7FO7AY', iid='B004Q7CK9M', r_ui=5.0, est=4.981852367221776, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AKABUMXBAC69W', iid='B0091JKY0M', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2L4X2YO7BKNQ4', iid='B00JDQKFPC', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1G2TIZW7OJ4I7', iid='B005ESMF5G', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ATZ9ZSR664K54', iid='B00BXLW5QC', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AXK37UZY8UPYP', iid='B01B25L7US', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2QKY7ZG920FT7', iid='B00GRLUECA', r_ui=5.0, est=4.203915326713893, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A1SB5ORQW3DHF0', iid='B00910XGTM', r_ui=5.0, est=4.777777777777778, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AWX69VUHQ4K3N', iid='B00BXQIGA6', r_ui=5.0, est=4.220878222752798, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3CHNGUSZR497B', iid='B006PJHP62', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A6MEGFLO6NT4L', iid='B01CT5PHJ2', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3JVYMD4HETANN', iid='B00OX9OKO6', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1KU8DS7KA7OYT', iid='B009HE86FQ', r_ui=5.0, est=4.664544368926529, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AZKLLDZ59Q4A1', iid='B00PG8502O', r_ui=5.0, est=4.88422161750611, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A31V303E0E0QAW', iid='B00BXLSUF2', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A63HW9AIN5MI3', iid='B01B25L7US', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1WLQZOGXNQQC8', iid='B015WY0DOQ', r_ui=5.0, est=4.911764705882353, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A9J7798EZ7F8C', iid='B0091JKVU0', r_ui=5.0, est=4.936836726442428, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1O0W1MJPZYI9J', iid='B0091JKVU0', r_ui=5.0, est=4.995391825777675, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2XVDYOW18FNMJ', iid='B00HLAO65M', r_ui=5.0, est=4.854469854469855, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A259R4SKC5Q7T6', iid='B00BXLUFQ4', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3FWMBEGL6C665', iid='B00FTGTIOE', r_ui=5.0, est=4.96, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='ALG9T0EF2ZXDI', iid='B00PG8502O', r_ui=5.0, est=4.954482031138414, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='ARLPBIM5RLZ64', iid='B00BXLW5QC', r_ui=5.0, est=4.954527254099131, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='ADFC4YK6CC9C1', iid='B00GOLGWVK', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2FQU2MZBR2JWV', iid='B00F2RZMEA', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1KTZOXL3WB1D8', iid='B0091JKY0M', r_ui=5.0, est=4.510858224407224, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2AWS633WWTXFX', iid='B00BXLT5EW', r_ui=5.0, est=4.927178341689715, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AF5DE7E49647T', iid='B00BXLVD8I', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A27A4BCOBGPYR3', iid='B00BXLW4Q8', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AK3402G7FO7AY', iid='B01E4QUN0W', r_ui=5.0, est=4.88, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1DWCUOCK2EKCG', iid='B00MV9LSHC', r_ui=5.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1I7BRTU2J9MHS', iid='B0091JKVU0', r_ui=5.0, est=4.898305084745763, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2LNRXH1S0EH1H', iid='B00BXLVAD6', r_ui=4.0, est=4.424260618684179, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A333GGTZSUJC30', iid='B0091JKJ0M', r_ui=5.0, est=4.9743589743589745, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3RUNGX8PZ8VYO', iid='B01CZ54L66', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AU0MC17FYRPIU', iid='B0078EPBHI', r_ui=5.0, est=5, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='AFOKMN2M7MGQK', iid='B006PJHP62', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1YWA3Z785KX03', iid='B00OX9OKO6', r_ui=5.0, est=4.578834260708603, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1C0CVNL72PEQH', iid='B01CT5PHJ2', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A35S2WL2F27WC7', iid='B00JDQJZWG', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2KJQVKKBIEGNC', iid='B00FTGTIOE', r_ui=5.0, est=4.96, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A4S0944WECL61', iid='B00MV9FM9C', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A34CF62DEN31Q9', iid='B00MV9H6VY', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A2QKY7ZG920FT7', iid='B00BXLVD8I', r_ui=5.0, est=4.828828828828829, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A32M8K2QDHX8JO', iid='B00PG8502O', r_ui=5.0, est=4.926076750174551, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A348GXFNYRHI22', iid='B006PJHPV2', r_ui=5.0, est=4.741290403329961, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A35S2WL2F27WC7', iid='B00MV9GRNW', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AWVA67A1LIEXB', iid='B006PJHS50', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2AWS633WWTXFX', iid='B00CXZPG0O', r_ui=5.0, est=5, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A2H5IZALZGE4AD', iid='B00UW1CEMY', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A35ZJY01RQSY5O', iid='B0091JKJ0M', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AM5S6RSDY2CTA', iid='B00BXQIGA6', r_ui=5.0, est=4.965802789545561, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AVCV7UBUUX7YP', iid='B00MV9GTFS', r_ui=5.0, est=4.857142857142857, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2CM3SWOMP3A9C', iid='B005DHN6E2', r_ui=5.0, est=4.818181818181818, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A241GI5D9EVJI6', iid='B00MV9O08G', r_ui=5.0, est=4.6, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A6CGXL9SR42M0', iid='B00BXLVE6Y', r_ui=5.0, est=4.988235294117647, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2SWVHBL244VHD', iid='B00GOLGWVK', r_ui=5.0, est=4.947876341171749, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A2NOW0DV5XI9NF', iid='B00BXLURUI', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3PRNMOWQGAR15', iid='B00FTJI60I', r_ui=5.0, est=4.826086956521739, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AYSOAWLV2LCCG', iid='B015WY0DOQ', r_ui=5.0, est=4.911764705882353, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A28TIBCUPRHJ6F', iid='B0091JKY0M', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1NTR9DDR4FCH4', iid='B0091JKJ0M', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3H395FWEN4AYR', iid='B01E4QS95I', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2FQU2MZBR2JWV', iid='B00BXLSM0A', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3GJ0ME0T16IIO', iid='B00PG9870U', r_ui=5.0, est=4.7381601239227855, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1IWJ6TXCUGXBF', iid='B00FTGSKL6', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A123IIX1Z50O9U', iid='B00JDQJZWG', r_ui=4.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2RTTRR421J9KG', iid='B00PG9870U', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A14H5YYC6WRY88', iid='B00ADR2XIC', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3J48YHTXF07FC', iid='B00FTGF3P2', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1CCSBUDVPRO8Y', iid='B00FTGF3P2', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A14H5YYC6WRY88', iid='B0091JKJ0M', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A2AWS633WWTXFX', iid='B00HLAO65M', r_ui=5.0, est=4.795485074632579, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A3CHNGUSZR497B', iid='B00BXLW5QC', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AXSVY0U0NVL89', iid='B0091JKJ0M', r_ui=5.0, est=4.9743589743589745, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ADL4AT0OZ9IS6', iid='B00AR51Y5I', r_ui=5.0, est=4.964701403143755, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A28MI0OGL4S2BB', iid='B00BXLTUBA', r_ui=5.0, est=4.924277907884465, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1QIDC5ILLFYGB', iid='B01B25LFGY', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1PGEVY0S98WCC', iid='B014S24DAI', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2DIIBPEA3CTXL', iid='B0091JKVU0', r_ui=5.0, est=4.898305084745763, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2RTTRR421J9KG', iid='B00JJ59UA8', r_ui=5.0, est=5, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='ATZR7KHUSFX3K', iid='B00JDQJZWG', r_ui=5.0, est=4.955051952882882, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AWVA67A1LIEXB', iid='B00BXLVE6Y', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3OZ1Q3VI8H8EO', iid='B00GOLGWVK', r_ui=5.0, est=4.886792452830188, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AF5DE7E49647T', iid='B00ELQD11E', r_ui=5.0, est=4.625, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1FKMXROBDOI7W', iid='B015WY0DOQ', r_ui=3.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A30LWSTIFT6LJB', iid='B00GOLGWVK', r_ui=5.0, est=5, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A1TCBHXA93SDOW', iid='B014S24DAI', r_ui=5.0, est=4.995337995337995, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3UD0L5MQNQKG9', iid='B00ET5WASC', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3LT61TE9F13YF', iid='B00BXLTUBA', r_ui=5.0, est=4.809523809523809, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1C1YNIRA6OSMQ', iid='B00KV30IHG', r_ui=5.0, est=4.888888888888889, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A11X3NZ01RLQYZ', iid='B00ADR2XIC', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1EN789V0ZI7BQ', iid='B00GOLGWVK', r_ui=5.0, est=4.928459119496855, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2P6CE40SQB90M', iid='B00P3DUFRW', r_ui=5.0, est=5, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A2CM3SWOMP3A9C', iid='B0091JKY0M', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2AQXLQBQ9DDLY', iid='B00AS527QW', r_ui=5.0, est=5, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A2LNRXH1S0EH1H', iid='B0188LO3UK', r_ui=5.0, est=4.383678255819667, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2VIPI69EC0N1F', iid='B0091JKJ0M', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1DWCUOCK2EKCG', iid='B01FYJMJHI', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1MJFUM51NG1IQ', iid='B00FTGTIOE', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AAD9PJLHYQXHB', iid='B0091JL3OI', r_ui=5.0, est=4.922446406052964, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3JOKTA79FF9ZO', iid='B00F2RZMEA', r_ui=5.0, est=4.837837837837838, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A37CORPQS3IVD0', iid='B00GOLGWVK', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A3JRBFPC9U5LT8', iid='B00CHQ7I2S', r_ui=5.0, est=4.979130973550653, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AF5DE7E49647T', iid='B00BXLVFAO', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A28DC3TXTBUV96', iid='B00P3DUFRW', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3BZAHYJ1UIIEU', iid='B0078EPBHI', r_ui=5.0, est=4.8430127054879675, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A6CGXL9SR42M0', iid='B00P3DUFRW', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3BZAHYJ1UIIEU', iid='B00FTJI60I', r_ui=1.0, est=4.496741799250518, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='ADGKZ1FXY3DRE', iid='B01B25LFGY', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ATDJ6NCKR2VLE', iid='B00PG8502O', r_ui=5.0, est=4.9180207457444025, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='ASWJYDUI75UD2', iid='B01CZ54L66', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2LNRXH1S0EH1H', iid='B00HLAO65M', r_ui=5.0, est=4.854469854469855, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1U1G73EI5IRZF', iid='B0078EPRPE', r_ui=5.0, est=3.808523143920969, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A1Y1SGZB6T9RYM', iid='B00MV9O08G', r_ui=5.0, est=4.762162162162162, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A6MEGFLO6NT4L', iid='B00OX9OKO6', r_ui=5.0, est=4.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ADFC4YK6CC9C1', iid='B00BXLVHZM', r_ui=5.0, est=4.739130434782608, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3LT61TE9F13YF', iid='B00FTGTIOE', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1K78G1I46XN4O', iid='B01H5PPJT4', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A37CORPQS3IVD0', iid='B00AR51Y5I', r_ui=5.0, est=4.949367088607595, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A15NY62RL9WFIO', iid='B006PJHS50', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A35ZJY01RQSY5O', iid='B01E4QQ6QM', r_ui=3.0, est=3.6074310064399544, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A2PHOTTFXUGB7V', iid='B01E4QPDV6', r_ui=3.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A9J7798EZ7F8C', iid='B0091JL3OI', r_ui=5.0, est=4.8076923076923075, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AGJAI24VR1C5U', iid='B0091JKY0M', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='ASMBYX11IUPJR', iid='B0188LO3UK', r_ui=4.0, est=4.817124355011854, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AARJP1PJV9OMN', iid='B00S5JE4PU', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3BPXL02KIHS47', iid='B00CHQ7I2S', r_ui=5.0, est=4.9879171869534975, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='ANDVICVXBOXGN', iid='B01E4QPDV6', r_ui=5.0, est=4.973250857205053, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A1LCT6F9JL6P7C', iid='B00KV30IHG', r_ui=4.0, est=4.888888888888889, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2EMTLQJQS9PQJ', iid='B00BXQIGA6', r_ui=5.0, est=4.935755147489031, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A36S68IV7UQ7D9', iid='B00DNAGTIQ', r_ui=5.0, est=4.906382978723404, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3VN3FXPVOEHGD', iid='B00BXLSZPM', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AILCRSJ7NXB1L', iid='B01E4QUN0W', r_ui=5.0, est=4.998868104593396, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AOI2LGQR941L7', iid='B00FTGESM6', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2TZK0F2X8EIVA', iid='B01E4QPDV6', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='ARZLW6MFV58E9', iid='B00JDQKFPC', r_ui=5.0, est=4.933333333333334, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AKMEY1BSHSDG7', iid='B006PJHP62', r_ui=5.0, est=5, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A2WPBMZ2ISXTSA', iid='B00CHQ7I2S', r_ui=5.0, est=4.871794871794871, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A333GGTZSUJC30', iid='B006PJI03Y', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AYPZMUSCTT46O', iid='B00S5JE4PU', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AFOKMN2M7MGQK', iid='B00BXLVHZM', r_ui=5.0, est=4.802004611501113, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2630ATALYRS6K', iid='B00ADR2XIC', r_ui=4.0, est=4.559063048924609, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2CGORRQGDEL37', iid='B00BXLW5QC', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AQ2S8N5JQW6LB', iid='B00BXLSZPM', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2W3RQOSC87P4A', iid='B00JDQKFPC', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A24ISEVWULRQXW', iid='B00BXLW5QC', r_ui=5.0, est=4.987722978181728, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A2RTTRR421J9KG', iid='B00DNAGTIQ', r_ui=5.0, est=4.885852345356522, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1L4GG3FBMIG6V', iid='B01FERR9FW', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2C1R5BBL1WXTB', iid='B00BXLVHZM', r_ui=5.0, est=4.772759117357767, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A2C1R5BBL1WXTB', iid='B0078EPBHI', r_ui=5.0, est=4.928369383386919, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A28DC3TXTBUV96', iid='B0188LOK7G', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AARJP1PJV9OMN', iid='B00CHQ7I2S', r_ui=3.0, est=2.9917948717948715, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A9T9SO0VP3QA0', iid='B00BXLW5QC', r_ui=5.0, est=1.2936170212765963, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A175XXVMLQA98A', iid='B014S24DAI', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2QKY7ZG920FT7', iid='B00EEHV8DI', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3BTZ27R4XTL19', iid='B014S24DAI', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2XVDYOW18FNMJ', iid='B00GRLUECA', r_ui=5.0, est=4.894736842105263, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AF5DE7E49647T', iid='B00BXLVHC0', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1KU8DS7KA7OYT', iid='B00FTGTV4Q', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A7WQRCJRV6LWB', iid='B00HLAO65M', r_ui=5.0, est=4.6923076923076925, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A125P742OY9R8Z', iid='B00PG8502O', r_ui=5.0, est=4.923917137476459, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='ABWSFKJ1MRN1Q', iid='B01FERQPAM', r_ui=3.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1JE5NEAFE9SV3', iid='B01E4QUN0W', r_ui=5.0, est=4.984334825836359, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1U1G73EI5IRZF', iid='B00BXLW4Q8', r_ui=5.0, est=4.567248401922103, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A3AOM70ZI312W2', iid='B00GOLH84U', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A10CJ0DWV2M12X', iid='B00MV9N316', r_ui=5.0, est=4.406152808784086, details={'actual_k': 2, 'was_impossible': False}),
# ...
#  Prediction(uid='AAE05KS3NMVPL', iid='B01E4QUN0W', r_ui=5.0, est=4.999852341040488, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A3CX6XW2EG15QW', iid='B015WY0DOQ', r_ui=5.0, est=4.963208128433681, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='ALMJ3UPQJLH6H', iid='B0078EPRPE', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1SVYJFIASQ46Z', iid='B00GOLGWVK', r_ui=4.0, est=3.97093115155872, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A15FGESGPI84VP', iid='B00JJ59UA8', r_ui=5.0, est=4.9, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3FWMBEGL6C665', iid='B006PJHPV2', r_ui=5.0, est=4.636363636363637, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2S1WMTSRVLCN9', iid='B00CHQ7I2S', r_ui=5.0, est=4.982905982905982, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2GKZPASOVZ4DM', iid='B0091JKVU0', r_ui=5.0, est=4.949833260744951, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2VZWIEOT8UVIR', iid='B00O4I5HWA', r_ui=5.0, est=4.778846153846154, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2WZZQ6FR13T3T', iid='B00BXLTUBA', r_ui=5.0, est=4.809523809523809, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2QKY7ZG920FT7', iid='B0078EPBHI', r_ui=5.0, est=4.596100265049483, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A2QARZA980DE7S', iid='B006PJHP62', r_ui=4.0, est=4.379972405068445, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A2QHY2VA7AZEL2', iid='B00ELQD5K6', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ABKP22S8RXAAJ', iid='B006PJHP62', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1DWCUOCK2EKCG', iid='B00MV9OQYO', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A11P365785M5XM', iid='B016CICYXO', r_ui=5.0, est=4.941666666666666, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A348GXFNYRHI22', iid='B01FERR1VE', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3OHGWD8LIDZ8K', iid='B00BXLW5QC', r_ui=5.0, est=4.935752395237976, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A1U3DENVSYZ5BQ', iid='B00CHQ7I2S', r_ui=5.0, est=4.871794871794871, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1ISQ4BFCCGKVY', iid='B00BXLT1UA', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2KOKSKEDIBRGQ', iid='B0091JKVU0', r_ui=3.0, est=3.0094161958568737, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A138CUKESU7PIX', iid='B00AR51Y5I', r_ui=5.0, est=5, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A2P6CE40SQB90M', iid='B00BXLW4Q8', r_ui=5.0, est=5, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A15FGESGPI84VP', iid='B00FTGSKL6', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3JOKTA79FF9ZO', iid='B00BXQIGA6', r_ui=5.0, est=4.875, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3MXDV25XUTB16', iid='B01FERQPAM', r_ui=5.0, est=4.1923076923076925, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AYPGDJ2X47CIW', iid='B00ET5WBU4', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2HYGTHB4LJ9FW', iid='B01B25LFGY', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3OFTIM87CP08T', iid='B00BXLSUF2', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3KIBFTS3ES1T2', iid='B01E4QQ6QM', r_ui=5.0, est=4.88676241570938, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3VZ1JUAW5IYR8', iid='B01E4QPDV6', r_ui=5.0, est=5, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='AETR739T7Z70K', iid='B00JDQJZWG', r_ui=5.0, est=4.919675988597052, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='ACCXISPR2ASZA', iid='B01BLV4R8M', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A28YGUP7ZFI6PP', iid='B01H5PPJT4', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3BZAHYJ1UIIEU', iid='B00AR51Y5I', r_ui=5.0, est=5, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='ALQUMN89FI5HD', iid='B00UW1CEMY', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1U1G73EI5IRZF', iid='B01E4QPDV6', r_ui=5.0, est=5, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A1IBN28RK6OFSP', iid='B006PJHP62', r_ui=2.0, est=2.171826885990544, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A35PR9CBSXMNO6', iid='B014S2HRVK', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AYPGDJ2X47CIW', iid='B00FTGF3P2', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1WC5ETRY53R2P', iid='B00P3DUFRW', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2P9CF2457P7J1', iid='B00ELQD11E', r_ui=5.0, est=4.578212564530228, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3GJ0ME0T16IIO', iid='B004Q7CK9M', r_ui=5.0, est=4.1797208120647875, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AYPZMUSCTT46O', iid='B0091JKJ0M', r_ui=5.0, est=4.985450391706417, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1YXA1KL03KML', iid='B01E4QPDV6', r_ui=5.0, est=4.991692745951035, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='ATZ9ZSR664K54', iid='B00AR51Y5I', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A38DRHN4C89VWY', iid='B01E4QRAX0', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2YSO316K2D5MK', iid='B00ET5WASC', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A33N3U5Y2BVSIL', iid='B01E4QRAX0', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A35ZJY01RQSY5O', iid='B01E4QPDV6', r_ui=5.0, est=3.282272122331886, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A1QZ08NSDCZBA3', iid='B01E4QPDV6', r_ui=5.0, est=4.97848847088651, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='ASWJYDUI75UD2', iid='B00BXLVAD6', r_ui=5.0, est=4.895822776279651, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='AZ09GH240Q557', iid='B00O4I5S7O', r_ui=5.0, est=4.9593613933236576, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A6RN8JWGV20PT', iid='B01E4QQ6QM', r_ui=5.0, est=4.972083125276009, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A3JT9D014239AO', iid='B01FERQPAM', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3BJVPWDEUJHIY', iid='B0078EPBHI', r_ui=5.0, est=4.953316065319084, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A2LN59TG9PA926', iid='B00PG9870U', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1TCBHXA93SDOW', iid='B00CHQ7I2S', r_ui=5.0, est=4.871794871794871, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='ALMJ3UPQJLH6H', iid='B00GRLUECA', r_ui=5.0, est=4.937290033594625, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AV5VSJDEEZIBN', iid='B00IGYPALG', r_ui=3.0, est=4.9, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A6MEGFLO6NT4L', iid='B00MV9O08G', r_ui=5.0, est=4.6, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A9RFZUK1R1DPR', iid='B00MV9H6VY', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A125P742OY9R8Z', iid='B01E4QUN0W', r_ui=5.0, est=4.96439768332754, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1G2TIZW7OJ4I7', iid='B004Q7CK9M', r_ui=5.0, est=4.885245901639344, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1U1G73EI5IRZF', iid='B016J1LGPG', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1MYVI4E6ZCLHE', iid='B01E4QUN0W', r_ui=5.0, est=4.980681334171849, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A37CORPQS3IVD0', iid='B00DNAGTIQ', r_ui=5.0, est=4.930451593009259, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1NWGBDJ06W9BH', iid='B01FERQPAM', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A182B2JKKMI6DM', iid='B00AR51Y5I', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A12YA3BE6TJK3U', iid='B01E4QPDV6', r_ui=5.0, est=4.997035158825895, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A2UAWNUKHPNXBJ', iid='B00BXLW5QC', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2CUBTVB712ZW3', iid='B00CXZPG0O', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1D38S3FRJTOMX', iid='B00FTGSBBA', r_ui=5.0, est=4.8, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1NTR9DDR4FCH4', iid='B00CHQ7I2S', r_ui=5.0, est=4.9917948717948715, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2QARZA980DE7S', iid='B00BXLUDXO', r_ui=4.0, est=4.134275339171477, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A17WJKTK88DY0C', iid='B0091JL3OI', r_ui=5.0, est=4.876986346018108, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A2EMTLQJQS9PQJ', iid='B00MV9GGEC', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ACK7HEPP1HW8S', iid='B00BXLVAD6', r_ui=5.0, est=4.785714285714286, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1LIO5JM3K8O28', iid='B00FTJI60I', r_ui=5.0, est=4.934195064629847, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A300JMW5AMQ4UR', iid='B0078EPRPE', r_ui=5.0, est=5, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A13OFOB1394G31', iid='B01E4QUN0W', r_ui=5.0, est=4.88, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AEGP5NUG8YFS0', iid='B01E4QUN0W', r_ui=5.0, est=4.88, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1NA33MSDOA41K', iid='B015WY1JDK', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2A8YBVMJCO71I', iid='B00MV9OQYO', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2QKY7ZG920FT7', iid='B004Q7CK9M', r_ui=5.0, est=4.574585250654425, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1EKEP11L6DPIM', iid='B006PJHP62', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1VZMC04HF3FWV', iid='B00GRLUECA', r_ui=5.0, est=4.894736842105263, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2CHMYBZTQEK50', iid='B01H5PPJT4', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2R2WCEUJHAV7D', iid='B01B25L7US', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1EAL14H9EIX3F', iid='B01E4QPDV6', r_ui=5.0, est=4.894736842105263, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2TZK0F2X8EIVA', iid='B004Q7CK9M', r_ui=5.0, est=4.984965678571033, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3MXDV25XUTB16', iid='B01E4QQ6QM', r_ui=5.0, est=4.866666666666666, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AYSOAWLV2LCCG', iid='B00CHQ7I2S', r_ui=5.0, est=4.94747588417425, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A35ZJY01RQSY5O', iid='B0091JL3OI', r_ui=5.0, est=2.1943967649155134, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1HNDJ1Y6EB5EQ', iid='B00CHQ7I2S', r_ui=5.0, est=4.9917948717948715, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1U3DENVSYZ5BQ', iid='B0080IR6BA', r_ui=5.0, est=4.988062059230683, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A25POI5IGGENPM', iid='B01E4QUN0W', r_ui=5.0, est=4.999385939519324, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3R3UC3SWC7RIL', iid='B004Q7CK9M', r_ui=4.0, est=4.35401853453526, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1TCBHXA93SDOW', iid='B004Q7CK9M', r_ui=5.0, est=4.885245901639344, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AUTIFERZSY9B2', iid='B00FTJI60I', r_ui=5.0, est=4.923227909699418, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3GPR4SKRP0QNR', iid='B00BXLTR6S', r_ui=4.0, est=4.875, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3OHGWD8LIDZ8K', iid='B00BXLVE6Y', r_ui=5.0, est=4.9778235044153964, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A27E3CO88L5D6F', iid='B0091JKJ0M', r_ui=5.0, est=4.9743589743589745, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A195U6GX56H2PC', iid='B00MV9H6VY', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AKABUMXBAC69W', iid='B014S24DAI', r_ui=5.0, est=4.96969696969697, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A17PNZL8SLGRG8', iid='B006PJHP62', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2RV5MAIOHKMW0', iid='B0078EPRVS', r_ui=5.0, est=4.8150023665096695, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2RTTRR421J9KG', iid='B00F2RZMEA', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A90F0XHX30G4F', iid='B014S24DAI', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1GQAKL9CGQLP1', iid='B0188LO3UK', r_ui=5.0, est=4.8920634920634924, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2WCRWBZJETE17', iid='B004Q7CK9M', r_ui=5.0, est=4.9981288330407, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A18FM0A09F4VI9', iid='B016PASEN8', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1WLQZOGXNQQC8', iid='B00PG8502O', r_ui=5.0, est=4.927485380116959, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3UYNGXBNCBLHW', iid='B00BXLVHZM', r_ui=4.0, est=4.739130434782608, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2Y9R4IWK1ANBN', iid='B00BXLSZPM', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3FMYD94ZH4TBD', iid='B00MV9GM8W', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3BTZ27R4XTL19', iid='B00JDQJZWG', r_ui=5.0, est=4.99664163903242, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3AOM70ZI312W2', iid='B00ELQD11E', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1FKMXROBDOI7W', iid='B00AR51Y5I', r_ui=4.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AN7NSSEVCS3DS', iid='B00MV9H6VY', r_ui=5.0, est=4.928571428571429, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3Q0MGLP821SHF', iid='B00BXLW5QC', r_ui=5.0, est=4.92360182414518, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2VLZZ3G2IK5KP', iid='B00BXQIGA6', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A11X3NZ01RLQYZ', iid='B0091JKY0M', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A36S68IV7UQ7D9', iid='B00BXLVFAO', r_ui=5.0, est=5, details={'actual_k': 4, 'was_impossible': False})]

# %%
print("Item-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# Item-based Model : Test Set
# RMSE: 0.4484
# 0.4483574473278089

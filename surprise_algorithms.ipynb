# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from random import sample
from surprise import KNNBasic
from surprise import KNNWithMeans
from surprise import KNNWithZScore
from surprise import KNNBaseline
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
import os
from surprise.model_selection import train_test_split

# %%
raw_data = pd.read_csv("Data/Gift_Cards.csv", names=['Item', 'User', 'Rating', 'Timestamp'])
data = raw_data.sample(n=30000)
data.drop(['Timestamp'], axis=1,inplace=True)
data = data[['User', 'Item', 'Rating']]

# %%
data
# Out:
#                   User        Item  Rating
# 52232    AL62UO713MU4Y  B0091JKJ0M     2.0
# 9989     AI07W4LXAXWND  B004LLILO6     3.0
# 104838  A2W6OSOAD3PNNB  B00JDQJZWG     5.0
# 139208  A1IMVS3FZ49YMW  B00BT1XFBU     5.0
# 96472   A13B5IO3B5SOHF  B00H5BMVG8     5.0
# ...                ...         ...     ...
# 36405   A1R4L0T4FZ6G89  B005ESMJ02     1.0
# 10323   A2GGCMT8W2WGHR  B004LLIL3M     5.0
# 101302  A3N2XM7MMDLVS9  B00IYVZ6MY     5.0
# 105264   AL5SQKHRN6E9P  B00JDQJZWG     5.0
# 105946  A17BP5EMRTEMQT  B00K4PIL84     5.0
#
# [30000 rows x 3 columns]

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(data,reader)

# %%
trainset, testset = train_test_split(data, test_size=0.3,random_state=10)

# %%
algo = KNNWithZScore(k=5, sim_options={'name': 'cosine', 'user_based': False})
algo.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='A30MV56YIP32KW', iid='B0066AZGD4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BC4S9XZV6D50', iid='B00BSXWO52', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADGKZ1FXY3DRE', iid='B01B25LFGY', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1V2LYS3JB5GCU', iid='B00G4IV2VI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37CI026BOMQ9J', iid='B004LLIKVU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BZYIPH3AYZVO', iid='B00H5BMH44', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8CM0B9F47Z99', iid='B0091JKJ0M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3NGQPARZUE954', iid='B004LLIKVU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9KH6RZF95YQU', iid='B004KNWX3U', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A24RHUFVZZCROH', iid='B00P9VHCBU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LQWEXH9KF6UO', iid='B00H5BOF26', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TBEELDTPIT1U', iid='B0062ONJEM', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3L9PE9IAAQPVN', iid='B00Q5BN3P2', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2UM8GFT9NAQ26', iid='B00CRQ4CF4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Q7WCGZEF94AY', iid='B00E1QB4U4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8WLHGCFNAQRW', iid='B00G4IV2VI', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASGBJSWQ9W8GX', iid='B004LLIKY2', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WCAUEOOXEGN1', iid='B00B2TFSO6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2IRCN0XU7LKA0', iid='B00BXLURUI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PE73PHK23HDM', iid='B0091JKVU0', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NRUIUOZ45XFR', iid='B00G4IUURA', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ESHEBVAET8EM', iid='B0066AZGD4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JR6PX63GWJI9', iid='B00G4IWEZG', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YBE8R6VRIM96', iid='B004KNWWU4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LYJA4XTB7UQ2', iid='B00ELQD0DS', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AT7ZGM09BMEI0', iid='B00MV9H6VY', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Q3S0HMKZ9QKV', iid='B00BXQIGA6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FHGE3STSEVPC', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A30MIG5O6SREEG', iid='B00FJ4CDGQ', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABUC9UA133V32', iid='B01E4QRAX0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A28E1FP7YL68X2', iid='B00B2TFSO6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2I2F15X2HND1R', iid='B005DHN6E2', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A27BEQWKGUVSRM', iid='B004LLIL5A', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QEKJT3MM4AF3', iid='B004Q7CK9M', r_ui=5.0, est=4.649616368286445, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A294Q9NEJC0BFZ', iid='B00KV30IHG', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WXXI2BGHWKYS', iid='B005DHN6E2', r_ui=5.0, est=4.999279561294341, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AUCF3PTW0YP2R', iid='B00H5BMF00', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A169ME2XWWC5UR', iid='B00KFLZVQM', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32AWJAXQZDZ1W', iid='B0066AZGD4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A233TIRHCO6GDO', iid='B006PJHP62', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PVDRKJ6HP7RH', iid='B007V6ETDK', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37E3V4E0JZSF9', iid='B004Q7CK9M', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TN0TB20T6IJG', iid='B0091JKY0M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32783ASXH5UB3', iid='B004KNWX3U', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TTLQ599KE8QX', iid='B00CHSWKEM', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQPMZDAFNQP5A', iid='B0091JKJ0M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JWO119I5D8PI', iid='B004KNWWV8', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XSEMOMKK3QW4', iid='B0188LO3UK', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FFPQ8LHCTRZ4', iid='B00KV30IHG', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3UFMLO3A08RCF', iid='B00B2TFURQ', r_ui=3.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3A8ITQLQPILNI', iid='B018UPUQ5A', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A30HJQLH98VY63', iid='B006PJHPV2', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18TWE0WAMMKIP', iid='B00BXQIGA6', r_ui=5.0, est=4.453781512605042, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A33R334D6R84TC', iid='B00H5BMMVW', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3Q9OKMMO9HW11', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2L7AMF5YBILTA', iid='B00JDQJZWG', r_ui=5.0, est=4.713024282560706, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1TTCUO9EH2F8K', iid='B014S24DAI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AEIBZJJGZ8BI2', iid='B00H5BNOMI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FD5HMU6M9LLW', iid='B00G4IV2VI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGNDK2JPRY4EZ', iid='B00BXLSSOU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2B98CSJJVIHMM', iid='B0091JKVU0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1APUC8IRMU1RT', iid='B00BXLUFQ4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADDZ7P3Q8EB6C', iid='B014S24DAI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QX6UJ91ION23', iid='B00CXZPG0O', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASK4K2JSMLZBT', iid='B00GU2ZZ8Y', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2S59XUMWX26YI', iid='B00H5BMIHA', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3NSY4G0D88ZGR', iid='B00AF0K90Q', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2K7LDTUB0ZOWB', iid='B004LLIKVU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A33PSMPYA7GWHB', iid='B00P8N3QLY', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2N3BP1J6X8WW3', iid='B00B2TFSO6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ALQQ6ZBGMQV6', iid='B00FTJI60I', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22MXE92UFGQG2', iid='B004LLIL2I', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A375WGB3T2VZ0G', iid='B00MV9L0PW', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FDCKOOIBKSEY', iid='B004KNWX94', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQVPYF87SQF6S', iid='B00MV9N316', r_ui=5.0, est=4.76, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A21XV41X4JXRFN', iid='B01E4QPDV6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3UR48KLK7TFFA', iid='B018UPUQ5A', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXPMCSTRNMSUT', iid='B00H5BNIR4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GLPW8SIWVHS7', iid='B00AS527QW', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HP6GUB53AQCT', iid='B001GXRQW0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HS5D7NJPND84', iid='B00911NGTG', r_ui=5.0, est=4.7727272727272725, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2YVZ7R015TUAN', iid='B00BT1XFBU', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CF23230N6UHD', iid='B00H5BM3L6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TLPL2VIM8THP', iid='B00BT1XFBU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2EL9Z15C7GSA7', iid='B00G4IWEZG', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3SBQ4PDVSDPCE', iid='B0091JKY0M', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3F3JFEFDDBKH7', iid='B006PJHP62', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1I8M1M1GTWM2F', iid='B004LLILMI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A16TMLWXLBCLLZ', iid='B00BXLVHZM', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3L4KSYYHY03T', iid='B004LLIKVU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AS0U972UALMQT', iid='B00HI3QRZE', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1AHOCK06CAZ3O', iid='B0091JKJ0M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3NF164LUTT60Q', iid='B005ESMJ02', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39LROEBW3OSYR', iid='B005EISPLE', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1F6L5YHFERYKF', iid='B007EE5YMY', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AL6C4MOP0VCMT', iid='B004LLIKY2', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LNMZIQ1T8MFT', iid='B00PABVTS6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2QECWEN7ECX1O', iid='B00P9VEQF0', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2UE8ZF27F9WPN', iid='B006PJI0Y8', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGDQFNO7EXEFQ', iid='B004KNWWMW', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A28HH42N10IOIM', iid='B00OH7ZB2O', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WZZQ6FR13T3T', iid='B00O4I5S7O', r_ui=5.0, est=4.52, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AWR7X9UQT7MDW', iid='B005ESMJ02', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32UIZ98J12SRN', iid='B00G4IWDXE', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38N2AZ2AC7YQR', iid='B00H5BMH44', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XSKJGY3622LV', iid='B001GXRQW0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANI6846KWA6NQ', iid='B0066AZGJI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AFFWFS29VEU0I', iid='B0189TCA7E', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3ABYP13RARJVC', iid='B00AS527QW', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AEDVG8PNCYBQ9', iid='B004LLIL32', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9F8P9LEE3EEV', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1DRMC38NSULJJ', iid='B00I542DM6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHXK89X1G0MNP', iid='B0091JKY0M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Z6SM93P8114I', iid='B0145WHNXA', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OOROY105XME2', iid='B01E4QUN0W', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22AIQY9T0O4KP', iid='B004LLIL6O', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Y4FAFFHHXHZ2', iid='B00G4IV2VI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CF7X6BUGRVW1', iid='B0091JKVU0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25RVG8V8HK9JD', iid='B00H5BMVG8', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AP856479OWV9', iid='B00KV30IHG', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASTY2IQJGWZNV', iid='B00CHQ7I2S', r_ui=4.0, est=4.107661153773322, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AQ2A4EJJAKW80', iid='B0091JKVU0', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37MNYQNMNAOU7', iid='B00H5BNENW', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19E7Q9EUNBV1S', iid='B00BXLW5QC', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3I4GAXWCTZKBO', iid='B004LLIKY2', r_ui=3.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HID8WRMR2101', iid='B00HLAO65M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HVSD7XUKXHRZ', iid='B00I542CPE', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1CY9SFCWDUA16', iid='B004KNWWU4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38U1K049PJBUO', iid='B00BXLSIJ0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3B8OUCCPBYY78', iid='B00JDQKFPC', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15FOD1Z7T7DTX', iid='B004LLIL4G', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RRRBNQ898LWG', iid='B00CHQ7I2S', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YVI6XT80SZVZ', iid='B00JQKJO6G', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WA34BWJZG723', iid='B00BXLURUI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NOSKVH8Q753L', iid='B00BXQIGA6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='API74HU70GT9D', iid='B004LLILGO', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AUN5JGLKP8UW9', iid='B0091JL3OI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29VORO3GETU2U', iid='B00MV9LHPU', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HMMFGJY8MRH7', iid='B00G4IW690', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KVP1U2F9JZTV', iid='B004LLIL3M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QNMV3KCZEFDC', iid='B00BXLW4Q8', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GV3V823S56FB', iid='B004LLIL5A', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WVKWBLDS0PED', iid='B0188LO3UK', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVAG8DFKYQB0X', iid='B01B25LU7S', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALQQ05PQGJXR3', iid='B004KNWX3U', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1I9RN4ILY8J0X', iid='B00ELQD11E', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ZLWQ83DWBI96', iid='B007V6ETXA', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYQH52KGV4C26', iid='B00GOLQ9AY', r_ui=2.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1AX1WIWFO9Q4N', iid='B01B25L7US', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MEIJJ78G2E8N', iid='B00I5426SM', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1H7J6CELFJF7X', iid='B004LLIL2I', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQVAP6ZWUPGC3', iid='B0066AZGD4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A17VMAJFZRX3U7', iid='B00BXLTR6S', r_ui=5.0, est=3.2888888888888888, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='APMJNEQQHH9WP', iid='B00H5BMH44', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1HUMB887UAR7U', iid='B004KNWWOK', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LQ032CAHH1XP', iid='B005ESMMWW', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2O7XDUJ5TB97E', iid='B014S1KPKG', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NGGUGIAQDY46', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2XCVX54SRZ0Q4', iid='B0091JKVU0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3CE05E6Q4LDM2', iid='B00BWDGYL8', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MQG691YWM6K2', iid='B005ESMJ02', r_ui=5.0, est=4.633333333333334, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1XHK33WBGVHFP', iid='B005EISOUQ', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3VD0TUQ4LRVJW', iid='B00CHSWGR8', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAH2VI3PLF1DP', iid='B014S24DAI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3RSDHV4880GND', iid='B01E4QUN0W', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A23GLRRZ8S56HC', iid='B004LLIL2I', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1TEEGOHZ4HR9H', iid='B014S24DAI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AUQVK2V0FDAYG', iid='B00H5BMH44', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IA9MVREZINT3', iid='B00CHSWJPC', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12UTVNSA8LR4J', iid='B00G4IV2VI', r_ui=2.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HII376FU3XBO', iid='B00MV9GGEC', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1U1G73EI5IRZF', iid='B016J1LGPG', r_ui=5.0, est=4.653846153846154, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A34ISGQOXJ8ZGY', iid='B00CHSWGFU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3SE7GWFO924VR', iid='B0091JKY0M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YTXU5V9OEF69', iid='B005ESMMWW', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A27B01WGQH5E3Y', iid='B01E4QPDV6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BVOIMKKW6VWD', iid='B00MN5VAWC', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AM3HF8SVLVXMY', iid='B01E4QUN0W', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2X8VNSCRUA1U6', iid='B0091JKJ0M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2A3XMD6NJZNPD', iid='B00BXLW9J0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVIEJXUTJUDR5', iid='B01E4QS95I', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AI5AWLFQ93DPG', iid='B00H5BMH44', r_ui=3.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1SQWZAL6PRLU3', iid='B00BWDH0LQ', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LT21RMYNS7JS', iid='B004LLILF0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21XK6UNK3P4HI', iid='B00C5UMEMA', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AKKR6GJFC6SGB', iid='B004LLIKVU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2L1F1NTHYW3RL', iid='B009HE86FQ', r_ui=5.0, est=4.714285714285714, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AGE1KDO4NEBSJ', iid='B00PG40QOK', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2B8H3BJUAR45Z', iid='B018UPUQ5A', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IQUJT67S5JBK', iid='B00H5BMF00', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3511OC1L324FI', iid='B004LLILLO', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HZZ60X18P9DP', iid='B0091JL3OI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAR752T5OMUQ9', iid='B00H5BMH44', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39ZWTYFT5HHFG', iid='B00MV9GM8W', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3F6ISWFKU99JI', iid='B00BWDHBU6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2YEBQKBSL2Z23', iid='B004LLIKY2', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NOYXBBWMN8JB', iid='B00AR51Y5I', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AS6ABFQAEXQH0', iid='B01B25L7US', r_ui=5.0, est=4.862068965517241, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A32C4HRTZ6QO3Y', iid='B004LLIKVU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3CZVO53OIHIWN', iid='B00CHSWG6O', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6AVNF07FPHCP', iid='B007EE5KKK', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4GHVZCZ8JSOX', iid='B004KNWWTK', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LNNVGP6724UW', iid='B00BWDH7SC', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1L94M5UXWI6T8', iid='B00PMLD91O', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMBN0TB42EUNU', iid='B005ESMJCU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A163WCR7QQ5GY1', iid='B00H5BNENW', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32N7XMJWAI4Q9', iid='B004KNWWXQ', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACTR2G6BEVUHS', iid='B004KNWX2Q', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2A0OV5GVZTE5Y', iid='B00G4IV2VI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A13CJWSNJE7A5', iid='B00PG40SDY', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1B6NRK6DMI5N5', iid='B007V6ETDK', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21VBMAFHOLDUG', iid='B00EPLSMGY', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYOF5I1NHFZXI', iid='B005EISOOC', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZNPTMFE59ZJ6', iid='B00PMLDTO6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2C851D8PRIJVR', iid='B004LLILEG', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Y5V70AIE6GL6', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3C5CPTZ8E3UTM', iid='B00CHSWG6O', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3UGDM2DT2GRE3', iid='B01E4QUN0W', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3OTIZALIBKULL', iid='B00CRQ4YDE', r_ui=3.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3O07ISG3YGCBQ', iid='B0091JKY0M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19HYXY4ETPT99', iid='B004LLIKY2', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AZW3EEIISWYQ8', iid='B00BXLURUI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3L0FX610J2UIX', iid='B006PJHP62', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ATDIMSG2L0B8K', iid='B01E4QUN0W', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3G7J8K8DS3JV9', iid='B005ESMJ02', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QNLVPPJXXAHM', iid='B0078EPBHI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NXU13HPBVM7R', iid='B00MV9P8MS', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1C592GOLIB23Z', iid='B004LLIKVU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABAWFE66B0EWA', iid='B004LLIKVU', r_ui=5.0, est=4.983346582553206, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3GJF6Y7ZQPP8C', iid='B00ADR2XIC', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JD7QKV3DS00', iid='B00CRQ4URY', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15W267NR6RO90', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22T92LXK4TFSX', iid='B00AF0K90Q', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A259HN7JK5W13J', iid='B00O3YKR48', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1CFCQ8VIWSHCT', iid='B00JDQJZWG', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A0435668H73OPGIKAVS2', iid='B004LLIL5U', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MW8WQU1VTNEK', iid='B00BXLUDXO', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXO4KM1LTKZFQ', iid='B0091JKY0M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FD3BKI7STWQ7', iid='B004LLILEG', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21A0R9W2GHBS2', iid='B00FJ4CDGQ', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WU0FDJLVKGOC', iid='B004Q7CK9M', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10BP6S6SE5PBR', iid='B00I5428EE', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3UQPQV2FQY7ED', iid='B004LLIL5A', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1HPBRUUOJDIQO', iid='B00Q5BN7BC', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JL7I4Y754JKO', iid='B01GF6X842', r_ui=2.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3H3KECNF1UQ90', iid='B006PJHP62', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JU576Y5Y9J64', iid='B005ESMJ02', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3F4SVL87LAPUF', iid='B006PJHP62', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A264Y8W1CQE08U', iid='B00CHQ7I2S', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A34UB1SWSIRPMA', iid='B00AF0K90Q', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26WVRHJMLVH5V', iid='B0066AZGD4', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29AYGRTJK7QKK', iid='B0091JKY0M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1M37NHLTWR5KF', iid='B00BXLW4Q8', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A28LV4KSNX8VNJ', iid='B00ADR2XIC', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAVXZSLM7XSX5', iid='B00G4IV2VI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1A1EAMN0WVB93', iid='B01E4QRAX0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XQIOP7M55G8W', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARYJP3GAJDX2X', iid='B00CHSWGFU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2KVLNWDZUS9RM', iid='B00CHSWGFU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AZ7UJO22ZOI6N', iid='B01FERR9FW', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1C8PEIMFVWKUF', iid='B00I542CPE', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AOTYECRQA0LDI', iid='B004W8D0Y4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38Y6DSN2G3NOC', iid='B00YD5XWEY', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FPELS3MJ5102', iid='B00K4PIV2K', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2050LITK7YQ5U', iid='B00X6G8J3A', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RPKZX5F33Q76', iid='B016CICYXO', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1J8FCFW59OMWC', iid='B002BSHDJK', r_ui=5.0, est=4.454545454545454, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AP9TCIYC7APLB', iid='B004LLIKVU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A28T3YQKTKUYMF', iid='B004KNWWMW', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QCYYZBKE3MF4', iid='B00BXLTUBA', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3DXXHLHM9H3XI', iid='B00C5UMEMA', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KM585FT2QI8M', iid='B00G08KW2C', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AT9X6W69AE5VX', iid='B006PJHP62', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3USZI6J9UQMU0', iid='B00CHQ7I2S', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2333WM1CMQKJT', iid='B00BT1XFBU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A238XA90TF0AVE', iid='B01G44QKQI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AUU43I22SGCVI', iid='B00BXLUO1U', r_ui=5.0, est=4.833333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1DSLY9R5BD4TW', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3CH367S8UDZ2R', iid='B0091JKVU0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SSPKF2WU70HU', iid='B004RD9ACA', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WELLXD1L8VA0', iid='B004LLIL4G', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CPUSBXQUDI2Y', iid='B004LLIL4G', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QJEIBTMSY92Q', iid='B00JDQJZWG', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QB55Q0AFT4WH', iid='B00PG8502O', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ZUBTUL5380DM', iid='B00FTJI60I', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JJTKCUAZN9K8', iid='B00MV9O08G', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2EZJV50Q51213', iid='B004W8D0Y4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PL9AO5A1TQY2', iid='B004LLIL5A', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BOBMRWIUDVMZ', iid='B004LLILBY', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2K6VQRNSRSZDJ', iid='B004LLIKVU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3CTEZ37RSOW5D', iid='B00CRQ47WC', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5YPELBO80725', iid='B0091JKY0M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3N3RZ04ATBKWC', iid='B014S2HRVK', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQFC1C4JZ5U2R', iid='B004LLILGO', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1EK1O45Y0HB3C', iid='B00E1QB6ZC', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A20LPJZPIM9BTH', iid='B01E4QRAX0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APFMF103YJ8CH', iid='B004LLILLO', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHMHYFDOHWVHJ', iid='B0145WHUP6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1G2CE9GE2F2WC', iid='B00JDQJZWG', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...
#  Prediction(uid='A1KOH7VEZHC4HW', iid='B00YD74M4Q', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38NRHX6AL1XCQ', iid='B01FYJMJHI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3AM6K28K3LAHE', iid='B00MV9GM8W', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMZ1XQLYV7RQP', iid='B01B25L7US', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UEYYIRD58WLM', iid='B004KNWWU4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A20Q1MAIBU8H4Z', iid='B004KNWX6C', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A30CTTS4BCO5G7', iid='B01E4QUN0W', r_ui=5.0, est=4.806930693069307, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AVGLLWPGE3FAF', iid='B004LLIKVU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A310WU4D4OEDFZ', iid='B01E4QQ6QM', r_ui=3.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1L92RYNFQG3J0', iid='B00PG40F14', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RIOZ00JJO9KY', iid='B00S5JE4PU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Y8AMSQ2YT3LN', iid='B00MV9GTFS', r_ui=5.0, est=4.722222222222222, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1TO0N52RCQPL0', iid='B00JDQJZWG', r_ui=1.0, est=4.713024282560706, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AMH7JXL28O2EW', iid='B00JDQKFPC', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JKK175ULMXUR', iid='B00CHQ7I2S', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3M4OLTWL6XTT7', iid='B007EE5PEQ', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CCEE47FIXOTQ', iid='B004LLIKY2', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A151EE6CX153Z7', iid='B01E4QUN0W', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KB4CFWH94GE2', iid='B00A4EK106', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AY0IMIF3K5FCQ', iid='B004LLIL2I', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25B0VS6EGLP96', iid='B00AR51Y5I', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RS442M2COGLR', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2QDVZED8HBJLW', iid='B00P9VD9ZS', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IFNHMDJAWQEM', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3508BASEWUZLM', iid='B004LLIKVU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31O8YZGPQ0SZY', iid='B00MV9GM8W', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2IM76YU9QGS74', iid='B00KV30IHG', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZBJ4AR42IGAR', iid='B00OX9OKO6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALH13KYTCHR1Q', iid='B00CHSWGR8', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JYYMEH82UXZZ', iid='B00OX9OKO6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IK54EYQ64Q5Y', iid='B00AR51Y5I', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NC77EF5YT559', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LWVUYS5Y1T5Q', iid='B005ESMF5G', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A112X3X5HVW9XE', iid='B005ESMF5G', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AH4QG6SIBFCA8', iid='B0091JL3OI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2F7L4290V6CGZ', iid='B00CXZPG0O', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1AFFLKSMNANN5', iid='B0091JKY0M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KM9T93R2HS2S', iid='B0062ONAM8', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QF78HFT3DRGN', iid='B0078EPBHI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1CPSZ7BSLX1RW', iid='B005ESMMWW', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RVBO50A6B3YS', iid='B005ESMJ02', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38RX2KYRELLDJ', iid='B00I5428VM', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JVPFFPYNM33L', iid='B00CHSWG6O', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A28GL4VJ4ROJMY', iid='B004LLIKY2', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MN4LC34MUIN6', iid='B00EEHV8DI', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AWBM388SH9OJJ', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1HQHAIGNL3DGL', iid='B005EISOUQ', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AUOZLVB8WZ5QX', iid='B00H5BMH44', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9MK00SF04CI0', iid='B0091JKVU0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A215HHH0VX845Z', iid='B004LLIKY2', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3CT07NG5GOQOE', iid='B00CHSWK24', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38F9H8BGZU01S', iid='B00H5BMH44', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AV9947XA75GAS', iid='B00GRLGF6O', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1B3NR8BEUBG16', iid='B00PG8502O', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2L6TF69DXF31E', iid='B004LLILGO', r_ui=5.0, est=4.95366092817887, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1L5WI4XQLEXFA', iid='B00CHSWHJK', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9QJ4XZ0WF0VQ', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3CMN34HBZZSZE', iid='B00BXLW4Q8', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NZ6C13F78N2F', iid='B00CHQ7I2S', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1W54U22N1EUSD', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BZ4CU7RT9JYM', iid='B0066AZGD4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1X2NJ87L1HD5R', iid='B01CT5PHJ2', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3VE5FISJ0H07E', iid='B0145WHUP6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A382TR2Z1FD55Y', iid='B005ESMMWW', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2KI16QYGSNEUS', iid='B00I5426SM', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QSK5K3Y3CIV2', iid='B00BXQIGA6', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FB3SEK9LWDKA', iid='B004W8D0Y4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HW8SW2BSJ2MZ', iid='B01CZ54L66', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25BNCT1BBHNOJ', iid='B00ADR2XIC', r_ui=2.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A90P5W40Y289R', iid='B005DHN6E2', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACCP4UK85OZLD', iid='B004LLIKVU', r_ui=4.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3ASX3C7FKDXJJ', iid='B004W8D0Y4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1241RSXXBXDCX', iid='B014S1KPKG', r_ui=3.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JE5NEAFE9SV3', iid='B01FERQPAM', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UQZFEY0WAWNN', iid='B004LLIL5U', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2D3PMLF6SELWY', iid='B00VF0MCCS', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2R40XS40E3K11', iid='B01H5PPJT4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3P4UL5RX7C0AS', iid='B001GXRQW0', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BQO2R6OERG5K', iid='B0080IR6BA', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8F7OVUQ949FE', iid='B0062ONJ6U', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARTOBVGV46OU0', iid='B007V6ETXA', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RRX5XG4ZPUZ1', iid='B00H5BNFJK', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYIT1EFS9SVTD', iid='B001GXRQW0', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3G4C3U479UVX', iid='B00CHSWG6O', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3W3DCFP4GYWLD', iid='B00GRLUECA', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IBVG7WFPSD8N', iid='B00BXLUFQ4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A17X9K3QI7TJI7', iid='B004Q7CK9M', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YD3EUXRYOBMG', iid='B00F2RZMEA', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2C71B6DA19F6X', iid='B004LLIKVU', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OGZA3GR249WT', iid='B005ESMJ02', r_ui=1.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15WZQ4LNYG76F', iid='B00CHQ7I2S', r_ui=5.0, est=4.959933846990946, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3H8AD8L3MSFD6', iid='B00BXLUFQ4', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HWSPIGQLS0B7', iid='B015WY0DOQ', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APYJDUGYJD61P', iid='B00BXLT1UA', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3ENEO67EYOYLO', iid='B0062ONAM8', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1D89J8UN7SUAO', iid='B015NKJ6D8', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MS2CUTYVCCR1', iid='B004KNWWOA', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADXTRKRXTN3FV', iid='B009HE86FQ', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APMJI3BRCH3K7', iid='B00H5BMIHA', r_ui=5.0, est=4.666095238095238, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  ...]

# %%
print("User-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# User-based Model : Test Set
# RMSE: 0.9583
# 0.9582832053224247

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from random import sample
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
import os
from surprise.model_selection import train_test_split

# %%
raw_data = pd.read_csv("Data/AMAZON_FASHION.csv", names=['Item', 'User', 'Rating', 'Timestamp'])
data = raw_data.sample(n=30000)
data.drop(['Timestamp'], axis=1,inplace=True)
data = data[['User', 'Item', 'Rating']]

# %%
data
# Out:
#                   User        Item  Rating
# 839980  A11SSHGSVEK0HP  B01EKUOE1G     2.0
# 157771  A1O834L6Z6JJ1R  B00COM550W     2.0
# 668678  A1FRV055J81WYG  B0112S1YZI     5.0
# 812169   AMBFMS9T3OI5I  B01D1AO8QW     5.0
# 376418  A2DBDBSI8V6OJ8  B01E5T5IR6     5.0
# ...                ...         ...     ...
# 565012  A3EUEW2268UTMH  B00OA5QYZG     4.0
# 460725  A3B0H8SQJF8N61  B00DQYW8RK     5.0
# 650316   A39KK9OK7NXO8  B00YG7RI58     3.0
# 598915   A9QUY6NCUPHJO  B00SM4YF34     4.0
# 325344  A2S7IWJMPETRU1  B016NWTSWY     1.0
#
# [30000 rows x 3 columns]

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(data,reader)

# %%
trainset, testset = train_test_split(data, test_size=0.3,random_state=10)

# %%
algo = KNNWithMeans(k=5, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='AP16TKSDGN6TB', iid='B017IOPIK2', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12OEVO9EBRBDT', iid='B00WLN18OG', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXXHCZJJLYFLL', iid='B0192A3JCO', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZXRFJNGA0WDY', iid='B01DAFK1TG', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2DFR4K08CFXVM', iid='B00DH6LY90', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1VR3L28GGFN6P', iid='B01DJDBG66', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CKGVZ02C82B5', iid='B0163QQATY', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1PJXV5DCI010T', iid='B004MNO0QG', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AOZ0LKSORO3ZQ', iid='B00A3U74RO', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAW7F6ELLFFHX', iid='B00LL20G5U', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IZYINOGWMHJU', iid='B00HK50EQI', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3R581WU0C9AL4', iid='B00WBZUFR0', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2DYEPWNXVJIAR', iid='B0017JF4FO', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3792BYT81CXBQ', iid='B0118O59X4', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ATS1L5W4G87XL', iid='B00JLQL1M0', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A27ID1UXM3O7T7', iid='B00EEYJZGS', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3AYRO8L8KH5Y5', iid='B017PT3BWW', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2B7E1P9E1CEF7', iid='B00DP5NNHY', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3M9VPKYMKM1V6', iid='B00ZGO03PM', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3J9TPAC8DOY8R', iid='B01EC05AZI', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2R7V260R8KD5F', iid='B00TE0TREC', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Y0V3G7LO87GJ', iid='B00FAD21NQ', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A185MY1T3K7D81', iid='B00XFSDPYW', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OQ9VCXUNG706', iid='B00L0X1K1E', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WQ9XKMIGLJXA', iid='B002O90P0U', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AB5Z3BFTMNIC', iid='B00JPRC8I6', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2F2GXZMQ53QVU', iid='B0007PLXO0', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1HIYG0B4X65GD', iid='B00UWUH3NU', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KMM8W9N7QATD', iid='B000G01UBW', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARD5DYFFB0IW0', iid='B00II22V5E', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3B5H91H7PR892', iid='B00PBTAVEK', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A102QGOB4F68TI', iid='B00SKJJ3G0', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3SZ218MYSRRJO', iid='B00IXF7O8U', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1VXP8HP0UR50F', iid='B01GCBB59A', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22QJ761SSJ94H', iid='B00EFLMD82', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RILFUSA8HZAD', iid='B015EZKDLG', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PZK6GQDOOW08', iid='B003ZAH4YM', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AOU5UWJGBF93U', iid='B00MOHESAK', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2W6A2AIR44KYN', iid='B00AECXN9Y', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IWXG8QLDCUIO', iid='B019XNGAXU', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AB7F7WHAVG39Z', iid='B00D5EM1TQ', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BD358SOBPNQD', iid='B0055QNJ84', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AWMSLFBLGQIV3', iid='B00VPQYU8G', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2D798OUKYRAB5', iid='B01AS6H93Q', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31GICBOUJWVUE', iid='B00X9JLQSE', r_ui=4.0, est=2.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A9VL6T8CNIP4H', iid='B01E5DM4WO', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQ2VUR80FF2U1', iid='B01HCJMBTY', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IGI2FDCMTR1T', iid='B0017U1KBK', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3S6BANNCF20CQ', iid='B008YOQ742', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ZACSSPW545Z2', iid='B00X8M1KE2', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACRDWGXWWR84B', iid='B00KBMDCNO', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2X0X8IUY3N698', iid='B00K4C4AJG', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A34P2ADLIVSMT2', iid='B00NFSCWD2', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGGA9WTSDT31T', iid='B01H1SLKN4', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Y9GTKXPFBTG6', iid='B00PKNWQ2M', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A05467882E05R82HOCOI', iid='B010OAMS2S', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39UOUSML9CGGS', iid='B01AP2B94I', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4KOMFXJZ09RX', iid='B00B1UDX98', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1L1NME55YY9TS', iid='B00ACIFQGS', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GWJFBM8CM4QG', iid='B01CP4JL76', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19LTQ956NXN0', iid='B00VFT3BRY', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1B1L8BP69ZK1S', iid='B01C6RNF6K', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21V49F1VW3BIM', iid='B01CU0MK1O', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2C7UM3S9RHR8Y', iid='B00LJMQ9O4', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AEF8XET8I5DOB', iid='B0168F8NSQ', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ATY0W4CP5TH5F', iid='B00EKN4BDA', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3CI8ZGVSPHYDK', iid='B01CV7PLIK', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3I4VAKVR5E4GV', iid='B01EJ4PU4I', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10L3QUQP1YC08', iid='B00ZIAXA9A', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1O1M8WMCFLDQY', iid='B01AYV1WCO', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAQLNCAYRN3L8', iid='B00W3B3ME0', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Q3SF4UBY2OV9', iid='B00POEQJVG', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FMSEQA852NS1', iid='B00WJMGEOI', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A34PCHQ7ISF4EH', iid='B011QXRAN4', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3J1WSINTFWVTC', iid='B005GPITLQ', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39NPUIAQ6S650', iid='B00M3XL90M', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31TU8AOIRY0HH', iid='B00DCZVET6', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2H5TBZCW1IFKK', iid='B0179CESPE', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GFUL31FSFCS4', iid='B00NB28UL0', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5AD9LZXG5UIF', iid='B00CTXVBPY', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21AUCM841YNA2', iid='B00RL1IY8Q', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AZ8DT4GV6E2U1', iid='B00OGR16WO', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JH5V4L5VARMR', iid='B00JKGF2EE', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A11T0SQPDAL91G', iid='B019NU7U96', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A30783HPWI0EX6', iid='B00CZ5007Q', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1CLNP4NQSQKLZ', iid='B0072J8JFK', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ZYLDFKDQ5E83', iid='B00GTR9DQU', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYSG7CGY5TL6R', iid='B00RMVRUCG', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RYP3X8MLEW4N', iid='B01B1WRBIO', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AFE4Y8H0MSORL', iid='B01DTKSY82', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3P3Q5FD16ZZGE', iid='B0068U71DK', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FYJX4NA19OJD', iid='B000GHRZN2', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A104FUDU465BSN', iid='B00V39H4TW', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LF922XA0ITZG', iid='B00L3NTUIG', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AZ4WN4M0TEOCQ', iid='B00BJ67EOE', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJHCE30GK4OGG', iid='B00N5FIBWG', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2S4G61WZHIA0W', iid='B018HH0BLU', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9GC4J4BRGHJU', iid='B000GHRZN2', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1E9CYHEVCKH0Q', iid='B016YPI63C', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AFV290HNX2XWG', iid='B002VJT8HY', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXN2E6DI0ZZMV', iid='B0183JQHCO', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26TAC0KSAXNDS', iid='B015TK5LI6', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NFZ0DER3X3L', iid='B019RKB2FA', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMSS7UHINXEIV', iid='B00HN5BE28', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1W948JERXBOZQ', iid='B0092SVT6U', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NWHTTCEC1I91', iid='B01EFJQFZ0', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHPORIO2HDEMA', iid='B01BFO4EQU', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2YYM50XWHNYGK', iid='B01BI7B4LC', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TWR874VKK7BM', iid='B01B7MW520', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JIHVSM8NDBUR', iid='B00YQ7Y2MK', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2YWSZF8GXUY2A', iid='B017VU1LNG', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A11N9I3EAG3LHR', iid='B00VTSZ8HM', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12V6WM7UFVB82', iid='B00QEQIPJM', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGDOR97QVBKYW', iid='B01CRDO2VU', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXHS45II3BQ18', iid='B01DDEHR64', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TD4EU2JTYX0B', iid='B00V0FO1PO', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21IV5XG2OODL9', iid='B005QSRYIC', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YCGG6S582AZC', iid='B01AQW1XI4', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AH7MST9252NJB', iid='B01FQ114LG', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3UKOT3XGX9OCU', iid='B000V0IBDM', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQR19V90PRRCZ', iid='B00V7GQ23A', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVUWDXRTSSJT2', iid='B007W9ZVME', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BSWS5AES5HU8', iid='B00NLXWXI0', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQG4AHGDMPCK4', iid='B015OXISV0', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A209H59UUU3BN3', iid='B00NB6QQEO', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IQM3RAKXBZG2', iid='B01F6MVRLM', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHF8SBFHS4G6C', iid='B01FPXBR8K', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AUQALVWEAP25S', iid='B00MH5ICN8', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A231SJWVFPT5JT', iid='B01AQW1XI4', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1G1WOD5R3MN2', iid='B008J7BCHG', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BT7M2QRHE1SL', iid='B00YP2TNZ2', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JQ0PHSAWAQOX', iid='B00NJKVL4W', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ZDYBT568TH88', iid='B00I1B29XG', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18NBET8BMH9EG', iid='B00YDMVY38', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37XO4MNXXS57N', iid='B00QV945H8', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BCBPXKAMZ7QA', iid='B00OH6EOGO', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25YBP2AJUBLWA', iid='B013HBMAQU', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3UU3CV67N32K9', iid='B00JKT0PJS', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LWZFVJA030WB', iid='B00IN9DK5W', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CVW2528DH9BB', iid='B0124CVQWW', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3P84XURF0N482', iid='B013QHJPUY', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A35W3NN11G5FYQ', iid='B00EH8MQTO', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JRE8QJQSXS5K', iid='B0045D7VZ0', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVP9NW07L1UBP', iid='B01CHGKDSS', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3SOV6BUMWHETL', iid='B01DK6MYKY', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3I3R03RTHYAJ4', iid='B00D0EURVA', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MWZBYALG9M9W', iid='B00P6ZXWCW', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3RD15ICP8LMM1', iid='B000V0IBDM', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APHEB66L6TMSK', iid='B01FLROTN0', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FO0FPTE58LIK', iid='B00NRPJSLC', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXTNFL34LSYPJ', iid='B00STV1K9W', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2OJ6MTCZS4G1Y', iid='B01ACYM3YY', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMKTE6JHTRX25', iid='B000I2Q2IY', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22QHDECJH4H6V', iid='B00KYH9VHC', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2UGYNCW9ABMV0', iid='B000IBVSYI', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WQN4U1IVPNEO', iid='B00YFS31LS', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJE6CLU8HUTU8', iid='B017VPXB0C', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4H798I2B27YT', iid='B000V588EO', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3R25EN7QO2ADZ', iid='B0017LD0BM', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2G7F5QK7OEL3G', iid='B00156BAYS', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A99IF4E5X47GC', iid='B013RUTVDG', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4KHM8SZ0R15A', iid='B00PJIV8OU', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1400F6VP0H0W2', iid='B018XV27HG', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3C0T70D5V9KIX', iid='B0052B4VWA', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1157HB5T7EQBB', iid='B00I54Q868', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OE4VAFLKF9ML', iid='B00CAA2BC8', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FSWVC1X7TAG0', iid='B000EVEAS8', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2YJ23HRF16ZMZ', iid='B00GTUEY02', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FJ42CJ1BSZLT', iid='B00VBDTHDQ', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NSTZV0H4YGRF', iid='B00O5C11B6', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3VTBW44KZF8T9', iid='B00RLSCLJM', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AR4M0V1Y1ZRWT', iid='B00O15LH2U', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AF7B4YLAAFG82', iid='B007XD6K1U', r_ui=4.0, est=3.1818181818181817, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1D2ATT020KJ0T', iid='B009RUKQ2G', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3AUU5XJ2P4B0C', iid='B00KXR6UHW', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A30CFZO2V4IA2J', iid='B00N1U2MVQ', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MK9GPODVH4C5', iid='B00ONJ045A', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1H6T5RY4FXTVV', iid='B00KTFS0J4', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15O808IG4IXY2', iid='B01CK9KPCG', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADT1KSJ347WUU', iid='B00FEVBQ7G', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ISAYZHF8NW4H', iid='B0017LD0BM', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A36WVSC6UURE4N', iid='B0098ANDCK', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AL4QOPJBDCY0W', iid='B00ID1TOF0', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5DZ16H3L6N2R', iid='B016XCVNYU', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3R131QM4H05XL', iid='B0185GSQOC', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A297ERUCST4Q4', iid='B00L1S8R6E', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UXNKRJ3FZZ41', iid='B004U325SI', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZGXOLSCW7R8G', iid='B00V48XOH8', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2K7IXYJK3SGH2', iid='B01FF9YZR4', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A22HKN2T7HV1S7', iid='B00BOBCMUU', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FHH1HUWHCVNM', iid='B002IYKIOY', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2PP3GO3WCT4JE', iid='B0018N8CHQ', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7GSEQFFFURE3', iid='B0068ODYAA', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YEWM1MPFKCA0', iid='B009PA6PPA', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7INMIF2DO84R', iid='B01GCMJ7QC', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21C98XLJZ1ILU', iid='B01DOBP4VG', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VHHA8RDUBE2Y', iid='B00TKM40CI', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A17CXOHPYWI3UZ', iid='B000NBIMG0', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AB8FAH0LI8A67', iid='B00N0S9MVM', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26DQIE5JRHSOL', iid='B01E94TZZI', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1433JJPWGM436', iid='B01DUMPPVS', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1C4UUBSTMQ73A', iid='B00N8PB9M2', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UPK8DBDAHIE5', iid='B0136L3ADS', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGS9VCXHJGVXT', iid='B01GIN6VSW', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Y1B60LN67RR0', iid='B00BJQKB9E', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XGY0LIXQJY9I', iid='B00KK1EV1S', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3N3X490B7JZKR', iid='B01D4MNNQS', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SUDULU7JWHDW', iid='B000RO5UYU', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2G0M9ISK4X7E0', iid='B00GYTNSLO', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CZ7Z5HF49BD1', iid='B00Q5LPJ0Y', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2R5GC9ZZXV2TF', iid='B00OWMCORY', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1VCXDLN6P94LJ', iid='B000YFSR5G', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AM2GWPXK02CCL', iid='B001HWBZNQ', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32BWU089OYMJ8', iid='B00PBVVD2W', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ADCX9BCQ2U4X', iid='B004OA7A78', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18MYEPLXFY9OG', iid='B017OYDHNQ', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OKIIQNTKZM84', iid='B01DF3L5CA', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARM1SYSJ0OE8A', iid='B019BEMRVA', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1P9VRALB6MSET', iid='B00XD6C0IS', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CRJW269SN0OX', iid='B01CE53K64', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9S8PIDJNOWRW', iid='B00BA1KI0U', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1B68LBJSAVLMM', iid='B01A7D4QH2', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YRRUPHM0UHVR', iid='B00ZBMECL0', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2IYYVS699R010', iid='B017IYN9RQ', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACJ4LYKH6XXKQ', iid='B01CUY5TQS', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AI4C93XV8L8ZD', iid='B0143HKDV6', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1SQS2VTTE43Q2', iid='B00OCFTMVW', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2KS3DLSQK2UL', iid='B00ISJXHG4', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SHXN4SK3MX21', iid='B00T9Y4DEM', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JATDIU3AFTBQ', iid='B01DWPSGVO', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29CRLT7AKA6RM', iid='B00P39C79U', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JUBDRUA0QYMP', iid='B00UDXTX7U', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1B5QIHW7VK8Z0', iid='B01843ROVW', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A35XBTKB398KVW', iid='B00ZW3SCF0', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37PV3ELSWJDZH', iid='B000K2PJ4K', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10ONZW2SNB4AP', iid='B00PBDCGWQ', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NVBWXS56Y7Q', iid='B019BJ8VLK', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26L2TNEAE7EXL', iid='B00PDACJ42', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TXSGQWQR7WEE', iid='B00BUROLDY', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A14LBGK0Z1FMMK', iid='B00LGXZW80', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WDQL5RZS1QOD', iid='B00Z2BLMSQ', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AWD1LR29MCO7R', iid='B01DZGV734', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A27J6BE3RBXJSG', iid='B0123BTLR6', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1C9MST9ZPY35Y', iid='B01FIBYY52', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NYX9RQN94PU4', iid='B00I5RIY1W', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JP1PJ38QF27', iid='B015M5EFB2', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YSKBSRI1FZUZ', iid='B00JC28TGE', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YE2LCYRFCCTU', iid='B018LIQU92', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMQKT48IKJ80M', iid='B00N9ZSJC4', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RR7IYWAROPTZ', iid='B00SVMXN6M', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1VAC6XP869VEJ', iid='B00VSYHMLM', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1PJHKWP0RQTJR', iid='B01EFV1AU8', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TY4A8MBI92ET', iid='B00FITPTTK', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQ1PR9IQ14PPC', iid='B005QCNH9S', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3NJTEFXKJ6WWB', iid='B00PHGJ5I0', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31S4MSF0FB4IH', iid='B01791SJ0K', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IHQQQZZZJPR0', iid='B01A07CGWW', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GWZ3HYVX8SGI', iid='B01AHD2NQS', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21RIP8OYDBWJ7', iid='B01D2WOUBW', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31VXHLM9NV0KN', iid='B015YYUW0Y', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3NG2HOIPSTECW', iid='B012R6MKWA', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APKFRK9IBKWKP', iid='B01AVYXZHY', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJPJPCSZ9J41N', iid='B00UB3635M', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8CHH4GOXRTUD', iid='B015FDC4K0', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PXVISRQXREYQ', iid='B00XMQL01M', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FE2RR28PALV3', iid='B00KMFQQJC', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1G19YB9Q323E1', iid='B00FJ2QJ72', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2X9T0XQCY4VFZ', iid='B00X23GJMK', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JRMPT7J1U6HC', iid='B00K6X6RM6', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BM8R2LNZ1O05', iid='B00Z4WFQIU', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1A249C384YHJW', iid='B00XCS6D08', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LPQQQURQVCME', iid='B01DL6W156', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1HYDNZK9WP0O1', iid='B015SRKE1Y', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAY347R9G35VP', iid='B0177TV3X4', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2819ODMT6CCLP', iid='B000685FK6', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A25CMOKTUDDQYN', iid='B014OPGBNQ', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BS5MPI35WU97', iid='B00UX378P4', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A345AKZGYG9I1P', iid='B014JCWKFC', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26P78O8OM1S7T', iid='B01CQR6HZ6', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BKDG3N78OIT6', iid='B00I54R17I', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3T8230ZUPFOUH', iid='B01H08ZIC4', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A24A1X38562RR5', iid='B00CHWVGTS', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JD4SGXAPNCJI', iid='B00QQ45HYI', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LTR39KUY8BIH', iid='B00EOMF83Y', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HXUVU18FTXTV', iid='B00FFRR2H2', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3VYCF032HIUU0', iid='B006XGK31G', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A324780GT4QOON', iid='B00Y2E23NW', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AT9RJ4VNZTBOZ', iid='B0145IEFZ8', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37BZX9YWH2C5O', iid='B015M36QB6', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2G7RDUYEUMI7Q', iid='B00UDF11O6', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANJ9OCCEOCOBV', iid='B00O3HZOB6', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1944Y235X4Z14', iid='B0015V8KN2', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AEIVUX2OC1CG3', iid='B015ZI9HY6', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OMO0WEHD0OAT', iid='B01B5SD5GQ', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYJA2G69TUQVL', iid='B01CW3V93O', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...
#  Prediction(uid='AOK9IWER0FMV1', iid='B00ZUA6AJK', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FG0KTV60KVYB', iid='B00A62U8QI', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RWLTHPUQRE6Q', iid='B00JOA8JW8', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1AEFQB74J49T9', iid='B018VP1VLC', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXKI8Z89OJS30', iid='B0131K1MFM', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FD6H0VPG68RQ', iid='B00AY8M3LW', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AK7FRBO443P63', iid='B01595PQNG', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVFEZI7173K5F', iid='B005M9OEPG', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2EOW3BZC55IJT', iid='B00TJV3HUQ', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADOL8DKY4HJQ5', iid='B009T8E3W0', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2PB500YVOKX56', iid='B00G4G2H8M', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZTAABK9ERJ8N', iid='B01HGRX1YG', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Z6G3I5CQBTRU', iid='B00XCWZBUW', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1HDJM8AT8QZ94', iid='B00LMU9NE6', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VB8E8O4Y6GH6', iid='B00BOBCMUU', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ATLHU8J15SRQI', iid='B003WJXKTO', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19GFQE83DAH4G', iid='B00Y5646BY', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HTVIJIF6PPPE', iid='B014I9L1EM', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A755ODDS6YUH6', iid='B00C97ISFG', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A11TDND9JRYTO5', iid='B00HX52W2Y', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QAPXXLKPO0NK', iid='B00KA3UV0Q', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AS8INYWMFFA9K', iid='B00Z972Y94', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A27868HL6G99L1', iid='B00HZ1LHCC', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1I65805J132XP', iid='B01EF9DQXY', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3N0HC324Y6EE4', iid='B007IVZWP2', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1AS1520CGYJ79', iid='B0058YEJ5K', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AUL1OQ52OFRFY', iid='B00UMXBBHQ', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2X16QA3E37LVC', iid='B00O2FSUL0', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3UGZU7ONR8G0I', iid='B015IWWV0G', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Q1D7ALJWW4DQ', iid='B008IBLBJM', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASRZPXC3F8A9U', iid='B018D4Z34C', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26FBCMCP4HPMR', iid='B01DXLTL4I', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYF0BLCK0F5KP', iid='B00SUMXGCO', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JQV469VTR2JH', iid='B00LWZH8C0', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AC3FH3FDI31AF', iid='B00UJ6GUYA', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FSQKDU7AWJSA', iid='B017I7QEZ2', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3L8UIU5CT536D', iid='B013S2SRB0', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3NQAJXL8QJF8X', iid='B016563L80', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OVLXLMW96T3H', iid='B00BYHUQTI', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJN2BNNE6J63B', iid='B01BDNCDM0', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2PUWDPGGMRZQC', iid='B013P17JZE', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MT4HSH6JLG44', iid='B00TJ4LOYE', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMP9Y01GC7UK2', iid='B015IH7LSI', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8ICLJAWSGOQY', iid='B017SJC59E', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASSUGYC2T8H1A', iid='B00T9TF5UI', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19G6F89CM1QJX', iid='B017LRH6KG', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AWKJ0RFV6MGFH', iid='B01EN5ORMY', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACN0S710EJH2X', iid='B0096D4O5Y', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASPWVIAFEZ1WG', iid='B000AT4INQ', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AI0X7RF8DRAB3', iid='B014WD812Y', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ATYX3N50VS1QQ', iid='B01CDV7TNE', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NVE0TX3ZB4SN', iid='B00QKBLB56', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2N54PX7459FV9', iid='B00R8SFYG2', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2H69QLVY3I7NW', iid='B000V0IBDM', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HP95HONNG90T', iid='B01EQB4UNQ', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACHCRUJXKXPFU', iid='B0169VM38A', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LWSTSNVA9IIV', iid='B00Y564600', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A187FIRR6A951Q', iid='B01GGEQSWM', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXXIDN2PMTRN3', iid='B01668UZ2W', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FEJQ912A5CJS', iid='B00201ER88', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANANMWR72XGNV', iid='B01CA3Y91A', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3AFG4P0PO39BA', iid='B00UTD4ACM', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9NBTDP1Y4JHR', iid='B01DR30R9U', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AZH806C9BISM6', iid='B013V4EQII', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BFA9Z38C6T7X', iid='B00DWJKQGE', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARIY6ICASOPS8', iid='B01G711PUE', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AMVXU2C7MTHPB', iid='B010SRTULY', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A13O4OO4WY1WNU', iid='B008EHO00M', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1D4TZ80BPUJXJ', iid='B01145BWXS', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYJ4UEKIN5DGF', iid='B0057PIKAU', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQLIFYXZ1RV56', iid='B000MLG81M', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A361YP9TEAKW3I', iid='B00W8ROHIY', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHQ8IM56BL5S9', iid='B00V48V5J2', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1EZGO398AW9YV', iid='B0125YG2WI', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10CM5OVZVDX1K', iid='B01B6MLF18', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AE17AHRJTLD0K', iid='B00CJ3SAF8', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GVHN4HI7KR7K', iid='B0186YFYUW', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JL48PL1IXE62', iid='B00JB0Y9MK', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21K1614D5OAHO', iid='B00FPIBY98', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APFE5VXI70K71', iid='B00ZOWJI7A', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2F6YDFP8R6DUR', iid='B003N7NXXS', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4KJIZ15R5DZ5', iid='B00VX1B9K0', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXTB0GHB14SJS', iid='B000P0X15G', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A23B6J4MFA21ZB', iid='B017D0MJRQ', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JDXWQ82RVSYC', iid='B00WMNEJYG', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2OGFIEIK65OTD', iid='B0102WISOK', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZG4OTMGQKV5X', iid='B00K2QLXL2', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANECAAG0676V5', iid='B01F1XBXN8', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AX8UXVRFQJOO8', iid='B019FDELQ6', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2PL7HFA5MT1FJ', iid='B00QY2EKHW', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HZZX9GDMZ9WJ', iid='B01DX82JWC', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2D34WG99F630I', iid='B00PAZ9KYC', r_ui=2.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ZGQJ428XU2RT', iid='B014DNZL80', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1C2CBGSJ1G0RP', iid='B01DK9EX3M', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A30MCMM9MB1RTZ', iid='B01DSUBG5G', r_ui=5.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32MMD4LI1OVM5', iid='B00GWQSZPS', r_ui=4.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2PDQH0HXGVPTU', iid='B00UHQ1FWE', r_ui=1.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UPYG99POG0MI', iid='B01AROGYC6', r_ui=3.0, est=3.9180952380952383, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  ...]

# %%
print("Item-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# Item-based Model : Test Set
# RMSE: 1.4140
# 1.4139714923326716

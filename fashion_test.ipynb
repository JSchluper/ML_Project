# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from random import sample
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
import os
from surprise.model_selection import train_test_split

# %%
raw_data = pd.read_csv("Data/AMAZON_FASHION.csv", names=['Item', 'User', 'Rating', 'Timestamp'])
data = raw_data.sample(n=30000)
data.drop(['Timestamp'], axis=1,inplace=True)
data = data[['User', 'Item', 'Rating']]

# %%
data
# Out:
#                   User        Item  Rating
# 54052   A2XGDWW77FEE7V  B00201ER88     5.0
# 387961  A3ETHOWPDSIXN6  B01FXEHODI     5.0
# 569520  A1D143Y4JVNBCE  B00OQ04XZS     5.0
# 494483   AT5A00RYJDEZ8  B00HYKK6V2     5.0
# 607883  A1UTF7VDL4GI7R  B00TQ63BQO     3.0
# ...                ...         ...     ...
# 102369   AB4KPD7OG3FZH  B00ACIFQGS     2.0
# 299999  A1U1D1KYZQ29JZ  B011M4A0LQ     5.0
# 292842  A3DJV2CJJDXRUM  B01090LK1S     5.0
# 672587   A78LWTHV27SHI  B011ISZW3C     1.0
# 267109  A2J85JF8QK3AFR  B00WFS9L0A     5.0
#
# [30000 rows x 3 columns]

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(data,reader)

# %%
trainset, testset = train_test_split(data, test_size=0.3,random_state=10)

# %%
algo = KNNWithMeans(k=5, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='A1B6V4Q3W65VUU', iid='B01DWBI8IO', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAK4EXLYIE5KM', iid='B00062NHH0', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A16GRITEI264PH', iid='B00FAD21NQ', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6UJXYTPJC3NV', iid='B001G7R0CC', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1PN7DYTLVESFT', iid='B01AHD2NQS', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2IGY77JABPBUA', iid='B019IIX3C6', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9UKQYQ68C2YP', iid='B01D3HOHEG', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IWVE4JMSJAQ1', iid='B000YFSR4W', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2QS22P4HS4NPR', iid='B00Z8V61K4', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1M9RRMQDEZCCS', iid='B00OPA8OP4', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5JRXWSKJDAH6', iid='B00E1LAO1O', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A890BVCQ05TAV', iid='B00KW4LCCE', r_ui=5.0, est=3.875, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3I4IME1NIPFQ', iid='B00R7ODPMM', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1L49UPSMYAEBL', iid='B01D2H9CQK', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AS1ZAT6MFXE94', iid='B00FA80S68', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3AOFXGVENKBR6', iid='B010RHVHMK', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Q9HJJERZ237T', iid='B00E4XRPG6', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3S9K9M8IUZAD', iid='B004AROJRY', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18HJLUCM3ZK2V', iid='B01DI4J0FA', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6I4WJ3AD2R75', iid='B01C4G7XDE', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2055SLLT5VHJP', iid='B0145IDYY6', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A28CZL3LFLXRA8', iid='B00OIWG7IU', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QEKH6WPUYH2G', iid='B00UNTISYI', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3L81ZACHLH8KB', iid='B01D3X9VMI', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2OKFZO5YLATO1', iid='B00I0VHS10', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A369H7SK49DB4F', iid='B01CRQB04O', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KPE3HARIAP8B', iid='B00E1L9QOU', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LU68MR7OVFPM', iid='B00IICTNT6', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3CT7HFZLFGX1B', iid='B00EWAZV8K', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1SUIO2XLUGF6K', iid='B00JZGRKJY', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJD5CZ4RLFDAK', iid='B006RA1JC0', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGJRP59VVXTVF', iid='B01686JIBQ', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3FSHSPIXYKR0I', iid='B0194X55FI', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RUIO3KV28PXL', iid='B00IGAOBEC', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6F55RFGFNSMO', iid='B0134IPSDS', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1DTNMHFT8Y8RL', iid='B01EHD03BQ', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KOB37N1RM86Q', iid='B00KHX2DXC', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IAZA5UD8MSAN', iid='B01GMZ29X2', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1P86NE25HCCMY', iid='B00SB0HHO8', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3MT10P0PH2GF8', iid='B01D97OCI6', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5PPWGM2T3TD7', iid='B01FES6E34', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3UORIJWI4RHVV', iid='B00LULRDOY', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJIZIR7XR4U81', iid='B00SLHJ7XU', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JA04NP8ZTNA', iid='B01CAVFB2I', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A23ZLVSKUQE5DR', iid='B00FKFLHRK', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26630P2VAT6Q8', iid='B01G5BUAMK', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A24ET3LD9V5QLX', iid='B00E6MRBU0', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A370Y2LYOK3XB6', iid='B0144HG8GO', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3USFFE3Q3BM3R', iid='B01670UN3U', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29UUAEDDLY15R', iid='B00ZVFQRGK', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A20IIR0422G3A5', iid='B003WJXKTO', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3H9FST0V4TMC6', iid='B00STV2SI4', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A31BGTJJ9M0Y5S', iid='B00CKN7PYE', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TLRUG1HU8SF9', iid='B011QFAG8I', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VDCCSA0LMWP7', iid='B00O6RMC54', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZDINYVINMFG9', iid='B00JYT35ZK', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A172DFMH5R1QQ5', iid='B00H0TUV6C', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KUMNO842S7O4', iid='B010D1S2OG', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AS4RWY87KJXH3', iid='B00DP73YLM', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5GDE9G67O5JH', iid='B00F8ZI15I', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2UP8I9W0IQGXI', iid='B000V0IBDM', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XYL14L8YDU8U', iid='B00IQAOR00', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1S0UONLCWCF5I', iid='B016YWH0PA', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1OV9TAAR9TSPG', iid='B013DAEO2S', r_ui=3.0, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3UGQESSXA3RND', iid='B001F8LJ92', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVFG2IBURM71W', iid='B00VIP5Z7O', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LBCJPDEVSBEJ', iid='B00VTDWVSQ', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NXI7CX0768KG', iid='B00BJQKB9E', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3OSM81OP05VMH', iid='B015R34140', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADBZSBTUZI18', iid='B0133ZQU7K', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A9AGBYATBB9ZW', iid='B017IJL8GK', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1DE51NW1PKCJ3', iid='B00062NHH0', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2N2GO1TS1RZBJ', iid='B00OL47IO2', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVHVZJ5HB6FSK', iid='B0058YEJ5K', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1A9SV8Q8NND52', iid='B00M49FFSC', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VFUXCD4M8M27', iid='B00HF4N5C4', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BL9O5Y1C23EC', iid='B003MWEIA6', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AD1TB683LQRD0', iid='B01FES6E34', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Q9RLNPBGTW62', iid='B01CJG9YZ4', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2UD5K4Q72HUDW', iid='B00W1AFV7O', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQN5EC47BM75W', iid='B018FM61Q6', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1DQEC7VUXR1S8', iid='B015QUOOGO', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LS4E2KWMQ9Y3', iid='B000RN63K6', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AIPZM7FKJQUXF', iid='B00LQO1XOG', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A258LZMAW1E401', iid='B00Y2E23NW', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1O5T615LSL979', iid='B00P7BB7YU', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2555FNG6WF629', iid='B01AYPQ248', r_ui=5.0, est=4.2, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1JBKICJRGKPPR', iid='B0017JF4FO', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3V7G7TA8AUN6P', iid='B00FKFLFKY', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZHYFQ3J5CGZP', iid='B00YC5U8X8', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1MZ5MNJQ9VS65', iid='B01GRJKD1I', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3HC5WPY3B9LC6', iid='B015E5Q4ZA', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26DK3BH8YPM4P', iid='B005N7YWX6', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYZQMALLFTCVM', iid='B00UNTSPDW', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LL980H60LQR2', iid='B000HKLW2S', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3DKSL5L50YAZM', iid='B000JOOR7O', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APO5AN2A4O96F', iid='B00PAQMYBM', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1G47ZKZGHL3DT', iid='B00XO8SOR6', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2RHUZL5D87UX0', iid='B019FDELQ6', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A388KN4WIXX4IY', iid='B00YRBTT4G', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26JG1E0JSUJP7', iid='B0105EFX1Q', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABONZZSS8YG3K', iid='B0014F7B98', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A297B98DNSD4VW', iid='B000PHANNM', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LKPFLQ6OQ2L0', iid='B00INLBWLY', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7VT4RR4CKN8F', iid='B018W8EG8I', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JKS6Y6DHA3BJ', iid='B013TPMNO8', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A27BHM1HB5ZM93', iid='B007AK4DPG', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2W6Z9ACGSPNER', iid='B01CEZSSXY', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LATDM7B5AVRK', iid='B00LMUOXP0', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ZX84ZP1XJJHW', iid='B00IPTB40S', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18YNQYCUHWU6N', iid='B012FXRRYQ', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AWHCM4RUNKT83', iid='B00LGMNZ80', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A13TEAC37XNUEW', iid='B00LIA67HQ', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A238PSXJMS84XJ', iid='B01735Q4O0', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FLMD5F2ZZ0K9', iid='B013TKD3L0', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AE378YRDAB28R', iid='B0198PF60G', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZQ04F8TJH4TF', iid='B017D7B9DY', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXU88G7EDSLY3', iid='B00EWNRP5E', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A343H5WT8XSR2J', iid='B00HEP1U26', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2S2CIIJH8ZGT8', iid='B00EDQMQD6', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A35CPVRCFU99D4', iid='B00ZLVQN2W', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANTLOTLGG3NNP', iid='B010A0ROR6', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1MG0W42DA6VDJ', iid='B00PYIDSDY', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21IG5LB1OXWQY', iid='B0155VGL56', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAQSIUIGPXVI5', iid='B00VSYHMLM', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3ET2YPSGZ92PQ', iid='B0185LULRC', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Q1KOI6ZTOE73', iid='B00K0C87XA', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5ATDM86I9Q9U', iid='B00N7G7K0C', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QCY9A64T6S83', iid='B00ZBEJ98Y', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CGZM6IJXXBL3', iid='B00IID3SKA', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2G9UTKZH7YWLZ', iid='B00U5QQCI8', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A11WRTHAW0TZYK', iid='B01EKVSO2K', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2O4GGJ9A8598O', iid='B01ENDTHGW', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AO6NXW7V131EY', iid='B00VK6A9C2', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ASYIMBO65RVGB', iid='B00O16DJI4', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AUHDGHLFG2HG9', iid='B01G4STY44', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LMSXYPCKYT6L', iid='B00LKWYX2I', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A158MCE2DRVYQP', iid='B0182SAOXY', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A287DTZMYA4IJO', iid='B00VIKU05Q', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FL4YYTG000DE', iid='B009UNDXXY', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1EPB9SFZCGNRU', iid='B00QAJK8SE', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2IALWSO8MAJK8', iid='B015ZHNSOM', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A39AO03IU02M8N', iid='B00JCUPW3E', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A194O6A1CNHCBP', iid='B00JXMEHT6', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5JUJ9O4DPXJ3', iid='B01ELB9DBA', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AN4LA7P3TM196', iid='B00E9ASWS4', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A62YM6QR6WO9R', iid='B01AFYSG9W', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACM81JMTVNKP3', iid='B0122MHONO', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3I8U9OYTEOHIZ', iid='B0136KPT5G', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MLG70WGUANKJ', iid='B00DQYPSJU', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARSKK5ZTJZ5IK', iid='B00DR9AQV4', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38PM3PCVVYZ7M', iid='B00GXE331K', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1N91D0ZNP7WA2', iid='B0112Q161M', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACRX3C3MLG2LT', iid='B01CSK9N5M', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BE8CGU8BT0HK', iid='B0179AAO2C', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AS2BJ90BMSLCV', iid='B00BNB3A0W', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LZLBZ7A2613H', iid='B00DQ59IQ8', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AK1KJOZAS5ISO', iid='B00EY40JQI', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A45A5MLYKRVHR', iid='B01DSV48LY', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JK7F8U6HVX87', iid='B00O8QYDNC', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A29J7TY3U0ZJL5', iid='B01G63U7MU', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3OW2Z6KDJPZBN', iid='B00L82BTFO', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1K6RIU4KAN1HS', iid='B001B1THSS', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ARI3SVHMJM6V', iid='B009UAMWR0', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1NPJ6K2I6MNTV', iid='B00D09DZGE', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3M8BSQRTWADZO', iid='B00W3JFI9O', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AFM4SA83D0PP1', iid='B00533A2CU', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A17GP0QNVOAMTU', iid='B01DC5JNGG', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2SP85V2ZUV9FG', iid='B00UWZK8TQ', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37AL9QVFN5TBM', iid='B011P6PLCE', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AWIPJILFSLB8U', iid='B00076601U', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BR9YI89JB02V', iid='B000EM7WNC', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AOLIF68653S60', iid='B00KVMVGI2', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1N6EX09QYXR1L', iid='B00CZ50CXI', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACQDG1Q9YEWBH', iid='B00S99PCSE', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A369P1R7J1N4MW', iid='B00HN5BFA4', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3M5KTILGVR1YF', iid='B018TRL0RW', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADL7JXK2SJ4VA', iid='B000PHANNM', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18H88PZ7XGUXF', iid='B013SLWJJW', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AC8C9PT59CDW1', iid='B015754RII', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1342KSYME2QZF', iid='B01FLY2LRE', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2AM4MDACTIPY6', iid='B01F9FKN2K', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1S1UIXIQGBO4X', iid='B003KK6UEC', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21K12LFK7OA15', iid='B00U0HPPOY', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABJBB12HC3J1N', iid='B01G4ZFB2Q', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1SA1CPW73O6R1', iid='B00Y1YDKYO', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1Z9X6A2U5WY8P', iid='B01D2HZ7AK', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AT0NMK2QXQ9HH', iid='B00B7YLOB2', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AFC7IQAQKVOBQ', iid='B01E3F46DO', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AC5PPX3XLCZN1', iid='B009MA34NY', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AF82E8SEZZHY1', iid='B0148U9ZUS', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YWIHV69NX95S', iid='B00FDND7KO', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3C1D194R04N2F', iid='B01688INJW', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3AY7VO3JRNIZC', iid='B00FAD21NQ', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AEHOCC2S72M38', iid='B0092UF54A', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2OV3TXTT34GZO', iid='B00A71O6LQ', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KSWPTXJJ5PG8', iid='B00W035YMO', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NWI010N4ODCX', iid='B00JQ36X9O', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3VD1HQC02QYG4', iid='B01E9TYM4M', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ALU5WZ8J5O2BP', iid='B01E5FIY6C', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TY5LMLXI0MIA', iid='B01DLHX6AO', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2AGXTCSJVO09Y', iid='B019SR372S', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A14G6AUBVZISZE', iid='B00V5BV778', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1VPEWW3D9T9SF', iid='B00WV63B8O', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A36Z1PJ2HL6W15', iid='B004MNDTOK', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AR54Z4KPQEEC', iid='B005Z8CEQA', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANKYOCWXVTDIS', iid='B00928XTRC', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JUSFG1XHXEPI', iid='B000KPIHQ4', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2O45U7ZDRC3N0', iid='B001T4MSU6', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AZMK7N4FWJT1A', iid='B01EQWCP14', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XU4KQ4SSAYQF', iid='B00YHEURAS', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1JRXAR90YYI4', iid='B011HY0PQQ', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ATKZ8FJFFZ1GF', iid='B01E69KTQU', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1W733PYS4GWT1', iid='B00RLSCLJM', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RMJQ5FGT9EMJ', iid='B00Q438ZEA', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BDEUZCIWU7IS', iid='B006ENP0SE', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VNRZZUYADPQO', iid='B00LX0KSIA', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KYK1UBIVXID3', iid='B00NW6ST66', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3Q9MJODKG0NWU', iid='B000WXIK98', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1YZEYQ72XK7X8', iid='B01CJ97XYU', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2H2A71GOEGPPK', iid='B00HH977ZS', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AR2TKF9C6VSLW', iid='B01BFWVOTW', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2USZ7EM94TFJ6', iid='B00BTMZ7Q0', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A122Z081OYUPBL', iid='B019W1ODDM', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2K7IOJOHFOF3U', iid='B016XYQKIM', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1F62F8VQBU9FG', iid='B00OVJU9D4', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1E23WJD2VMBD7', iid='B00QA6MCFY', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A24C68LJGXB2YP', iid='B01EL76Y8E', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AOAV7YRGTS2BF', iid='B013JX8I8K', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TMA47HRIMVJS', iid='B0121M1AJE', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3OUHP3WDJ426', iid='B00I1AEDNG', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CD9PT0PK0TPM', iid='B000WDUX3Y', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A373WRYPNMD7BL', iid='B0136KPT5G', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1TCFFC1HQ4OO0', iid='B01F4GUP7M', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IWKRAGP0QBTD', iid='B00913ZVHE', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1RTL8Q1JUJLJI', iid='B00L3YSG4Y', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3DWDUNOVCEPVE', iid='B00PYIDSDY', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A236ELWELKQPYO', iid='B00DUYXL86', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3URPCC9XF9DYB', iid='B01CZL0O2K', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1K8CSOUE1CPZR', iid='B00MU9YVDG', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1D7QWFVQCM1BD', iid='B00DY45UH2', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A15U6LU5N31FTC', iid='B011P3DFSE', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Z1AZKXBSIIAJ', iid='B0113RAWF6', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3OBENAIV0BIW2', iid='B01BSJBSKM', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A24NWJ1GO0GLZ7', iid='B017EAZ896', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A43O931YUK564', iid='B00HMBIO1C', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3G8U446QTTDMU', iid='B00V3Q7AMG', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3CHZZOMRC28PD', iid='B000V0IBDM', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1EZ1CHP91EIVI', iid='B01EY6041U', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AL52XU53IC9QC', iid='B00UV3QALO', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LOAFYNASKK72', iid='B000V5DJEI', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3ER5LXUPS864K', iid='B00GC2K2TO', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ARQD82YMU0GVA', iid='B015XT9BJI', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJFLHSRFQLR6E', iid='B00JXO3RCW', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A46RY8666D5J6', iid='B000V0IBDM', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LQIZKOGCXPW3', iid='B0045D7VZ0', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BQ2O8UJF0T1F', iid='B015YGIDWQ', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A24WKJRALMEYTK', iid='B013V2D3QQ', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3D15BBNNXNZR0', iid='B00V9POYJ8', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TP3W28L6XPRF', iid='B01AL15SQ8', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AOMDYAHZ6X011', iid='B01C8DXUTE', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2GN8PGML2OSCC', iid='B00DF9LVLU', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVOKJKPIPRMW1', iid='B01G78HQZU', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NLK7Y3IC6VPK', iid='B01464A5X2', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3DY7ZZMKEKRG1', iid='B0148W0WNA', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CQZ3ZP32SDPP', iid='B00B5TEIAS', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1CVIEP19YAHHL', iid='B00G9CRMSQ', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A24M1XH1WHVRZV', iid='B00794QYMS', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3VMENM5CPGF1W', iid='B009T3SNZS', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A33EWG3P7NAYU9', iid='B00E3CN1FW', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37D51GNUFCOW9', iid='B00TY0BYW0', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GBAH8F6FRWLK', iid='B00FAD21NQ', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BEF3DU6TQID', iid='B00HDOAZV0', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHC8GHH4IQ3FD', iid='B00S4661VE', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KBGZ0D0JP4PO', iid='B00V903YRQ', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAMFJ7NENQITF', iid='B00NBLXA0M', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANC5XU3WCRZPF', iid='B00KA3VG7I', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A11AKR9JSYL3Y', iid='B000YFSR5G', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A28BQ26P37ZIU', iid='B013V4R7Q6', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AAZ5392IELXX2', iid='B00XV52VMG', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2U5XTWX6LUC3P', iid='B014FASM32', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ABGJVZZ643CTA', iid='B00YGMRQTG', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1X6QM5ZM35K1H', iid='B0012DR1LU', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FVBERKZK6NQO', iid='B00LMR1IIS', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADC7X6TT24139', iid='B01BEPL94U', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AA2CT2G07CPM5', iid='B013UQN8X6', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3P2XSOOUGUTA0', iid='B015VVC67W', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2AN6V38B93CAH', iid='B01H4SF4AQ', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYZIHDP5MZU6D', iid='B0057A0KVC', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LM6959HI4JPZ', iid='B01CIUN4P2', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1G7EAPLDL0GKP', iid='B00DP5NNHY', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A391RE5DYP4XVG', iid='B00F55SMGO', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1DL6R1VTMTWA3', iid='B01CJXSAAW', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A8UJTO2KWWW2M', iid='B0105T6ABI', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3F9QB2R9RBKGU', iid='B00KGMGACO', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...
#  Prediction(uid='AS4U0HUU72NI1', iid='B00BV1WHPI', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19I6RFSLTP3SS', iid='B01C1DJYSW', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38LM0WR9X9AJ7', iid='B009046YFW', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KB67J1ZI2PQW', iid='B000V0IBDM', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A14NZV01GJJJVV', iid='B013HU5MPM', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ATXFH1CTN6986', iid='B00A8FWGS6', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TXQ1NP548FJM', iid='B012BV51O0', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='APGH8B7HZOBQG', iid='B00LVNOUJ2', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A30DN8D48270EA', iid='B01EN36PB2', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2VQZV04PXSSM2', iid='B00MB14VOC', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A110MU3L9CLLVL', iid='B00NORCV44', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18UO9WP2ZBJ8Y', iid='B01CNM0W4G', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2H8N75FYH7UNI', iid='B00I47ZA38', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NR0PJ3SP2LGW', iid='B00M1E2DM6', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A366Z0VVOYOHG0', iid='B00HJJZ6DQ', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2JD5TQH7BXNJ5', iid='B0176Z3IQY', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A188OLEUR0AC6M', iid='B000NBIMG0', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2E2HOS60V7BVI', iid='B000PMNS3E', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AHSAQFKOZHI55', iid='B016X23YHE', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1UKYJPD32YV35', iid='B00TI6S4LY', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AWWT91VY9GSXF', iid='B00ZUA6AJK', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HUEPR4SXZ7MN', iid='B00AEDFN9Q', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1TUMTROZ9OXEA', iid='B00PFL7XQI', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1K7PB4TCHVF89', iid='B013VG9VE0', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVXHYVDQ7B81T', iid='B009VKV0OK', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5CNVTMYJXH53', iid='B00DPNYZ78', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38I7MUUX1G2F3', iid='B01049596G', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A141WZDIZW4TFY', iid='B0042T8BD8', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACFVFN9516ND', iid='B00D9EIB2I', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AUN2G88C26KJA', iid='B015PULZO4', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KJE5XL58MJNY', iid='B00CMSSZGE', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1IB1EG60POZ5T', iid='B00CPBRDWA', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AK4Y5QCF8LRWJ', iid='B01G6T0936', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QRQY0L6IFN18', iid='B00W51QPIS', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1LN09Z2UDE5CY', iid='B00V9PIV3S', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3QPLS13SBPL0F', iid='B012V1GBWQ', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GSTPP7PO14YL', iid='B00N283G3U', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A34FJ0OXKWHTNT', iid='B00GXE331K', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2AR5TJ3JWDWRY', iid='B015HZSDF6', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3H6LR6HYLPW2Q', iid='B01DZA23GU', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AOURKK2CPSBGX', iid='B006WIYWFS', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1FG3EKAKHBSLI', iid='B000BB8CBW', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A207H9056XZD8P', iid='B000V0IBDM', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ACEOHFC3WVSIC', iid='B01E4Q9MJA', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3VC8QVVSPM2XU', iid='B001EIPBIS', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AVYS6EQ8QT9U', iid='B003ESTRW2', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FHKAQ1CD2NZL', iid='B00YMMIGH6', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JWQODK6POHG0', iid='B00YHAW1WO', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1CLRNY1X5Z403', iid='B00P1RX69E', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3OLX7J4YUR28E', iid='B01EN5O1AC', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XO04KJHET7EL', iid='B00IM07OGS', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A34UF9DQJOLTY8', iid='B00X92BSNY', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3CCPC01EY9DR9', iid='B00NV6FA5A', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WW6RXRAJDG9A', iid='B0156E5004', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3K95RA32QI1TU', iid='B00P9QPOSS', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2MD18DNO9IX9C', iid='B003WJXKTO', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A18A00DGF7KIK2', iid='B01H7KY678', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A38XA5ILTEQB2L', iid='B00O1ZMY4K', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KZ165Y43YXOK', iid='B00ZOQ4LIC', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A4GVI97D1NWN2', iid='B01CZL0O2K', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12B5AOORF9RFG', iid='B00BUCJLOI', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3PJCBN2DG7SXW', iid='B017OAE3TM', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Z70Z3FGJ947M', iid='B00K59FS7Q', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AE3MDP30GBSKC', iid='B01CL80NSC', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2041X4LZF2KGS', iid='B01FN7WFDO', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BSHGC9H3VQIR', iid='B012NOM7OW', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3V8TVMSO5W8KS', iid='B01E3TGGKG', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ATO5VX9J2KW0E', iid='B00GOFF5BY', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2ERLZ73I69I3I', iid='B00YAFK7UE', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1H3YQBU418BAP', iid='B00N5HA3P2', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3OYIS41E0T75W', iid='B00FXOFTOK', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A26HJNXJ9IX0YH', iid='B0026OSMSU', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12ELI3KWAZ4GH', iid='B0172XKTG2', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1I7GOZ3UXSNUA', iid='B01G5D5H9E', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AM2XWRQJD1HZZ', iid='B00S3UQCEW', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2NKU7KCHEGVGX', iid='B01AZN9LZ6', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A24SRDO5VVFGYS', iid='B0189GJRJQ', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ADWHVCLBY47N8', iid='B00TQAS47Q', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1K4MYCGTEJFU', iid='B01ENXR70K', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3TPED76TGMK74', iid='B01FO04LGE', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2O05RWKHXNWTM', iid='B00XT15P8E', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A136U3D1EJDRBQ', iid='B00L4YXEE0', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AWL5WR9N5KHK5', iid='B01AR9WAQK', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A211DYW0X9DDNH', iid='B0067A40NA', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1AR16B7IU6J5A', iid='B00QWUTOP4', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19IP3TUIGR5PW', iid='B00RN65GXA', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3A4I5YVBL75BX', iid='B0091V6UQM', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BQGOHT0Z51BI', iid='B00GNN5TU4', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1DHLJG39FPZXF', iid='B00VRLQB9K', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37KRDIMMO7EZB', iid='B0194XQ5FM', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1PAPFLHGPLQBQ', iid='B01BWM0GD0', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1ZOQXTFA44ZK8', iid='B00DQM58SI', r_ui=1.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2WKHUWW46441Z', iid='B0146CG7XG', r_ui=2.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A274CTY7G8B82E', iid='B00E9OTP2W', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A190I3C4C7AIYD', iid='B007F55UGW', r_ui=4.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2UYO4GZRPC348', iid='B00PJIR7M2', r_ui=4.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AG5TA5F5AXRA9', iid='B00I0VHS10', r_ui=5.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TGWCKTZNMJUN', iid='B00DZJSIHK', r_ui=3.0, est=3.8943809523809523, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  ...]

# %%
print("Item-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# Item-based Model : Test Set
# RMSE: 1.4298
# 1.4297853035606714

# %% [markdown]
# ####
